# %%
sys.path.append("/nas3/gpratt/gscripts")
import pybedtools
import intersection_helpers as helpers
pybedtools.set_tempdir("/nas/nas0/scratch/gpratt/pybedtools_tmp")
# Out:
# /nas3/yeolab/Software/Python_dependencies-2.7/matplotlib-1.1.0-py2.7-linux-x86_64.egg/pytz/__init__.py:35: UserWarning: Module pytz was already imported from /nas3/yeolab/Software/Python_dependencies-2.7/matplotlib-1.1.0-py2.7-linux-x86_64.egg/pytz/__init__.pyc, but /nas/nas0/yeolab/Software/Python_dependencies-2.7/pytz-2012f-py2.7.egg is being added to sys.path
#   from pkg_resources import resource_stream
# /nas3/yeolab/Software/Python_dependencies-2.7/matplotlib-1.1.0-py2.7-linux-x86_64.egg/pytz/__init__.py:35: UserWarning: Module dateutil was already imported from /nas3/yeolab/Software/Python_dependencies-2.7/matplotlib-1.1.0-py2.7-linux-x86_64.egg/dateutil/__init__.pyc, but /nas/nas0/yeolab/Software/Python_dependencies-2.7/python_dateutil-1.5-py2.7.egg is being added to sys.path
#   from pkg_resources import resource_stream

# %%
human_ultraDict = {
"m6a_T293"  : pybedtools.BedTool("/nas3/gpratt/projects/m6a_analysis/m6a_cell_293T_peaks_cut.bed")
}

# %%
human_CLIPDict = {
"FOX2_human_brain" : pybedtools.BedTool("/nas3/lovci/projects/FOX2/FOX2_human_brain/CLIP/analysis_gsnap/FOX2_human_brain.CLIP.slop.p01.BED"),
"FOX2_NPC" : pybedtools.BedTool("/nas3/lovci/projects/FOX2/FOX2_NP/CLIP/analysis3/fitted_clusters.BED"),
"FOX2_ES"  : pybedtools.BedTool("/nas3/lovci/projects/FOX2/FOX2_ES/CLIP/analysis/FOX2_all.BED"),
'LIN28ES'  : pybedtools.BedTool("/nas3/mwilbert/projects/LIN28/data/clusters/LIN28ES_09.12_13_10_cluster.1_6_11/LIN28ES_09.hg18.1_6_11_clusters.BED"),
'LIN28v5'  : pybedtools.BedTool("/nas3/mwilbert/projects/LIN28/data/clusters/LIN28v5_2010.1_2_11_cluster.1_4_11/LIN28v5_2010.hg18.1_4_11_cluster.BED"),
'AGO1' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/AGO1_par_clusters.liftover_hg19.bed"),
'AGO2' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/AGO2_par_clusters.liftover_hg19.bed"),
'AGO3' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/AGO3_par_clusters.liftover_hg19.bed"),
'AGO4' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/AGO4_par_clusters.liftover_hg19.bed"),
#'AGO_miR24' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/AGO_miR24_par_clusters.liftover_hg19.bed"),
#'AGO_miR7' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/AGO_miR7_par_clusters.liftover_hg19.bed"),
'HNRNPA1CLIP' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/HnRNPA1_comb_trim_ingenes_clusters_hg18150_scored.liftover_hg19.bed"),
'HNRNPA2B1CLIP' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/HnRNPA2B1_comb_trim_ingenes_clusters_hg18150_scored.liftover_hg19.bed"),
'HNRNPFCLIP' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/HnRNPF_comb_trim_ingenes_clusters_hg18150_scored.liftover_hg19.bed"),
'HNRNPH1CLIP' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/HnRNPH_Burge_comb_trim_ingenes_clusters_hg18150_scored.liftover_hg19.bed"),
'HNRNPMCLIP' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/HnRNPM_comb_trim_ingenes_clusters_hg18150_scored.liftover_hg19.bed"),
'HNRNPUCLIP' : pybedtools.BedTool("/nas3/gpratt/RBP_peaks/HnRNPU_comb_trim_ingenes_clusters_hg18150_scored.bed"),
'HuR_HeLA_4su_demem' : pybedtools.BedTool("/nas3/gpratt/HuR/HuR_HeLa_4su_dmem_binding_sites.bed"),
'HuR_HeLa_4su_silac' : pybedtools.BedTool("/nas3/gpratt/HuR/HuR_HeLa_4su_silac_binding_sites.bed"),
'HuR_HeLa_6sg_silac' : pybedtools.BedTool("/nas3/gpratt/HuR/HuR_HeLa_6sg_silac_binding_sites.bed"),
}

# %%
human_ultra_by_clip, human_ultra_by_clip_fraction, human_clip_by_ultra, human_clip_by_ultra_fraction = helpers.get_raw_percents(human_ultraDict, human_CLIPDict)
# Out:
# # ultra conserved elements that intersect with CLIP-seq data
#                     m6a_T293
# HNRNPFCLIP               637
# HuR_HeLA_4su_demem         5
# HNRNPA2B1CLIP            157
# HuR_HeLa_4su_silac        12
# AGO1                     611
# HuR_HeLa_6sg_silac        32
# HNRNPA1CLIP               86
# LIN28v5                   34
# LIN28ES                   47
# FOX2_NPC                   0
# HNRNPH1CLIP              836
# HNRNPMCLIP                20
# AGO4                      38
# HNRNPUCLIP                35
# FOX2_human_brain          29
# FOX2_ES                   83
# AGO3                       3
# AGO2                      60
# # CLIP-seq peaks that intersect with ultra conserved elements
#                     m6a_T293
# HNRNPFCLIP               544
# HuR_HeLA_4su_demem         5
# HNRNPA2B1CLIP            132
# HuR_HeLa_4su_silac        12
# AGO1                     607
# HuR_HeLa_6sg_silac        31
# HNRNPA1CLIP               57
# LIN28v5                   33
# ...

# %%
# Out:
# ['',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/distribute-0.6.28-py2.7.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/clipper-0.1.1-py2.7-linux-x86_64.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/pybedtools-0.6.1-py2.7-linux-x86_64.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/pp-1.6.2-py2.7.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/matplotlib-1.1.0-py2.7-linux-x86_64.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/pysam-0.6-py2.7-linux-x86_64.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/argparse-1.2.1-py2.7.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/Cython-0.16-py2.7-linux-x86_64.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/nose-1.1.2-py2.7.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/ipython-0.13-py2.7.egg',
#  '/nas3/yeolab/Software/Python_dependencies-2.7/bx_python-0.7.1-py2.7-linux-x86_64.egg',
# ...

# %% [markdown]
# Looking at prevous data, seeing if it correlates, also looking at Julias data, seeing the correlation on that

# %%
import bx.bbi.bigwig_file
sample1_ctrl = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/12011012_m6a_293T/GSM928398_hek293t.human.sample1.cntl.bw", "rb"))
sample1_merip = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/12011012_m6a_293T/GSM928399_hek293t.human.sample1.merip.sysy.bw", "rb"))
sample2_ctrl = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/12011012_m6a_293T/GSM928400_hek293t.human.sample2.cntl.bw", "rb"))
sample2_merip = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/12011012_m6a_293T/GSM928401_hek293t.human.sample2.merip.sysy.bw", "rb"))
sample3_ctrl = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/12011012_m6a_293T/GSM928402_hek293t.human.sample3.cntl.bw", "rb"))
sample3_merip = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/12011012_m6a_293T/GSM928403_hek293t.human.sample3.merip.neb.bw", "rb"))
#JN6A_06_pos = bx.bbi.bigwig_file.BigWigFile(open("/nas3/scratch/ppliu/julia/Project_nussbacher/Sample_JNM6A_06/wig_files/JNM6A_06.sort.bam.pos.bigWig", 'rb'))
#JN6A_06_neg = bx.bbi.bigwig_file.BigWigFile(open("/nas3/scratch/ppliu/julia/Project_nussbacher/Sample_JNM6A_06/wig_files/JNM6A_06.sort.bam.neg.bigWig", 'rb'))
#JN6A_12_pos = bx.bbi.bigwig_file.BigWigFile(open("/nas3/scratch/ppliu/julia/Project_nussbacher/Sample_JNM6A_12/wig_files/JNM6A_12.sort.bam.pos.bigWig", 'rb'))
#JN6A_12_neg = bx.bbi.bigwig_file.BigWigFile(open("/nas3/scratch/ppliu/julia/Project_nussbacher/Sample_JNM6A_12/wig_files/JNM6A_12.sort.bam.neg.bigWig", 'rb'))
JN06 = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/20130225_m6a_prototype/JN_m6a_2_06_GCCAAT_L002_R1.fastq.clipped.Aligned.out.sam.bam.sorted.bw", 'rb'))
JN12 = bx.bbi.bigwig_file.BigWigFile(open("/nas3/gpratt/projects/m6a_analysis/20130225_m6a_prototype/JN_m6a_2_12_GCCAAT_L002_R1.fastq.clipped.Aligned.out.sam.bam.sorted.bw", 'rb'))

# %%
#sample1_ctrl_array = sample1_ctrl.get_as_array("chr22", 0, 51304566)
#sample1_merip_array = sample1_merip.get_as_array("chr22", 0, 51304566)
sample2_ctrl_array = sample2_ctrl.get_as_array("chr22", 0, 51304566)
sample2_merip_array = sample2_merip.get_as_array("chr22", 0, 51304566)
sample3_ctrl_array = sample3_ctrl.get_as_array("chr22", 0, 51304566)
sample3_merip_array = sample3_merip.get_as_array("chr22", 0, 51304566)

#JN6A_06_pos_array = JN6A_06_pos.get_as_array("chr22", 0, 51304566)
#JN6A_06_neg_array = JN6A_06_neg.get_as_array("chr22", 0, 51304566)
#JN6A_12_pos_array = JN6A_12_pos.get_as_array("chr22", 0, 51304566)
#JN6A_12_neg_array = JN6A_12_neg.get_as_array("chr22", 0, 51304566)

JN06_array = JN06.get_as_array("chr22", 0, 51304566)
JN12_array = JN12.get_as_array("chr22", 0, 51304566)

# %%
sample2_ctrl_array[np.isnan(sample2_ctrl_array)] = 0
sample2_merip_array[np.isnan(sample2_merip_array)] = 0
sample3_ctrl_array[np.isnan(sample3_ctrl_array)] = 0
sample3_merip_array[np.isnan(sample3_merip_array)] = 0

#JN6A_06_pos_array[np.isnan(JN6A_06_pos_array)] = 0  
#JN6A_06_neg_array[np.isnan(JN6A_06_neg_array)] = 0
#JN6A_12_pos_array[np.isnan(JN6A_12_pos_array)] = 0
#JN6A_12_neg_array[np.isnan(JN6A_12_neg_array)] = 0

JN06_array[np.isnan(JN06_array)] = 0
JN12_array[np.isnan(JN12_array)] = 0

# %%
plot(sample2_ctrl_array, sample2_merip_array, "+")
xlabel("ctrl")
ylabel("merip")
xlim( (0, 3500) )
ylim( (0, 3500) )
# Out:
# (0, 3500)

# %%
plot(sample3_ctrl_array, sample3_merip_array, "+")
xlabel("ctrl")
ylabel("merip")
xlim( (0, 1000) )
ylim( (0, 1000) )
# Out:
# (0, 1000)

# %%
plot(JN6A_06_pos_array, JN6A_12_pos_array, "+")
xlabel("06")
ylabel("12")

# %%
plot(JN6A_06_neg_array, JN6A_12_neg_array, "+")
xlabel("06")
ylabel("12")

# %%
plot(JN12_array, sample3_ctrl_array, "+")

# %%
plot(JN12_array, sample3_merip_array, "+")

# %%
plot(sample3_merip_array, sample2_merip_array, "+")

# %%
plot(JN12_array, sample1_ctrl_array, "+")
