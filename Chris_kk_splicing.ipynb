# %%
import pandas as pd

# %%
df = pd.read_table("/nas3/gpratt/projects/splicing/data/all.csv")

# %%
df[~(df.mjay_sepscore_yeo_july14_BrD_BrB == df.mjay_sepscore_yeo_july14_ELAVD_SCB)][['mjay_sepscore_yeo_july14_BrD_BrB']]
# Out:
#      mjay_sepscore_yeo_july14_BrD_BrB
# 162                 Cnpy1_1_s0e5_skip
# 249                               NaN
# 288                               NaN
# 306                Uaca_(508)_include
# 338                               NaN
# 422                Tsr1_(104)_include
# 565              Zdhhc12_(41)_include
# 664                               NaN
# 686                Gprc5c_1_s0e5_skip
# 804                               NaN
# 814       1700026L06Rik_(148)_include
# 916                               NaN
# 942                Cish_(221)_include
# 995               Dnalc4_(67)_include
# 1153             Chrnd_1_s0e4_include
# 1166                 Il17re_(96)_skip
# 1207                 Banf2_(119)_skip
# 1241                Hsd3b1_(190)_skip
# 1400                              NaN
# 1527                              NaN
# 1541           Etnk2_3_s10e18_include
# 1547                              NaN
# 1716             Slc18a1_(29)_include
# 1797                Nsl1_1_s7e14_skip
# ...

# %%
BrD_BrB_df = pd.read_table("/nas3/gpratt/projects/splicing/data/BrD_BrB.csv")

# %%
BrD_BrB_df
# Out:
#              Gene path               event position             event name  \
# 0            Ktn1   in    chr14:48323952-48325437:+              Ktn1_(69)
# 1            Gas5   in   chr1:162966375-162966679:+             Gas5_(302)
# 2          Agpat9   sk   chr5:101275247-101275490:+          Agpat9_1_s0e4
# 3            Mpp5   in    chr12:79849897-79895231:+            Mpp5_1_s0e5
# 4           Acot8   in   chr2:164618510-164620581:-             Acot8_(96)
# 5             H13   in   chr2:152526004-152530357:+              H13_(200)
# 6     D16Ertd472e   sk    chr16:78576299-78576703:-       D16Ertd472e_(34)
# 7         Col25a1   sk   chr3:130220655-130225350:+          Col25a1_(27a)
# 8          Ppfia2   sk  chr10:106364898-106368199:+            Ppfia2_(92)
# 9          Mapk14   sk    chr17:28828389-28850718:+          Mapk14_1_s0e5
# 10  4922505G16Rik   sk   chr2:157034285-157090808:-  4922505G16Rik_1_s7e51
# ...

# %%
df[['mjay_sepscore_yeo_july14_BrD_BrB']]
# Out:
#    mjay_sepscore_yeo_july14_BrD_BrB
# 0               Tom1l1_1_s0e17_skip
# 1                    Mxi1_1_s0e7_n2
# 2            Slc17a7_1_s0e6_include
# 3                Prkce_1_s0e37_skip
# 4            Map4k1_1_s0e59_include
# 5              Rbm14_1_s1e7_include
# 6             Papss2_1_s0e5_include
# 7                Gba2_(153)_include
# 8          Slc38a1_2_s28e38_include
# 9                    Ilf3_(98)_skip
# 10                  Ubac2_(48)_skip
# 11                Bsg_(348)_include
# 12               Gusb_(396)_include
# 13             Gdf15_1_s0e4_include
# 14              Dnajc1_1_s1e13_skip
# 15          Cep110_1_s53e66_include
# 16            Psd3_1_s40e45_include
# 17           Dnaic2_1_s7e32_include
# 18                 Rlf_1_s0e12_skip
# 19               ORF19_(81)_include
# 20             Mbd3_1_s0e10_include
# 21               Cep72_(34)_include
# 22           Fam134b_1_s0e7_include
# 23               Pacsin2_(123)_skip
# 24                 Eif2a_(119)_skip
# ...

# %%
df.mjay_sepscore_yeo_july14_ELAVD_SCB
# Out:
# 0          Tom1l1_1_s0e17_skip
# 1               Mxi1_1_s0e7_n2
# 2       Slc17a7_1_s0e6_include
# 3           Prkce_1_s0e37_skip
# 4       Map4k1_1_s0e59_include
# 5         Rbm14_1_s1e7_include
# 6        Papss2_1_s0e5_include
# 7           Gba2_(153)_include
# 8     Slc38a1_2_s28e38_include
# 9               Ilf3_(98)_skip
# 10             Ubac2_(48)_skip
# 11           Bsg_(348)_include
# 12          Gusb_(396)_include
# 13        Gdf15_1_s0e4_include
# 14         Dnajc1_1_s1e13_skip
# ...
# 22740           Rhbdf2_(667)_include
# 22741          Thsd4_1_s0e23_include
# 22742         BC021381_(240)_include
# 22743               Thrap3_(88)_skip
# 22744    4930562D19Rik_(136)_include
# 22745               Pola2_(651)_skip
# 22746          Eif2a_1_s0e14_include
# 22747          Inpp5f_(1304)_include
# 22748         Tada1l_1_s5e17_include
# 22749             Foxred1_(413)_skip
# 22750         Dach1_2_s21e25_include
# 22751     1110007C09Rik_(60)_include
# ...
