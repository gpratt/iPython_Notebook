# %%
import scurgen.hilbert as hb
import sys
import os
import matplotlib.pyplot as plt
from matplotlib import cm as cm
import matplotlib.colors as colors
from pylab import *
from PIL import Image
import argparse

# %%
path = ""
hm1 = hb.HilbertMatrix("/nas3/gpratt/projects/upf1/scripts/UPF1_1_2.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed", 
                        "hg19", "chr1", 256, 
                           None)
hm2 = hb.HilbertMatrix("/nas3/gpratt/clipper/clipper/data/hg19.AS.STRUCTURE.COMPILED.gff", "hg19", "chr1", 256,
                           None)
# Out:
# chr1 size:  249250621
# using matrix of size 256 there are 65536 cells in the matrix and each cell represents 3803 base pairs.
# chr1
#  size:  249250621
# using matrix of size 256 there are 65536 cells in the matrix and each cell represents 3803 base pairs.

# %%
hilb1 = plt.imshow(hm1.matrix, interpolation='nearest', cmap="Reds")

# %%
hilb2 = plt.imshow(hm2.matrix, interpolation='nearest', cmap="Blues")

# %%
hilb1 = imshow(hm1.matrix, interpolation='nearest', cmap="Reds")
hilb2 = imshow(hm2.matrix, interpolation='nearest', cmap="Blues")

# %%
figsize(15,15)
from matplotlib.colors import colorConverter
import matplotlib as mpl


img2 = plt.imshow(hm1.matrix, interpolation='nearest', cmap="Blues", origin='lower')
img3 = plt.imshow(hm2.matrix, interpolation='nearest', cmap="Reds", origin='lower', alpha=.5)

# %%
alphas
# Out:
# array([ 0.        ,  0.00310078,  0.00620155,  0.00930233,  0.0124031 ,
#         0.01550388,  0.01860465,  0.02170543,  0.0248062 ,  0.02790698,
#         0.03100775,  0.03410853,  0.0372093 ,  0.04031008,  0.04341085,
#         0.04651163,  0.0496124 ,  0.05271318,  0.05581395,  0.05891473,
#         0.0620155 ,  0.06511628,  0.06821705,  0.07131783,  0.0744186 ,
#         0.07751938,  0.08062016,  0.08372093,  0.08682171,  0.08992248,
#         0.09302326,  0.09612403,  0.09922481,  0.10232558,  0.10542636,
#         0.10852713,  0.11162791,  0.11472868,  0.11782946,  0.12093023,
#         0.12403101,  0.12713178,  0.13023256,  0.13333333,  0.13643411,
#         0.13953488,  0.14263566,  0.14573643,  0.14883721,  0.15193798,
#         0.15503876,  0.15813953,  0.16124031,  0.16434109,  0.16744186,
#         0.17054264,  0.17364341,  0.17674419,  0.17984496,  0.18294574,
#         0.18604651,  0.18914729,  0.19224806,  0.19534884,  0.19844961,
# ...
