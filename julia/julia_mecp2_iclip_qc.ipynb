# %%
from gscripts.general import parsers
from IPython.core.display import HTML

from gscripts.general import dataviz
from gscripts.clipseq import clipseq_barcode_metrics
# Out:
# /nas3/yeolab/Software/lib/python2.7/site-packages/seaborn-0.3-py2.7.egg/seaborn/rcmod.py:465: UserWarning: set_color_palette is deprecated, use set_palette instead.
#   UserWarning)

# %%
def percent(x):
    return "{:.2f}%".format(x * 100)

# %%
iclip_metrics = parsers.clipseq_metrics("/nas3/gpratt/projects/julia/analysis/mecp2_iclip_v1/", iclip=True)
iclip_metrics = iclip_metrics.rename(columns={"Processed bases" : "Input Bases",
           "Processed reads" : "Input Reads",
           "Number of input reads" : "Reads after Quality Filtering"
           })

iclip_metrics["percent_mapped"] = iclip_metrics['Uniquely mapped reads number'].astype(float) / iclip_metrics['Reads after Quality Filtering']
iclip_metrics["percent_repetative"] = 1 - (iclip_metrics['Reads after Quality Filtering'] / iclip_metrics['Input Reads'].astype(float))
iclip_metrics["Reads After Triming"] = iclip_metrics['Input Reads'] - iclip_metrics['Too short reads']
iclip_metrics["%usable / input"] = (iclip_metrics['Usable Reads'] / iclip_metrics['Uniquely mapped reads number']) * 100
iclip_metrics["%usable / mapped"] = (iclip_metrics['Usable Reads'] / iclip_metrics['Input Reads']) * 100
iclip_metrics = iclip_metrics.drop(["Finished on", 
                  "Mapping speed, Million of reads per hour", 
                  "Trimmed bases",
                  "Started job on",
                  "Started mapping on"], axis=1)
# Out:
# <closed file '/nas3/gpratt/projects/julia/analysis/mecp2_iclip_v1/B4P34_MeCP2_Mid_NoIndex_L008_R1.unassigned.gz.polyATrim.adapterTrim.metrics', mode 'r' at 0xca3f4b0>
# <closed file '/nas3/gpratt/projects/julia/analysis/mecp2_iclip_v1/B4P34_MeCP2_High_NoIndex_L007_R1.unassigned.gz.polyATrim.adapterTrim.metrics', mode 'r' at 0xca3f4b0>

# %%
filtered_df = iclip_metrics[[ "Input Reads",
                            "Reads After Triming",
                            "Reads after Quality Filtering", 
                            "Uniquely mapped reads number",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            #"spot",
                            "Num Peaks",
                            "%usable / input",
                            "%usable / mapped"
                            
                            ]]


HTML(filtered_df.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely mapped reads number" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas,
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads After Triming</th>
#       <th>Reads after Quality Filtering</th>
#       <th>Uniquely mapped reads number</th>
#       <th>Usable Reads</th>
#       <th>Num Peaks</th>
#       <th>%usable / input</th>
#       <th>%usable / mapped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B4P34_MeCP2_High_NoIndex_L007_R1.R01</th>
#       <td>    22,624</td>
#       <td>    22,405</td>
#       <td>     21,626</td>
#       <td>      2,484</td>
#       <td>    332</td>
#       <td>    0</td>
#       <td>  13.36554</td>
#       <td> 1.467468</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_High_NoIndex_L007_R1.R02</th>
#       <td> 2,954,652</td>
#       <td> 2,914,046</td>
#       <td>  2,825,301</td>
#       <td>    420,193</td>
#       <td> 30,487</td>
#       <td>   22</td>
#       <td>  7.255475</td>
#       <td> 1.031830</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_High_NoIndex_L007_R1.R03</th>
#       <td> 1,450,618</td>
#       <td> 1,429,663</td>
#       <td>  1,401,171</td>
#       <td>     86,169</td>
#       <td> 13,800</td>
#       <td>   12</td>
#       <td>  16.01504</td>
#       <td> 0.951319</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_High_NoIndex_L007_R1.R08</th>
#       <td> 4,793,524</td>
#       <td> 4,758,247</td>
#       <td>  3,459,824</td>
#       <td>  2,878,093</td>
#       <td> 52,284</td>
#       <td>   42</td>
#       <td>   1.81662</td>
#       <td> 1.090722</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_High_NoIndex_L007_R1.unassigned</th>
#       <td>         0</td>
#       <td>         0</td>
#       <td> 46,825,071</td>
#       <td> 21,028,187</td>
#       <td>227,150</td>
#       <td>  989</td>
#       <td>  1.080217</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_Mid_NoIndex_L008_R1.R02</th>
#       <td>19,676,831</td>
#       <td>19,457,554</td>
#       <td> 18,970,419</td>
#       <td>  2,794,820</td>
#       <td> 53,910</td>
#       <td>  115</td>
#       <td>  1.928926</td>
#       <td> 0.273977</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_Mid_NoIndex_L008_R1.R03</th>
#       <td> 9,796,821</td>
#       <td> 9,679,008</td>
#       <td>  9,519,476</td>
#       <td>    570,543</td>
#       <td> 29,039</td>
#       <td>   21</td>
#       <td>  5.089713</td>
#       <td> 0.296412</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_Mid_NoIndex_L008_R1.R06</th>
#       <td>    95,298</td>
#       <td>    93,964</td>
#       <td>     71,080</td>
#       <td>     18,586</td>
#       <td>  1,915</td>
#       <td>   24</td>
#       <td>  10.30345</td>
#       <td> 2.009486</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_Mid_NoIndex_L008_R1.R08</th>
#       <td>33,990,662</td>
#       <td>33,776,497</td>
#       <td> 24,266,033</td>
#       <td> 20,216,122</td>
#       <td>123,094</td>
#       <td>  545</td>
#       <td> 0.6088903</td>
#       <td> 0.362141</td>
#     </tr>
#     <tr>
#       <th>B4P34_MeCP2_Mid_NoIndex_L008_R1.unassigned</th>
#       <td>         0</td>
#       <td>         0</td>
#       <td> 42,415,296</td>
#       <td> 19,375,638</td>
#       <td>240,856</td>
#       <td>1,793</td>
#       <td>  1.243087</td>
#       <td>      NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
with dataviz.Figure("julia_out.svg", figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   "/nas3/gpratt/projects/julia/analysis/split_fastq_v2/B4P34_MeCP2_High_NoIndex_L007_R1.metrics",
                                                   "R01 R06".split())
    ax.set_title("B4P34_MeCP2_High.metrics")
# Out:
# no barcode unassigned 55683960
# R08 AATG 4793524
# R02 TTGT 2954652
# R03 CAAT 1450618
# R09 TGGC 38044
# R10 GGTC 26274
# R01 GGTT 22624
# R11 AACC 15435
# R06 CCGG 15143
# R15 AATA 13760
# R07 TTAG 13725
# R12 CCAC 13489
# R13 CGGA 7138
# R04 ACCT 3517
# BSRclip04 TGACCA 3205
# rKERclip23 CCACTC 2057
# R16 TTAA 1286
# KERclip03 TTAGGC 1012
# R14 GGCA 657
# rSBRclip30 CCGGTG 590

# %%
with dataviz.Figure("julia_out.svg", figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   "/nas3/gpratt/projects/julia/analysis/split_fastq_v2/B4P34_MeCP2_Mid_NoIndex_L008_R1.metrics",
                                                   "R01 R06".split())
    ax.set_title("B4P34_MeCP2_Mid.metrics")
# Out:
# no barcode unassigned 50694501
# R08 AATG 33990662
# R02 TTGT 19676831
# R03 CAAT 9796821
# R09 TGGC 267258
# R01 GGTT 216628
# R10 GGTC 184613
# R06 CCGG 95298
# R11 AACC 95264
# R15 AATA 93780
# R07 TTAG 92456
# R12 CCAC 90843
# R13 CGGA 58551
# BSRclip04 TGACCA 23755
# R04 ACCT 22971
# rKERclip23 CCACTC 13659
# R16 TTAA 8762
# KERclip03 TTAGGC 7085
# R14 GGCA 5039
# R05 GGCG 4450

# %%
mid_barcodes = clipseq_barcode_metrics.parse_file("/nas3/gpratt/projects/julia/data/mecp2_rip_clip/B4P34_MeCP2_Mid_NoIndex_L008_R1.fastq.gz")
high_barcodes = clipseq_barcode_metrics.parse_file("/nas3/gpratt/projects/julia/data/mecp2_rip_clip/B4P34_MeCP2_High_NoIndex_L007_R1.fastq.gz")
