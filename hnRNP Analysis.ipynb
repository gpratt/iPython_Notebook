# %%
from IPython.display import Image

# %%
Image(filename="/nas3/gpratt/projects/pipeline_analysis/combined_hnRNP/hnRNP_A1.polyATrim.adapterTrim.rmRep.sorted.bed.QCfig.png")

# %%
Image(filename="/nas3/gpratt/projects/pipeline_analysis/combined_hnRNP/hnRNP_F.polyATrim.adapterTrim.rmRep.sorted.rmDup.bed.QCfig.png")

# %%
Image(filename="/nas3/gpratt/projects/pipeline_analysis/combined_hnRNP/hnRNP_G.polyATrim.adapterTrim.rmRep.sorted.rmDup.bed.QCfig.png")

# %%
Image(filename="/nas3/gpratt/projects/pipeline_analysis/combined_hnRNP/hnRNP_M.polyATrim.adapterTrim.rmRep.sorted.rmDup.bed.QCfig.png")

# %%
Image(filename="/nas3/gpratt/projects/pipeline_analysis/combined_hnRNP/hnRNP_U.polyATrim.adapterTrim.rmRep.sorted.rmDup.bed.QCfig.png")
