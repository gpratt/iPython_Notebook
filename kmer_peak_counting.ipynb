# %%
cd /nas3/gpratt/projects/encode/fastq
# Out:
# /nas/nas0/gpratt/projects/encode/fastq

# %%
ls *.hist
# Out:
# out.hist

# %%
reads = numpy.loadtxt('out.hist')

# %%
figsize(10,10)
plot(reads[10000:,0], reads[10000:, 1], label='raw reads')
axis(ymax=200)
legend()
title("A fake metagenome (1:10)")
ylabel('N(k-mers at that abundance)')
xlabel('k-mer abundance')

# %%
kh
