# %%
import os
import glob
from collections import Counter
from itertools import groupby

from IPython.core.display import Image
from bx.bbi.bigwig_file import BigWigFile 
import gffutils
import pandas as pd
import pysam

from clipper.src import get_genomic_regions
from gscripts.general import dataviz
import HTSeq
from gscripts.riboseq import riboseq_utils
img_dir = "/nas3/gpratt/Dropbox/riboseq_team/figures/es_riboseq_rpf/"
analysis_dir = "/nas3/gpratt/projects/es_riboseq/analysis/es_riboseq_v1"
second_dir = "/nas3/gpratt/projects/es_riboseq/analysis/es_riboseq_second_round_v1/"
# Out:
# /nas/nas0/gpratt/virtualenvs/default/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))
# /nas/nas0/gpratt/virtualenvs/default/lib/python2.7/site-packages/seaborn/rcmod.py:465: UserWarning: set_color_palette is deprecated, use set_palette instead.
#   UserWarning)

# %% [markdown]
# #Code

# %%
def get_five_prime_end(interval):
    #interval.score = str(len(interval)) 
    interval.score = str(sum(map(int, interval[10].split(","))))
    if interval.strand == "+":
        interval.stop = interval.start + 1
    else:
        interval.start = interval.stop - 1
    return interval

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
half_window_width = 50
def pad(interval):
    interval.start = interval.start - half_window_width 
    interval.stop = interval.stop + half_window_width
    return interval

# %% [markdown]
# #Gather Data

# %%
features  = get_genomic_regions.GenomicFeatures( "hg19", 
                                                gffutils.FeatureDB("/nas3/gpratt/gencode/gencode.v17.annotation.gtf.db"),
                                                )
regions = features.get_feature_locations()
padded_start_codons = regions['start_codons'].each(pad).sort().saveas()
padded_stop_codons = regions['stop_codons'].each(pad).sort().saveas()

# %%
files = glob.glob(os.path.join(analysis_dir, "*.rg.bam")) + glob.glob(os.path.join(second_dir, "*.rg.bam"))
riboseq = {os.path.basename(name.split(".")[0]) : 
           pybedtools.BedTool(name) for name in files }

# %%
stop_distance_results = {}
for experiment in riboseq:
    print "starting ", experiment, 
    stop_distance_results[experiment] = riboseq_utils.get_closest(riboseq[experiment], regions['stop_codons']).T
    print "done!"
# Out:
# starting  NPC_1_CGATGT_L005_R1
# done!
# starting  SOX17_1_Ribo_NoIndex_L003
# done!
# starting  TGFP_2_Ribo_NoIndex_L002
# done!
# starting  SOX17_1_TGACCA_L005_R1
# done!
# starting  ES_2_ACTTGA_L006_R1
# done!
# starting  SOX17_2_TTAGGC_L005_R1
# done!
# starting  NPC1_Ribo_NoIndex_L005_R1
# done!
# starting  NPC_2_ATCACG_L005_R1
# done!
# starting  TGFP_1_GCCAAT_L006_R1
# done!
# starting  ES_1_GATCAG_L006_R1
# done!
# starting  ES_3_CAGATC_L006_R1
# done!
# starting  TGFP_1_Ribo_NoIndex_L001
# done!
# starting  TGFP_2_ACAGTG_L005_R1
# done!
# starting  SOX17_2_Ribo_NoIndex_L004
# done!

# %%
distance_results = {}
for experiment in riboseq:
    print "starting ", experiment, 
    distance_results[experiment] = get_closest(riboseq[experiment], regions['start_codons']).T
    print "done!"

# %% [markdown]
# #Figures

# %% [markdown]
# #Example RPF Figures for presentation
# showing working and not working datasets

# %%
filtered_starts = {key : value for key, value in distance_results.items() if key in ["NPC_1_CGATGT_L005_R1", "SOX17_2_Ribo_NoIndex_L004"]}
filtered_stops = {key : value for key, value in stop_distance_results.items() if key in ["NPC_1_CGATGT_L005_R1", "SOX17_2_Ribo_NoIndex_L004"]}

# %%
#fig = plt.Figure()
with dataviz.Figure(os.path.join(img_dir, "ribosome_occupancy_cdf_start_site_small.svg"), figsize=(10,10)) as fig:
    for count, (name, closest_start_df) in enumerate(filtered_starts.items()):
        closest_start_df_filtered = closest_start_df[(closest_start_df.dist > -30) & (closest_start_df.dist < 30) ]

        ax = fig.add_subplot(2, len(filtered_starts.items()), count + 1)
        x = ax.hist(closest_start_df_filtered.dist, bins=59)
        ax.set_title("_".join(name.split("_")[:2]) + "\nRead Start Distance\nfrom known Start Codon")
        
        ax = fig.add_subplot(2, len(filtered_starts.items()), len(filtered_starts.items()) + count + 1)
        x = ax.hist(closest_start_df_filtered.length, bins=100, range=(0,100))
        ax.set_xlim(10,40)
        ax.set_title("_".join(name.split("_")[:2])  + "\nFragment Lengths")

# %%
#fig = plt.Figure()
with dataviz.Figure(os.path.join(img_dir, "ribosome_occupancy_cdf_stop_site_small.svg"), figsize=(10,10)) as fig:
    for count, (name, closest_start_df) in enumerate(filtered_stops.items()):
        closest_start_df_filtered = closest_start_df[(closest_start_df.dist > -30) & (closest_start_df.dist < 30) ]

        ax = fig.add_subplot(2, len(filtered_stops.items()), count + 1)
        x = ax.hist(closest_start_df_filtered.dist, bins=59)
        ax.set_title("_".join(name.split("_")[:2]) + "\nRead Start Distance\nfrom known Stop Codon")
        
        ax = fig.add_subplot(2, len(filtered_stops.items()), len(filtered_stops.items()) + count + 1)
        x = ax.hist(closest_start_df_filtered.length, bins=100, range=(0,100))
        ax.set_xlim(10,40)
        ax.set_title("_".join(name.split("_")[:2])  + "\nFragment Lengths")

# %% [markdown]
# #Full figures for presentation, showing all datasets

# %%
#fig = plt.Figure()
with dataviz.Figure(os.path.join(img_dir, "ribosome_occupancy_cdf_start_site.svg"), figsize=(50,10)) as fig:
    for count, (name, closest_start_df) in enumerate(distance_results.items()):
        closest_start_df_filtered = closest_start_df[(closest_start_df.dist > -30) & (closest_start_df.dist < 30) ]

        ax = fig.add_subplot(2, len(distance_results.items()), count + 1)
        x = ax.hist(closest_start_df_filtered.dist, bins=59)
        ax.set_title("_".join(name.split("_")) + "\nRead Start Distance\nfrom known Start Codon")
        
        ax = fig.add_subplot(2, len(distance_results.items()), len(distance_results.items()) + count + 1)
        x = ax.hist(closest_start_df_filtered.length, bins=100, range=(0,100))
        ax.set_xlim(10,40)
        ax.set_title("_".join(name.split("_"))  + "\nFragment Lengths")

# %%
with dataviz.Figure(os.path.join(img_dir, "ribosome_occupancy_cdf_stop_site.svg"), figsize=(50,10)) as fig:
    for count, (name, closest_stop_df) in enumerate(stop_distance_results.items()):
        closest_stop_df_filtered = closest_stop_df[(closest_stop_df.dist > -30) & (closest_stop_df.dist < 30) ]

        ax = fig.add_subplot(2, len(stop_distance_results.items()), count + 1)
        x = ax.hist(closest_stop_df_filtered.dist, bins=59)
        ax.set_title("_".join(name.split("_")[:2]) + "\nRead Start Distance\nfrom known Stop Codon")
        
        ax = fig.add_subplot(2, len(stop_distance_results.items()), len(stop_distance_results.items()) + 1+ count)
        x = ax.hist(closest_stop_df_filtered.length, bins=100, range=(0,100))
        ax.set_xlim(10,40)
        ax.set_title("_".join(name.split("_")[:2]) + "\nFragment Lengths")
    
    fig.tight_layout()

# %%
fig = Figure() 
ax = fig.add_subplot(2,1,1)
x = ax.hist(closest_start_df_filtered.dist, bins=30)
ax.set_title("Read Start Distance\nfrom known Start Codon")

ax = fig.add_subplot(2,1,2)
x = ax.hist(closest_start_df_filtered.length, bins=40)
ax.set_title("Fragment Lengths")
ax = fig.add_subplot(2,1,1)
x = ax.hist(closest_start_df_filtered.dist, bins=30)
ax.set_title("Read Start Distance\nfrom known Start Codon")

ax = fig.add_subplot(2,1,2)
x = ax.hist(closest_start_df_filtered.length, bins=40)
ax.set_title("Fragment Lengths")

# %% [markdown]
# General distributions, most reads that map near start codons are between 25 and 31 bp long, and they mostly map 14 and 11bp upstream of annotated start codons

# %%
len(closest_start_df_filterd[closest_start_df_filterd.length.isin(range(25, 31))]) / float(len(closest_start_df_filterd.length))
# Out:
# 0.860593039556287

# %% [markdown]
# In fact 86% of reads are beween 25 and 31bp when near start codons

# %% [markdown]
# Do Distributions Change with Fragment Length?
# ---------------------------------------

# %%
smallest = 25
largest = 40
with Figure(os.path.join(img_dir, "ribosome_occupancy_start_site_size_split.svg"), figsize=(10,20)) as fig:
    for x, fragment_length in enumerate(range(smallest, largest)):
        ax = fig.add_subplot(len(range(smallest, largest)),1,x + 1)    
        ax.hist(closest_start_df_filterd[closest_start_df_filterd.length == fragment_length].dist, bins=30)
        ax.set_title("Fragment Length " + str(fragment_length))
        print Counter(closest_start_df_filterd[closest_start_df_filterd.length == fragment_length].dist).most_common(2)
# Out:
# [(-11, 1035), (-14, 787)]
# [(-11, 1741), (-14, 986)]
# [(-9, 1876), (-12, 1491)]
# [(-11, 3336), (-14, 3313)]
# [(-14, 11588), (-11, 8431)]
# [(-14, 4185), (-11, 3814)]
# [(-14, 1952), (-11, 1353)]
# [(-14, 602), (-15, 431)]
# [(-15, 257), (-14, 256)]
# [(-14, 278), (-11, 212)]
# [(-14, 191), (-15, 152)]
# [(-14, 72), (-15, 64)]
# [(-14, 83), (-11, 36)]
# [(-14, 28), (-15, 25)]
# [(-11, 14), (-14, 12)]

# %% [markdown]
# No, no they don't

# %%
stop_codon_overlapping_reads = riboseq["NPC_2_ATCACG_L005_R1"].intersect(padded_stop_codons, u=True, s=True, sorted=True).saveas()
stop_codon_reads_bed = stop_codon_overlapping_reads.bam_to_bed(bed12=True).saveas()
stop_codon_true_starts = stop_codon_reads_bed.each(get_five_prime_end).saveas()
closest_stop_codons = stop_codon_true_starts.closest(regions['stop_codons'], D="b", s=True).saveas()
closest_stop_df = pd.DataFrame({x.name : {"dist" : int(x[-1]), "length" : int(x.score)} for x in closest_stop_codons}).T
closest_stop_df_filterd = closest_stop_df[(closest_stop_df.dist > -30) & (closest_stop_df.dist < 0) ]

# %%
with Figure(os.path.join(img_dir, "ribosome_occupancy_stop_site.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(2,1,1)
    x = ax.hist(closest_stop_df_filterd.dist, bins=30)
    ax.set_title("Read Start Distance\nfrom known Stop Codon")
    
    ax = fig.add_subplot(2,1,2)
    x = ax.hist(closest_stop_df_filterd.length, bins=40)
    ax.set_title("Fragment Lengths")

# %%
Counter(closest_stop_df_filterd.dist)
# Out:
# Counter({-23: 8605, -26: 7715, -20: 6911, -29: 6608, -17: 4638, -27: 3328, -22: 2835, -24: 2735, -21: 2735, -19: 2656, -16: 2656, -25: 2370, -28: 2323, -9: 2233, -12: 2226, -18: 2224, -10: 2063, -13: 2033, -4: 1979, -15: 1958, -14: 1908, -3: 1871, -7: 1745, -6: 1712, -1: 1557, -11: 1044, -8: 672, -2: 671, -5: 561})

# %%
counts = [count for dist, count in sorted([(dist, count) for dist, count in Counter(closest_stop_df_filterd.dist).items()])]

# %%
smallest = 25
largest = 40
with Figure(os.path.join(img_dir, "ribosome_occupancy_stop_site_size_split.svg"), figsize=(10,20)) as fig:
    for x, fragment_length in enumerate(range(smallest, largest)):
        ax = fig.add_subplot(len(range(smallest, largest)),1,x + 1)    
        ax.hist(closest_stop_df_filterd[closest_stop_df_filterd.length == fragment_length].dist, bins=30)
        ax.set_title("Fragment Length " + str(fragment_length))
        print Counter(closest_stop_df_filterd[closest_stop_df_filterd.length == fragment_length].dist).most_common(2)
# Out:
# [(-16, 361), (-23, 305)]
# [(-29, 417), (-20, 410)]
# [(-23, 605), (-26, 458)]
# [(-23, 1184), (-20, 1001)]
# [(-23, 2649), (-20, 2384)]
# [(-26, 2565), (-29, 2104)]
# [(-23, 378), (-27, 319)]
# [(-23, 50), (-29, 45)]
# [(-29, 31), (-17, 23)]
# [(-17, 12), (-3, 12)]
# [(-4, 19), (-24, 13)]
# [(-20, 10), (-16, 9)]
# [(-18, 11), (-16, 6)]
# [(-29, 3), (-24, 3)]
# [(-22, 2), (-19, 2)]

# %% [markdown]
# #Real Examples

# %%
Image("/nas3/gpratt/Dropbox/riboseq_team/browser_shots/vim_stop.png")

# %%
Image("/nas3/gpratt/Dropbox/riboseq_team/browser_shots/ENSG00000123416.11_near_end.png")

# %%
Image("/nas3/gpratt/Dropbox/riboseq_team/browser_shots/ENSG00000197238.3_end.png")

# %% [markdown]
# Things to do:
#
# + Filter to just reads between 25-31 and see where they map
# + Filter to full length reads and see whats going on with them
# + Come up with a metric of perodicty,

# %%
samtools view NPC_2_ATCACG_L005_R1.fastq.gz.polyATrim.adapterTrim.rmRep.sorted.rg.bam | awk '{if(25 < length($10) && length($10) <= 31)  print $0}' > ../ad-hoc/NPC_2_proper.sam
samtools view NPC_2_ATCACG_L005_R1.fastq.gz.polyATrim.adapterTrim.rmRep.sorted.rg.bam | awk '{if(length($10) == 50)  print $0}' > ../ad-hoc/NPC_2_long.samsamtools view NPC_2_ATCACG_L005_R1.fastq.gz.polyATrim.adapterTrim.rmRep.sorted.rg.bam | awk '{if(25 < length($10) && length($10) <= 31)  print $0}' > ../ad-hoc/NPC_2_proper.sam
samtools view NPC_2_ATCACG_L005_R1.fastq.gz.polyATrim.adapterTrim.rmRep.sorted.rg.bam | awk '{if(length($10) == 50)  print $0}' > ../ad-hoc/NPC_2_long.sam
