# %%
from collections import defaultdict
import glob
import os

import pandas as pd
import matplotlib as mpl
import statsmodels.api as sm
import scipy.stats
import gffutils
from IPython.core.display import HTML
import seaborn
import numpy as np

from gscripts.general.dataviz import plot_cdf
from gscripts.general import dataviz
from gscripts.general.dataviz import PCA_viz

img_dir = "/nas3/gpratt/Dropbox/riboseq_team/figures/es_riboseq_translational_efficency/"

# %% [markdown]
# #Code

# %%
#go = GO()
def geneNames(x):
    try:
        return gene_name_dict[x]
    except:
        return x

# %%
def plot_cdf(cdf_list, **kwargs):
    cdf = sm.distributions.ECDF(cdf_list)
    cdf_linspace = np.linspace(min(cdf_list), max(cdf_list))
    if kwargs['ax'] is not None:
        ax = kwargs['ax']
        del kwargs['ax']
        ax.plot(cdf_linspace, cdf(cdf_linspace), **kwargs)
        ax.set_ylim((0,1))
    else:
        plot(cdf_linspace, cdf(cdf_linspace), **kwargs)

# %%
#remove ES_1 which is an internal control
def renamer(x):
    if "ES" in x:
        x = x.split("_")
        x[1] = int(x[1]) - 1
        x = "_".join(map(str, x))
    return x

# %% [markdown]
# #Setup data frame

# %%
human_db = "/nas3/gpratt/gencode/gencode.v17.annotation.gtf.db"
db = gffutils.FeatureDB(human_db)
genes = db.features_of_type('gene')

gene_type_dict = {}
gene_name_dict = {}
for gene in genes:
    try:
        gene_type_dict[gene.attributes['gene_id'][0]] = gene.attributes['gene_type'][0]
    except KeyError:
        pass
    
    try:
        gene_name_dict[gene.attributes['gene_id'][0]] = gene.attributes['gene_name'][0]
    except KeyError:
        pass

# %%
es_color, npc_color, sox17_color, mesoderm_color, c1 = map(mpl.colors.rgb2hex, seaborn.color_palette('Set1', 5))

# %%
rnaseq_files
# Out:
# []

# %%
riboseq_files = glob.glob("/nas3/gpratt/projects/es_riboseq/analysis/es_riboseq_v3/*.rpkm")
rnaseq_files = glob.glob("/nas3/gpratt/projects/es_riboseq/analysis/es_rnaseq_v3/*.rpkm")

riboseq_dict = {"_".join(os.path.basename(fn).split("_")[:2]).replace("-", "") : pd.read_csv(fn, sep="\t", index_col=0) for fn in riboseq_files}
rnaseq  = pd.concat({"_".join(os.path.basename(fn).split("_")[:2]).replace("-", "") : pd.read_csv(fn, sep="\t", index_col=0) for fn in rnaseq_files})

#riboseq_r2_files = glob.glob("/nas3/gpratt/projects/es_riboseq/analysis/es_riboseq_second_round_v1//*.rpkm")
#riboseq_r2_dict  = {"_".join(os.path.basename(fn).split("_")[:2]) + "_r2": pd.read_csv(fn, sep="\t", index_col=0) for fn in riboseq_r2_files}

#riboseq_dict.update(riboseq_r2_dict)
riboseq = pd.concat(riboseq_dict)

riboseq = riboseq.drop("ES_1").rename(renamer)
#riboseq = riboseq.rename({"NPC1_Ribo" : "NPC_1"})

riboseq["riboseq"] = riboseq.RPKM
riboseq['rnaseq'] = rnaseq.RPKM
riboseq['te'] = np.log2(riboseq.riboseq / riboseq.rnaseq)
riboseq = riboseq.drop(["RPKM", "flag"], axis=1)

gene_names = []
gene_types = []
for gencode_id in riboseq.index.get_level_values(1):
    try:
        gene_names.append(gene_name_dict[gencode_id])
        gene_types.append(gene_type_dict[gencode_id])
    except KeyError:
        gene_names.append("error")
        gene_types.append("error")
        
        
riboseq["gene_name"] = gene_names
riboseq["gene_type"] = gene_types
riboseq["logged_riboseq"] = riboseq.riboseq.apply(np.log2)
riboseq["logged_rnaseq"] = riboseq.rnaseq.apply(np.log2)
riboseq_logged = riboseq[(riboseq.logged_riboseq != np.NINF) & (riboseq.logged_rnaseq != np.NINF) ]

# %%
riboseq.riboseq.unstack().T.to_csv("/nas3/gpratt/Dropbox/riboseq_team/riboseq_matrix.csv")
riboseq.rnaseq.unstack().T.to_csv("/nas3/gpratt/Dropbox/riboseq_team/rnaseq_matrix.csv")

# %%
descriptors = defaultdict(dict)
for item in set(riboseq.index.get_level_values(0)):
    if "ES" in item:
        descriptors[item] = {"cell_type" : "ES", "cell_color" : es_color}
    if "NPC" in item:
        descriptors[item] = {"cell_type" : "NPC", "cell_color" : npc_color}
        
    if "SOX17" in item:
        descriptors[item] = {"cell_type" : "SOX17", "cell_color" : sox17_color}
        
    if "TGFP" in item:
        descriptors[item] = {"cell_type" : "TGFP", "cell_color" : mesoderm_color}
        
descriptors = pd.DataFrame(descriptors).T

# %% [markdown]
# #How do the Riboseq technical Replicates Compare?

# %%
ordered_riboseq = riboseq[riboseq.logged_riboseq  != np.NINF].logged_riboseq.unstack().T.dropna()
ordered_rnaseq = riboseq[riboseq.logged_rnaseq  != np.NINF].logged_rnaseq.unstack().T.dropna()

# %%
experiment = "SOX17_1"
experiment_r2 = "SOX17_1_r2"

with dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    x = dataviz.loglog_hist2d(ordered_riboseq.NPC_1 , ordered_riboseq.NPC1_Ribo_r2, ax=ax)
    #x = ax.hist2d(ordered_riboseq.NPC_1 , ordered_riboseq.NPC1_Ribo_r2,
    #              bins=175, norm=mpl.colors.Normalize(), cmin=1, vmin=0, vmax=45)
    print scipy.stats.linregress(ordered_riboseq.NPC_1, ordered_riboseq.NPC1_Ribo_r2)[2] ** 2
# Out:
# 0.591431271283
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/font_manager.py:1240: UserWarning: findfont: Font family ['Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
experiment = "SOX17_1"
experiment_r2 = "SOX17_1_r2"

with dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)

    x = dataviz.loglog_hist2d(ordered_riboseq.SOX17_1 , ordered_riboseq.SOX17_1_r2, ax=ax)
    #x = ax.hist2d(ordered_riboseq.SOX17_1 , ordered_riboseq.SOX17_1_r2,
    #              bins=175, norm=Normalize(), cmin=1, vmin=0, vmax=45)
    print scipy.stats.linregress(ordered_riboseq.SOX17_1, ordered_riboseq.SOX17_1_r2)[2] ** 2
# Out:
# 0.769860812012

# %%
experiment = "SOX17_1"
experiment_r2 = "SOX17_1_r2"

with  dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)

    riboseq.logged_riboseq
    dataviz.loglog_hist2d(ordered_riboseq.SOX17_2 , ordered_riboseq.SOX17_2_r2, ax=ax)
    #x = ax.hist2d(ordered_riboseq.SOX17_2 , ordered_riboseq.SOX17_2_r2,
    #              bins=50, norm=Normalize(), cmin=1, vmin=0, vmax=45)
    print scipy.stats.linregress(ordered_riboseq.SOX17_2, ordered_riboseq.SOX17_2_r2)[2] ** 2
# Out:
# 0.631485133436

# %% [markdown]
# Low R2 but this is fine because original datasets had less than a million mapped reads.  Assumption is with more technical reps it would be better

# %%
experiment = "SOX17_1"
experiment_r2 = "SOX17_1_r2"

with dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)

    dataviz.loglog_hist2d(ordered_riboseq.SOX17_1_r2 , ordered_riboseq.SOX17_2_r2, ax=ax)
    print scipy.stats.linregress(riboseq.xs("SOX17_1_r2").riboseq, riboseq.xs("SOX17_2_r2").riboseq)[2] ** 2
# Out:
# 0.865612215307

# %%
experiment = "SOX17_1"
experiment_r2 = "SOX17_1_r2"

with dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)

    riboseq.logged_riboseq
    _, _, _, axImage = dataviz.loglog_hist2d(ordered_riboseq.SOX17_1_r2 , ordered_riboseq.SOX17_2_r2, ax=ax)

    print scipy.stats.linregress(riboseq.xs("SOX17_1_r2").riboseq, riboseq.xs("SOX17_2_r2").riboseq)[2] ** 2
    fig.colorbar(axImage, ax=ax, use_gridspec=False)
# Out:
# 0.865612215307
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/figure.py:1621: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# R2 for uncorrected Sox17 1 and SOX17 2 with proper read numbers is good

# %% [markdown]
# #Ribosome Occupancy Descriptive Stats

# %%
with dataviz.Figure(os.path.join(img_dir, "ribosome_occupancy_cdf.svg"), figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    for name in sorted(set(riboseq.index.get_level_values(0))):
        if all(np.isnan(riboseq.ix[name].te)):
            continue
        plot_cdf(riboseq.ix[name].te[~np.isinf(riboseq.ix[name].te)].dropna(), ax=ax, linewidth=4, alpha=.75, label=name)
        ax.set_xlabel("log2 Ribosome Occupancy")
        ax.set_ylabel("Cumulative Fraction")
        ax.set_title("Ribosome Occupancy")
        ax.legend()

# %% [markdown]
# Currently no major reproducable TE shifts between datasets, but will hopefully change as we get deeper sequencing

# %%
filtered_riboseq = riboseq[~np.isinf(riboseq.te)].dropna()
filtered_riboseq.sort('te', ascending=False)
filtered_riboseq.to_csv("/nas3/gpratt/Dropbox/riboseq_team/NPC_TE.csv")

# %%
x = 0
experiment_num = 8
with dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(20,10)) as fig:
    experiments = sorted(set(riboseq.index.get_level_values(0)))
    for experiment in experiments:
        if all(np.isnan(riboseq.ix[experiment].riboseq)) or all(np.isnan(riboseq.ix[experiment].rnaseq)):
            continue
        x += 1
        ax = fig.add_subplot(2, experiment_num / 2, x)    
        tmp = pd.DataFrame()
        tmp["riboseq"] = riboseq.ix[experiment].logged_riboseq
        tmp["rnaseq"] = riboseq.ix[experiment].logged_rnaseq
        tmp[np.isinf(tmp)] = np.nan 
        tmp = tmp.dropna()
        
        _, _, _, axImage = ax.hist2d(tmp.rnaseq, tmp.riboseq,
                      bins=175, norm=mpl.colors.Normalize(), cmin=1, vmin=0, vmax=45)
        ax.set_ylabel("Ribo-seq")
        ax.set_xlabel("RNA-seq")
        ax.set_title(experiment)
        fig.colorbar(axImage, ax=ax, use_gridspec=True)

# %% [markdown]
# It looks like there is an enriched population of genes have high ribosome occupancy, but same expression, those genes might be interesting...

# %%
with dataviz.Figure(os.path.join(img_dir, "rnaseq_vs_riboseq_heatmap.svg"), figsize=(6,6)) as fig:
    experiments = sorted(set(riboseq.index.get_level_values(0)))
    for x, experiment in enumerate(experiments):
        ax = fig.add_subplot(2,len(experiments) / 2, x + 1)
        x = ax.hist2d(riboseq_logged.ix[experiment].logged_riboseq, 
                      riboseq_logged.ix[experiment].logged_rnaseq, 
                      bins=175, 
                      norm=mpl.colors.Normalize(), cmin=1, vmin=0, vmax=45)
        ax.set_xlabel("Ribo-seq", fontsize=18)
        ax.set_ylabel("RNA-seq", fontsize=18)
        ax.set_title(experiment + "Riboseq RPKM vs RNAseq RPKM")
        break

# %% [markdown]
# #Are Markers Expressed in Cell Types we say they are?

# %%
markers = pd.read_csv('/nas3/gpratt/projects/es_riboseq/gene_list_for_linages.csv')

# %% [markdown]
# Stem Cell markers appear to be expressed and present in stem cells

# %% [markdown]
# #RNA-seq QC / Filtered Markers

# %%
cv_prototype = riboseq.rnaseq.unstack().T
cv_prototype = cv_prototype.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)
cv_prototype = cv_prototype[~cv_prototype.apply(lambda x: any(x == 0), axis=1)]

heatmap_filtered = cv_prototype.ix[(cv_prototype.std(axis=1) / cv_prototype.mean(axis=1)) > 1]

gene_panel_names = [gene_name_dict[gene_id] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,20), label_rows=gene_panel_names, cmap=mpl.cm.Greys)

# %%
foo = markers.unstack()
rnaseq_expression = riboseq[riboseq.gene_name.isin(markers.unstack())].rnaseq.unstack().T
heatmap_filtered =  rnaseq_expression.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,20), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3393e2012319> in <module>()
# ----> 1 foo = markers.unstack()
#       2 rnaseq_expression = riboseq[riboseq.gene_name.isin(markers.unstack())].rnaseq.unstack().T
#       3 heatmap_filtered =  rnaseq_expression.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)
#       4
#       5 gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
#
# NameError: name 'markers' is not defined

# %% [markdown]
# ES Marker Clustering

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['ES Markers'].dropna())].rnaseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 166.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 10)

# %% [markdown]
# Mesoderm Markers

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Mesoderm'].dropna())].rnaseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-196ee6a755d2> in <module>()
# ----> 1 expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Mesoderm'].dropna())].rnaseq.unstack().T
#       2 heatmap_filtered =  expression_heatmap.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)
#       3
#       4 gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
#       5 _ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
#
# NameError: name 'markers' is not defined

# %% [markdown]
# Ectoderm Markers

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Ectoderm'].dropna())].rnaseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f57a4d293d1f> in <module>()
# ----> 1 expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Ectoderm'].dropna())].rnaseq.unstack().T
#       2 heatmap_filtered =  expression_heatmap.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)
#       3
#       4 gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
#       5 _ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
#
# NameError: name 'markers' is not defined

# %% [markdown]
# Endoderm Markers

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Endoderm'].dropna())].rnaseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC1_Ribo_r2", "SOX17_1_r2", "SOX17_2_r2", "TGFP_1_r2", "TGFP_2_r2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 1490.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 10)

# %%
renamed_heatmap = heatmap_filtered.T.rename_axis(geneNames, 1)
pca = PCA_viz((renamed_heatmap + .9).apply(log10), whiten=True) 
pca(colors_dict = descriptors.cell_color)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-61c4e2427bf4> in <module>()
# ----> 1 renamed_heatmap = heatmap_filtered.T.rename_axis(geneNames, 1)
#       2 pca = PCA_viz((renamed_heatmap + .9).apply(log10), whiten=True)
#       3 pca(colors_dict = descriptors.cell_color)
#
# NameError: name 'heatmap_filtered' is not defined

# %% [markdown]
# #Ribo-seq Filtered Markers

# %%
cv_prototype = riboseq.riboseq.unstack().T
cv_prototype = cv_prototype.drop(["NPC_1", "SOX17_1", "SOX17_2", "TGFP_1", "TGFP_2"],axis=1)
cv_prototype = cv_prototype[~cv_prototype.apply(lambda x: any(x == 0), axis=1)]

heatmap_filtered = cv_prototype.ix[(cv_prototype.std(axis=1) / cv_prototype.mean(axis=1)) > 1]

gene_panel_names = [gene_name_dict[gene_id] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,20), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 430591.0
# vmin 1e-10
# width_ratios
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e33a6c21eb60> in <module>()
#       6
#       7 gene_panel_names = [gene_name_dict[gene_id] for gene_id in heatmap_filtered.index]
# ----> 8 _ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,20), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/gscripts-0.1.6-py2.7.egg/gscripts/general/dataviz.pyc in heatmap(df, title, colorbar_label, col_side_colors, row_side_colors, color_scale, cmap, row_linkage_method, col_linkage_method, figsize, label_rows, label_cols, vmin, vmax, xlabel_fontsize, ylabel_fontsize, cluster_cols, cluster_rows, plot_df)
#     388         yticklabels = [yticklabels[i] for i in row_dendrogram_distances[
#     389             'leaves']]
# --> 390         heatmap_ax.set_yticks(np.arange(df.shape[0]) + 0.5)
#     391         heatmap_ax.yaxis.set_ticks_position('right')
#     392         heatmap_ax.set_yticklabels(yticklabels, fontsize=ylabel_fontsize)
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/axes/_base.pyc in set_yticks(self, ticks, minor)
#    2837             Sets the minor ticks if *True*
#    2838         """
# -> 2839         return self.yaxis.set_ticks(ticks, minor=minor)
#    2840
#    2841     def get_ymajorticklabels(self):
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/axis.pyc in set_ticks(self, ticks, minor)
#    1580         else:
#    1581             self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1582             return self.get_major_ticks(len(ticks))
#    1583
#    1584     def _update_label_position(self, bboxes, bboxes2):
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1288             # update the new tick label properties from the old
#    1289             for i in range(numticks - len(self.majorTicks)):
# -> 1290                 tick = self._get_tick(major=True)
#    1291                 self.majorTicks.append(tick)
#    1292
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/axis.pyc in _get_tick(self, major)
#    1951         else:
#    1952             tick_kw = self._minor_tick_kw
# -> 1953         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    1954
#    1955     def _get_label(self):
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.tick1line = self._get_tick1line()
#     149         self.tick2line = self._get_tick2line()
# --> 150         self.gridline = self._get_gridline()
#     151
#     152         self.label1 = self._get_text1()
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/axis.pyc in _get_gridline(self)
#     565                     linewidth=rcParams['grid.linewidth'],
#     566                     alpha=rcParams['grid.alpha'],
# --> 567                     markersize=0
#     568                     )
#     569
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     223         self.set_markeredgecolor(markeredgecolor)
#     224         self.set_markeredgewidth(markeredgewidth)
# --> 225         self.set_fillstyle(fillstyle)
#     226
#     227         self.verticalOffset = None
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/lines.pyc in set_fillstyle(self, fs)
#     339         ACCEPTS: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#     340         """
# --> 341         self._marker.set_fillstyle(fs)
#     342
#     343     def set_markevery(self, every):
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/markers.pyc in set_fillstyle(self, fillstyle)
#     214                              % ' '.join(self.fillstyles))
#     215         self._fillstyle = fillstyle
# --> 216         self._recache()
#     217
#     218     def get_joinstyle(self):
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/markers.pyc in _recache(self)
#     180     def _recache(self):
#     181         self._path = Path(np.empty((0, 2)))
# --> 182         self._transform = IdentityTransform()
#     183         self._alt_path = None
#     184         self._alt_transform = None
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/transforms.pyc in __init__(self, *args, **kwargs)
#    1548
#    1549     def __init__(self, *args, **kwargs):
# -> 1550         Transform.__init__(self, *args, **kwargs)
#    1551         self._inverted = None
#    1552
#
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/transforms.pyc in __init__(self, shorthand_name)
#      95         # parents are deleted, references from the children won't keep
#      96         # them alive.
# ---> 97         self._parents = WeakValueDictionary()
#      98
#      99         # TransformNodes start out as invalid until their values are
#
# /nas3/yeolab/Software/lib/python2.7/weakref.pyc in __init__(self, *args, **kw)
#      46
#      47     def __init__(self, *args, **kw):
# ---> 48         def remove(wr, selfref=ref(self)):
#      49             self = selfref()
#      50             if self is not None:
#
# KeyboardInterrupt:
#  [0.25, 1]
# height_ratios [0.25, 1]
# (10, 20)
# KeyboardInterrupt

# %% [markdown]
# What is the Coefficent of variation, how is it distributed?

# %%
figsize(6,6)
x = hist((cv_prototype.std(axis=1) / cv_prototype.mean(axis=1)))

# %%
heatmap_filtered = cv_prototype.ix[(cv_prototype.std(axis=1) / cv_prototype.mean(axis=1)) > 1]

gene_panel_names = [gene_name_dict[gene_id] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,20), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 430591.0
# vmin 1e-10
# width_ratios
#  [0.25, 1]
# height_ratios [0.25, 1]
# (10, 20)

# %%
foo = markers.unstack()
riboseq_expression = riboseq[riboseq.gene_name.isin(markers.unstack())].riboseq.unstack()
heatmap_filtered =  expression_heatmap.drop(["NPC_1", "SOX17_1", "SOX17_2", "TGFP_1", "TGFP_2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,20), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 3290.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 20)

# %% [markdown]
# Trying individual markers and heatmaps independently

# %% [markdown]
# ES Markers

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['ES Markers'].dropna())].riboseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC_1", "SOX17_1", "SOX17_2", "TGFP_1", "TGFP_2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 170.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 10)

# %% [markdown]
# Mesoderm Markers

# %% [markdown]
# Check 3 base pair perodicity in each sample

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Mesoderm'].dropna())].riboseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC_1", "SOX17_1", "SOX17_2", "TGFP_1", "TGFP_2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 1772.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 10)

# %% [markdown]
# Ectoderm Markers

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Ectoderm'].dropna())].riboseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC_1", "SOX17_1", "SOX17_2", "TGFP_1", "TGFP_2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 88.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 10)

# %% [markdown]
# Endoderm Markers

# %%
expression_heatmap = riboseq[riboseq.gene_name.isin(markers['Endoderm'].dropna())].riboseq.unstack().T
heatmap_filtered =  expression_heatmap.drop(["NPC_1", "SOX17_1", "SOX17_2", "TGFP_1", "TGFP_2"],axis=1)

gene_panel_names = [gene_name_dict[gene_id] + " " + foo[foo.isin([gene_name_dict[gene_id]])].unstack().index[0] for gene_id in heatmap_filtered.index]
_ = dataviz.heatmap(heatmap_filtered, plot_df=heatmap_filtered, color_scale='log', figsize=(10,10), label_rows=gene_panel_names, cmap=mpl.cm.Greys)
# Out:
# vmax 3290.0
# vmin 1e-10
# width_ratios [0.25, 1]
# height_ratios [0.25, 1]
# (10, 10)

# %%
renamed_heatmap = heatmap_filtered.T.rename_axis(geneNames, 1)
pca = PCA_viz((renamed_heatmap + .9).apply(log10), whiten=True) 
pca(colors_dict = descriptors.cell_color)
# Out:
# PCA_viz(df=None)

# %% [markdown]
# PCA also doesn't provide sane results with Riboseq, need to dig into if I'm doing PCA right here, lots of abstractions I don't understand.

# %% [markdown]
# #Ectoderm Markers

# %%
HTML(riboseq.ix[['NPC_1', "NPC_2", "NPC1_Ribo_r2"]][riboseq.ix[["NPC_1", "NPC_2", "NPC1_Ribo_r2"]].gene_name.isin(markers['Ectoderm'].dropna())].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>riboseq</th>
#       <th>rnaseq</th>
#       <th>te</th>
#       <th>gene_name</th>
#       <th>gene_type</th>
#       <th>logged_riboseq</th>
#       <th>logged_rnaseq</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>gene</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="10" valign="top">NPC1_Ribo_r2</th>
#       <th>ENSG00000181449.2</th>
#       <td> 64.227193</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    SOX2</td>
#       <td> protein_coding</td>
#       <td> 6.005112</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000182968.3</th>
#       <td>  3.393302</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    SOX1</td>
#       <td> protein_coding</td>
#       <td> 1.762690</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000115507.5</th>
#       <td>  0.124981</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    OTX1</td>
#       <td> protein_coding</td>
#       <td>-3.000214</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000178403.3</th>
#       <td>  0.029578</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td> NEUROG2</td>
#       <td> protein_coding</td>
#       <td>-5.079320</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000165588.12</th>
#       <td>  5.354143</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    OTX2</td>
#       <td> protein_coding</td>
#       <td> 2.420656</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163508.8</th>
#       <td>  0.018497</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>   EOMES</td>
#       <td> protein_coding</td>
#       <td>-5.756602</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000136535.10</th>
#       <td>  0.005634</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    TBR1</td>
#       <td> protein_coding</td>
#       <td>-7.471637</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000122859.4</th>
#       <td>  0.019676</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td> NEUROG3</td>
#       <td> protein_coding</td>
#       <td>-5.667436</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000007372.15</th>
#       <td>  0.018728</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    PAX6</td>
#       <td> protein_coding</td>
#       <td>-5.738649</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000180828.1</th>
#       <td>  0.024088</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td> BHLHE22</td>
#       <td> protein_coding</td>
#       <td>-5.375555</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th rowspan="10" valign="top">NPC_1</th>
#       <th>ENSG00000181449.2</th>
#       <td> 54.780964</td>
#       <td> 46.518162</td>
#       <td> 0.235881</td>
#       <td>    SOX2</td>
#       <td> protein_coding</td>
#       <td> 5.775603</td>
#       <td> 5.539722</td>
#     </tr>
#     <tr>
#       <th>ENSG00000182968.3</th>
#       <td>  2.786622</td>
#       <td>  1.461893</td>
#       <td> 0.930680</td>
#       <td>    SOX1</td>
#       <td> protein_coding</td>
#       <td> 1.478517</td>
#       <td> 0.547837</td>
#     </tr>
#     <tr>
#       <th>ENSG00000115507.5</th>
#       <td>  0.000000</td>
#       <td>  0.000000</td>
#       <td>      NaN</td>
#       <td>    OTX1</td>
#       <td> protein_coding</td>
#       <td>     -inf</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000178403.3</th>
#       <td>  0.000000</td>
#       <td>  0.099962</td>
#       <td>     -inf</td>
#       <td> NEUROG2</td>
#       <td> protein_coding</td>
#       <td>     -inf</td>
#       <td>-3.322479</td>
#     </tr>
#     <tr>
#       <th>ENSG00000165588.12</th>
#       <td>  0.000000</td>
#       <td>  0.013237</td>
#       <td>     -inf</td>
#       <td>    OTX2</td>
#       <td> protein_coding</td>
#       <td>     -inf</td>
#       <td>-6.239227</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163508.8</th>
#       <td>  0.000000</td>
#       <td>  0.008930</td>
#       <td>     -inf</td>
#       <td>   EOMES</td>
#       <td> protein_coding</td>
#       <td>     -inf</td>
#       <td>-6.807116</td>
#     </tr>
#     <tr>
#       <th>ENSG00000136535.10</th>
#       <td>  0.715515</td>
#       <td>  0.013600</td>
#       <td> 5.717276</td>
#       <td>    TBR1</td>
#       <td> protein_coding</td>
#       <td>-0.482947</td>
#       <td>-6.200223</td>
#     </tr>
#     <tr>
#       <th>ENSG00000122859.4</th>
#       <td>  0.000000</td>
#       <td>  0.023748</td>
#       <td>     -inf</td>
#       <td> NEUROG3</td>
#       <td> protein_coding</td>
#       <td>     -inf</td>
#       <td>-5.396022</td>
#     </tr>
#     <tr>
#       <th>ENSG00000007372.15</th>
#       <td>  0.755074</td>
#       <td>  1.172469</td>
#       <td>-0.634860</td>
#       <td>    PAX6</td>
#       <td> protein_coding</td>
#       <td>-0.405310</td>
#       <td> 0.229550</td>
#     </tr>
#     <tr>
#       <th>ENSG00000180828.1</th>
#       <td>  0.679813</td>
#       <td>  0.009691</td>
#       <td> 6.132314</td>
#       <td> BHLHE22</td>
#       <td> protein_coding</td>
#       <td>-0.556790</td>
#       <td>-6.689103</td>
#     </tr>
#     <tr>
#       <th rowspan="10" valign="top">NPC_2</th>
#       <th>ENSG00000181449.2</th>
#       <td> 41.749623</td>
#       <td> 46.307137</td>
#       <td>-0.149471</td>
#       <td>    SOX2</td>
#       <td> protein_coding</td>
#       <td> 5.383691</td>
#       <td> 5.533163</td>
#     </tr>
#     <tr>
#       <th>ENSG00000182968.3</th>
#       <td>  2.090381</td>
#       <td>  1.459430</td>
#       <td> 0.518361</td>
#       <td>    SOX1</td>
#       <td> protein_coding</td>
#       <td> 1.063766</td>
#       <td> 0.545405</td>
#     </tr>
#     <tr>
#       <th>ENSG00000115507.5</th>
#       <td>  0.009459</td>
#       <td>  0.000000</td>
#       <td>      inf</td>
#       <td>    OTX1</td>
#       <td> protein_coding</td>
#       <td>-6.724164</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000178403.3</th>
#       <td>  0.139896</td>
#       <td>  0.046020</td>
#       <td> 1.604017</td>
#       <td> NEUROG2</td>
#       <td> protein_coding</td>
#       <td>-2.837577</td>
#       <td>-4.441594</td>
#     </tr>
#     <tr>
#       <th>ENSG00000165588.12</th>
#       <td>  0.074103</td>
#       <td>  0.000000</td>
#       <td>      inf</td>
#       <td>    OTX2</td>
#       <td> protein_coding</td>
#       <td>-3.754326</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163508.8</th>
#       <td>  0.049990</td>
#       <td>  0.026647</td>
#       <td> 0.907693</td>
#       <td>   EOMES</td>
#       <td> protein_coding</td>
#       <td>-4.322215</td>
#       <td>-5.229908</td>
#     </tr>
#     <tr>
#       <th>ENSG00000136535.10</th>
#       <td>  0.052342</td>
#       <td>  0.000000</td>
#       <td>      inf</td>
#       <td>    TBR1</td>
#       <td> protein_coding</td>
#       <td>-4.255890</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000122859.4</th>
#       <td>  0.000000</td>
#       <td>  0.000000</td>
#       <td>      NaN</td>
#       <td> NEUROG3</td>
#       <td> protein_coding</td>
#       <td>     -inf</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000007372.15</th>
#       <td>  0.778495</td>
#       <td>  1.075516</td>
#       <td>-0.466269</td>
#       <td>    PAX6</td>
#       <td> protein_coding</td>
#       <td>-0.361240</td>
#       <td> 0.105029</td>
#     </tr>
#     <tr>
#       <th>ENSG00000180828.1</th>
#       <td>  1.369842</td>
#       <td>  0.000000</td>
#       <td>      inf</td>
#       <td> BHLHE22</td>
#       <td> protein_coding</td>
#       <td> 0.454010</td>
#       <td>     -inf</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Neuranal Markers Don't appear to be present

# %% [markdown]
# #Endoderm Markers

# %%
HTML(riboseq.ix[["SOX17_1", "SOX17_2", "SOX17_1_r2", "SOX17_2_r2" ]][riboseq.ix[["SOX17_1", "SOX17_2", "SOX17_1_r2", "SOX17_2_r2"]].gene_name.isin(markers['Endoderm'].dropna())].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>riboseq</th>
#       <th>rnaseq</th>
#       <th>te</th>
#       <th>gene_name</th>
#       <th>gene_type</th>
#       <th>logged_riboseq</th>
#       <th>logged_rnaseq</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>gene</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="34" valign="top">SOX17_1</th>
#       <th>ENSG00000169856.6</th>
#       <td>    0.000000</td>
#       <td>    0.000000</td>
#       <td>      NaN</td>
#       <td> ONECUT1</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000112902.7</th>
#       <td>   10.316394</td>
#       <td>    5.097339</td>
#       <td> 1.017123</td>
#       <td>  SEMA5A</td>
#       <td> protein_coding</td>
#       <td>  3.366867</td>
#       <td>  2.349744</td>
#     </tr>
#     <tr>
#       <th>ENSG00000133937.3</th>
#       <td>   52.056989</td>
#       <td>   41.990432</td>
#       <td> 0.310031</td>
#       <td>     GSC</td>
#       <td> protein_coding</td>
#       <td>  5.702020</td>
#       <td>  5.391989</td>
#     </tr>
#     <tr>
#       <th>ENSG00000148826.6</th>
#       <td>    2.809056</td>
#       <td>    0.000000</td>
#       <td>      inf</td>
#       <td>  NKX6-2</td>
#       <td> protein_coding</td>
#       <td>  1.490085</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000141448.4</th>
#       <td>   57.306949</td>
#       <td>   30.742060</td>
#       <td> 0.898496</td>
#       <td>   GATA6</td>
#       <td> protein_coding</td>
#       <td>  5.840638</td>
#       <td>  4.942142</td>
#     </tr>
#     <tr>
#       <th>ENSG00000114315.3</th>
#       <td>    1.443410</td>
#       <td>    4.269061</td>
#       <td>-1.564438</td>
#       <td>    HES1</td>
#       <td> protein_coding</td>
#       <td>  0.529481</td>
#       <td>  2.093919</td>
#     </tr>
#     <tr>
#       <th>ENSG00000168646.8</th>
#       <td>    6.309938</td>
#       <td>   13.572665</td>
#       <td>-1.105006</td>
#       <td>   AXIN2</td>
#       <td> protein_coding</td>
#       <td>  2.657626</td>
#       <td>  3.762632</td>
#     </tr>
#     <tr>
#       <th>ENSG00000185155.7</th>
#       <td>   26.391542</td>
#       <td>    0.000000</td>
#       <td>      inf</td>
#       <td>   MIXL1</td>
#       <td> protein_coding</td>
#       <td>  4.722004</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163623.5</th>
#       <td>    0.964303</td>
#       <td>    0.000000</td>
#       <td>      inf</td>
#       <td>  NKX6-1</td>
#       <td> protein_coding</td>
#       <td> -0.052442</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000143768.7</th>
#       <td> 1243.630068</td>
#       <td>  332.717442</td>
#       <td> 1.902188</td>
#       <td>  LEFTY2</td>
#       <td> protein_coding</td>
#       <td> 10.280342</td>
#       <td>  8.378154</td>
#     </tr>
#     <tr>
#       <th>ENSG00000167693.12</th>
#       <td>   10.903406</td>
#       <td>   13.379154</td>
#       <td>-0.295208</td>
#       <td>     NXN</td>
#       <td> protein_coding</td>
#       <td>  3.446707</td>
#       <td>  3.741915</td>
#     </tr>
#     <tr>
#       <th>ENSG00000164093.10</th>
#       <td>    6.355426</td>
#       <td>    1.744047</td>
#       <td> 1.865550</td>
#       <td>   PITX2</td>
#       <td> protein_coding</td>
#       <td>  2.667989</td>
#       <td>  0.802439</td>
#     </tr>
#     <tr>
#       <th>ENSG00000104371.4</th>
#       <td>    0.000000</td>
#       <td>    0.000000</td>
#       <td>      NaN</td>
#       <td>    DKK4</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000241186.3</th>
#       <td>   56.937706</td>
#       <td>   38.660523</td>
#       <td> 0.558523</td>
#       <td>   TDGF1</td>
#       <td> protein_coding</td>
#       <td>  5.831312</td>
#       <td>  5.272789</td>
#     </tr>
#     <tr>
#       <th>ENSG00000104332.7</th>
#       <td>  124.729809</td>
#       <td>   99.815333</td>
#       <td> 0.321473</td>
#       <td>   SFRP1</td>
#       <td> protein_coding</td>
#       <td>  6.962662</td>
#       <td>  6.641190</td>
#     </tr>
#     <tr>
#       <th>ENSG00000107831.8</th>
#       <td>   13.601743</td>
#       <td>    6.456477</td>
#       <td> 1.074972</td>
#       <td>    FGF8</td>
#       <td> protein_coding</td>
#       <td>  3.765720</td>
#       <td>  2.690747</td>
#     </tr>
#     <tr>
#       <th>ENSG00000121966.6</th>
#       <td>  199.150261</td>
#       <td>   67.164080</td>
#       <td> 1.568096</td>
#       <td>   CXCR4</td>
#       <td> protein_coding</td>
#       <td>  7.637714</td>
#       <td>  6.069618</td>
#     </tr>
#     <tr>
#       <th>ENSG00000156925.7</th>
#       <td>   27.331866</td>
#       <td>   14.891089</td>
#       <td> 0.876135</td>
#       <td>    ZIC3</td>
#       <td> protein_coding</td>
#       <td>  4.772512</td>
#       <td>  3.896377</td>
#     </tr>
#     <tr>
#       <th>ENSG00000160973.7</th>
#       <td>   21.115216</td>
#       <td>    7.031998</td>
#       <td> 1.586277</td>
#       <td>   FOXH1</td>
#       <td> protein_coding</td>
#       <td>  4.400211</td>
#       <td>  2.813935</td>
#     </tr>
#     <tr>
#       <th>ENSG00000177426.15</th>
#       <td>   20.993166</td>
#       <td>   18.198752</td>
#       <td> 0.206080</td>
#       <td>   TGIF1</td>
#       <td> protein_coding</td>
#       <td>  4.391848</td>
#       <td>  4.185768</td>
#     </tr>
#     <tr>
#       <th>ENSG00000108379.5</th>
#       <td>    3.368327</td>
#       <td>    4.064739</td>
#       <td>-0.271130</td>
#       <td>    WNT3</td>
#       <td> protein_coding</td>
#       <td>  1.752032</td>
#       <td>  2.023163</td>
#     </tr>
#     <tr>
#       <th>ENSG00000156574.5</th>
#       <td>   82.125594</td>
#       <td>   25.926682</td>
#       <td> 1.663394</td>
#       <td>   NODAL</td>
#       <td> protein_coding</td>
#       <td>  6.359760</td>
#       <td>  4.696366</td>
#     </tr>
#     <tr>
#       <th>ENSG00000134982.12</th>
#       <td>    2.624792</td>
#       <td>    7.763145</td>
#       <td>-1.564438</td>
#       <td>     APC</td>
#       <td> protein_coding</td>
#       <td>  1.392203</td>
#       <td>  2.956641</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163508.8</th>
#       <td>   53.437416</td>
#       <td>   16.550284</td>
#       <td> 1.690994</td>
#       <td>   EOMES</td>
#       <td> protein_coding</td>
#       <td>  5.739778</td>
#       <td>  4.048784</td>
#     </tr>
#     <tr>
#       <th>ENSG00000186063.8</th>
#       <td>    2.638243</td>
#       <td>    7.802927</td>
#       <td>-1.564438</td>
#       <td>    AIDA</td>
#       <td> protein_coding</td>
#       <td>  1.399577</td>
#       <td>  2.964015</td>
#     </tr>
#     <tr>
#       <th>ENSG00000064655.14</th>
#       <td>    4.047445</td>
#       <td>    4.886046</td>
#       <td>-0.271656</td>
#       <td>    EYA2</td>
#       <td> protein_coding</td>
#       <td>  2.017011</td>
#       <td>  2.288667</td>
#     </tr>
#     <tr>
#       <th>ENSG00000132130.7</th>
#       <td>    4.651897</td>
#       <td>    3.370846</td>
#       <td> 0.464709</td>
#       <td>    LHX1</td>
#       <td> protein_coding</td>
#       <td>  2.217819</td>
#       <td>  1.753111</td>
#     </tr>
#     <tr>
#       <th>ENSG00000109625.14</th>
#       <td>    4.636420</td>
#       <td>    1.584069</td>
#       <td> 1.549376</td>
#       <td>     CPZ</td>
#       <td> protein_coding</td>
#       <td>  2.213011</td>
#       <td>  0.663635</td>
#     </tr>
#     <tr>
#       <th>ENSG00000101282.4</th>
#       <td>    0.000000</td>
#       <td>    0.000000</td>
#       <td>      NaN</td>
#       <td>   RSPO4</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000164683.12</th>
#       <td>    0.000000</td>
#       <td>    0.000000</td>
#       <td>      NaN</td>
#       <td>    HEY1</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td>      -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000169071.10</th>
#       <td>   19.299837</td>
#       <td>   19.701718</td>
#       <td>-0.029733</td>
#       <td>    ROR2</td>
#       <td> protein_coding</td>
#       <td>  4.270517</td>
#       <td>  4.300250</td>
#     </tr>
#     <tr>
#       <th

# %% [markdown]
# Endoderm markers look like they are there, fairly highly expressed

# %% [markdown]
# #Mesoder Markers

# %%
HTML(riboseq.ix[["TGFP_1", "TGFP_2", "TGFP_1_r2", "TGFP_2_r2"]][riboseq.ix[["TGFP_1", "TGFP_2",  "TGFP_1_r2", "TGFP_2_r2"]].gene_name.isin(markers['Mesoderm'].dropna())].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>riboseq</th>
#       <th>rnaseq</th>
#       <th>te</th>
#       <th>gene_name</th>
#       <th>gene_type</th>
#       <th>logged_riboseq</th>
#       <th>logged_rnaseq</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>gene</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="17" valign="top">TGFP_1</th>
#       <th>ENSG00000019549.4</th>
#       <td>    4.128768</td>
#       <td>  3.893936</td>
#       <td> 0.084482</td>
#       <td>  SNAI2</td>
#       <td> protein_coding</td>
#       <td>  2.045711</td>
#       <td> 1.961229</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163132.6</th>
#       <td>    2.665659</td>
#       <td>  4.190074</td>
#       <td>-0.652483</td>
#       <td>   MSX1</td>
#       <td> protein_coding</td>
#       <td>  1.414492</td>
#       <td> 2.066976</td>
#     </tr>
#     <tr>
#       <th>ENSG00000107485.11</th>
#       <td>    0.000000</td>
#       <td>  0.000000</td>
#       <td>      NaN</td>
#       <td>  GATA3</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000106038.8</th>
#       <td>    7.875641</td>
#       <td>  0.952269</td>
#       <td> 3.047956</td>
#       <td>   EVX1</td>
#       <td> protein_coding</td>
#       <td>  2.977397</td>
#       <td>-0.070559</td>
#     </tr>
#     <tr>
#       <th>ENSG00000143768.7</th>
#       <td>   23.512457</td>
#       <td> 17.301182</td>
#       <td> 0.442555</td>
#       <td> LEFTY2</td>
#       <td> protein_coding</td>
#       <td>  4.555353</td>
#       <td> 4.112799</td>
#     </tr>
#     <tr>
#       <th>ENSG00000026025.9</th>
#       <td>  108.419565</td>
#       <td> 63.190863</td>
#       <td> 0.778837</td>
#       <td>    VIM</td>
#       <td> protein_coding</td>
#       <td>  6.760481</td>
#       <td> 5.981644</td>
#     </tr>
#     <tr>
#       <th>ENSG00000128052.8</th>
#       <td>   22.407674</td>
#       <td> 12.774536</td>
#       <td> 0.810722</td>
#       <td>    KDR</td>
#       <td> protein_coding</td>
#       <td>  4.485921</td>
#       <td> 3.675199</td>
#     </tr>
#     <tr>
#       <th>ENSG00000107831.8</th>
#       <td>    7.174167</td>
#       <td>  2.255374</td>
#       <td> 1.669445</td>
#       <td>   FGF8</td>
#       <td> protein_coding</td>
#       <td>  2.842811</td>
#       <td> 1.173367</td>
#     </tr>
#     <tr>
#       <th>ENSG00000122691.8</th>
#       <td>    0.000000</td>
#       <td>  0.000000</td>
#       <td>      NaN</td>
#       <td> TWIST1</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000198336.4</th>
#       <td>    2.312313</td>
#       <td>  0.000000</td>
#       <td>      inf</td>
#       <td>   MYL4</td>
#       <td> protein_coding</td>
#       <td>  1.209337</td>
#       <td>     -inf</td>
#     </tr>
#     <tr>
#       <th>ENSG00000188095.3</th>
#       <td>    0.000000</td>
#       <td>  1.664862</td>
#       <td>     -inf</td>
#       <td>  MESP2</td>
#       <td> protein_coding</td>
#       <td>      -inf</td>
#       <td> 0.735403</td>
#     </tr>
#     <tr>
#       <th>ENSG00000156574.5</th>
#       <td>   13.364594</td>
#       <td>  6.947769</td>
#       <td> 0.943794</td>
#       <td>  NODAL</td>
#       <td> protein_coding</td>
#       <td>  3.740344</td>
#       <td> 2.796550</td>
#     </tr>
#     <tr>
#       <th>ENSG00000154342.4</th>
#       <td>   15.418579</td>
#       <td>  7.068842</td>
#       <td> 1.125124</td>
#       <td>  WNT3A</td>
#       <td> protein_coding</td>
#       <td>  3.946598</td>
#       <td> 2.821474</td>
#     </tr>
#     <tr>
#       <th>ENSG00000243709.1</th>
#       <td>   37.749884</td>
#       <td> 29.787441</td>
#       <td> 0.341768</td>
#       <td> LEFTY1</td>
#       <td> protein_coding</td>
#       <td>  5.238400</td>
#       <td> 4.896632</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163508.8</th>
#       <td>   31.917387</td>
#       <td> 11.264459</td>
#       <td> 1.502565</td>
#       <td>  EOMES</td>
#       <td> protein_coding</td>
#       <td>  4.996271</td>
#       <td> 3.493706</td>
#     </tr>
#     <tr>
#       <th>ENSG00000170365.5</th>
#       <td>    4.045974</td>
#       <td>  0.978423</td>
#       <td> 2.047956</td>
#       <td>  SMAD1</td>
#       <td> protein_coding</td>
#       <td>  2.016487</td>
#       <td>-0.031469</td>
#     </tr>
#     <tr>
#       <th>ENSG00000039068.13</th>
#       <td>   18.941708</td>
#       <td>  4.824271</td>
#       <td> 1.973184</td>
#       <td>   CDH1</td>
#       <td> protein_coding</td>
#       <td>  4.243495</td>
#       <td> 2.270311</td>
#     </tr>
#     <tr>
#       <th rowspan="17" valign="top">TGFP_1_r2</th>
#       <th>ENSG00000019549.4</th>
#       <td>    0.459331</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>  SNAI2</td>
#       <td> protein_coding</td>
#       <td> -1.122394</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163132.6</th>
#       <td>    0.078042</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>   MSX1</td>
#       <td> protein_coding</td>
#       <td> -3.679613</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000107485.11</th>
#       <td>    4.258623</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>  GATA3</td>
#       <td> protein_coding</td>
#       <td>  2.090387</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000106038.8</th>
#       <td>    0.549827</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>   EVX1</td>
#       <td> protein_coding</td>
#       <td> -0.862951</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000143768.7</th>
#       <td> 1249.308069</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td> LEFTY2</td>
#       <td> protein_coding</td>
#       <td> 10.286914</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000026025.9</th>
#       <td>   39.334360</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    VIM</td>
#       <td> protein_coding</td>
#       <td>  5.297718</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000128052.8</th>
#       <td>    9.969343</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>    KDR</td>
#       <td> protein_coding</td>
#       <td>  3.317499</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000107831.8</th>
#       <td>   16.433222</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>   FGF8</td>
#       <td> protein_coding</td>
#       <td>  4.038543</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000122691.8</th>
#       <td>    1.331276</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td> TWIST1</td>
#       <td> protein_coding</td>
#       <td>  0.412810</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000198336.4</th>
#       <td>   11.784080</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>   MYL4</td>
#       <td> protein_coding</td>
#       <td>  3.558767</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000188095.3</th>
#       <td>    0.124035</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>  MESP2</td>
#       <td> protein_coding</td>
#       <td> -3.011185</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000156574.5</th>
#       <td>   57.412055</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>  NODAL</td>
#       <td> protein_coding</td>
#       <td>  5.843282</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000154342.4</th>
#       <td>    1.203746</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td>  WNT3A</td>
#       <td> protein_coding</td>
#       <td>  0.267531</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000243709.1</th>
#       <td> 1771.732064</td>
#       <td>       NaN</td>
#       <td>      NaN</td>
#       <td> LEFTY1</td>
#       <td> protein_coding</td>
#       <td> 10.790945</td>
#       <td>      NaN</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163508.8</th>
#       <td>   57.096223</td>
#       <td>       NaN</td>

# %% [markdown]
# Mesoderm Markers also look like they are present, a bit hit and miss though...

# %% [markdown]
# #ES markers

# %%
HTML(riboseq.ix[['ES_1', 'ES_2']][riboseq.ix[["ES_1", 'ES_2']].gene_name.isin(markers['ES Markers'].dropna())].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>flag</th>
#       <th>riboseq</th>
#       <th>rnaseq</th>
#       <th>te</th>
#       <th>gene_name</th>
#       <th>gene_type</th>
#       <th>logged_riboseq</th>
#       <th>logged_rnaseq</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>gene</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="17" valign="top">ES_1</th>
#       <th>ENSG00000136826.10</th>
#       <td> 0</td>
#       <td>   0.091523</td>
#       <td>   0.313333</td>
#       <td>-1.775493</td>
#       <td>   KLF4</td>
#       <td> protein_coding</td>
#       <td>-1.038470</td>
#       <td>-0.503994</td>
#     </tr>
#     <tr>
#       <th>ENSG00000181449.2</th>
#       <td> 0</td>
#       <td>  80.591691</td>
#       <td>  75.970866</td>
#       <td> 0.085185</td>
#       <td>   SOX2</td>
#       <td> protein_coding</td>
#       <td> 1.906290</td>
#       <td> 1.880647</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163530.4</th>
#       <td> 0</td>
#       <td>   2.677735</td>
#       <td>   1.581970</td>
#       <td> 0.759291</td>
#       <td>  DPPA2</td>
#       <td> protein_coding</td>
#       <td> 0.427768</td>
#       <td> 0.199198</td>
#     </tr>
#     <tr>
#       <th>ENSG00000134323.10</th>
#       <td> 0</td>
#       <td>  10.122522</td>
#       <td>  11.327213</td>
#       <td>-0.162224</td>
#       <td>   MYCN</td>
#       <td> protein_coding</td>
#       <td> 1.005289</td>
#       <td> 1.054123</td>
#     </tr>
#     <tr>
#       <th>ENSG00000130816.10</th>
#       <td> 0</td>
#       <td>  11.120423</td>
#       <td>   8.649356</td>
#       <td> 0.362547</td>
#       <td>  DNMT1</td>
#       <td> protein_coding</td>
#       <td> 1.046121</td>
#       <td> 0.936984</td>
#     </tr>
#     <tr>
#       <th>ENSG00000241186.3</th>
#       <td> 0</td>
#       <td>  31.113611</td>
#       <td>  31.656676</td>
#       <td>-0.024964</td>
#       <td>  TDGF1</td>
#       <td> protein_coding</td>
#       <td> 1.492950</td>
#       <td> 1.500465</td>
#     </tr>
#     <tr>
#       <th>ENSG00000164362.14</th>
#       <td> 0</td>
#       <td>   0.957022</td>
#       <td>   1.203608</td>
#       <td>-0.330742</td>
#       <td>   TERT</td>
#       <td> protein_coding</td>
#       <td>-0.019078</td>
#       <td> 0.080485</td>
#     </tr>
#     <tr>
#       <th>ENSG00000156925.7</th>
#       <td> 0</td>
#       <td>   4.450922</td>
#       <td>   3.626748</td>
#       <td> 0.295428</td>
#       <td>   ZIC3</td>
#       <td> protein_coding</td>
#       <td> 0.648450</td>
#       <td> 0.559517</td>
#     </tr>
#     <tr>
#       <th>ENSG00000169679.10</th>
#       <td> 0</td>
#       <td>  22.257588</td>
#       <td>  15.487335</td>
#       <td> 0.523208</td>
#       <td>   BUB1</td>
#       <td> protein_coding</td>
#       <td> 1.347478</td>
#       <td> 1.189977</td>
#     </tr>
#     <tr>
#       <th>ENSG00000088305.13</th>
#       <td> 0</td>
#       <td>  77.130912</td>
#       <td>  71.551670</td>
#       <td> 0.108324</td>
#       <td> DNMT3B</td>
#       <td> protein_coding</td>
#       <td> 1.887228</td>
#       <td> 1.854620</td>
#     </tr>
#     <tr>
#       <th>ENSG00000171794.3</th>
#       <td> 0</td>
#       <td>   5.133998</td>
#       <td>   5.752309</td>
#       <td>-0.164058</td>
#       <td>   UTF1</td>
#       <td> protein_coding</td>
#       <td> 0.710456</td>
#       <td> 0.759842</td>
#     </tr>
#     <tr>
#       <th>ENSG00000116478.7</th>
#       <td> 0</td>
#       <td>  23.544355</td>
#       <td>  19.560546</td>
#       <td> 0.267435</td>
#       <td>  HDAC1</td>
#       <td> protein_coding</td>
#       <td> 1.371887</td>
#       <td> 1.291381</td>
#     </tr>
#     <tr>
#       <th>ENSG00000204531.10</th>
#       <td> 0</td>
#       <td> 169.903064</td>
#       <td> 165.221594</td>
#       <td> 0.040310</td>
#       <td> POU5F1</td>
#       <td> protein_coding</td>
#       <td> 2.230201</td>
#       <td> 2.218067</td>
#     </tr>
#     <tr>
#       <th>ENSG00000121570.8</th>
#       <td> 0</td>
#       <td>  84.035770</td>
#       <td>  74.174757</td>
#       <td> 0.180075</td>
#       <td>  DPPA4</td>
#       <td> protein_coding</td>
#       <td> 1.924464</td>
#       <td> 1.870256</td>
#     </tr>
#     <tr>
#       <th>ENSG00000168610.10</th>
#       <td> 0</td>
#       <td>   8.879412</td>
#       <td>   6.868273</td>
#       <td> 0.370517</td>
#       <td>  STAT3</td>
#       <td> protein_coding</td>
#       <td> 0.948384</td>
#       <td> 0.836848</td>
#     </tr>
#     <tr>
#       <th>ENSG00000111704.6</th>
#       <td> 0</td>
#       <td>  49.554554</td>
#       <td>  45.527873</td>
#       <td> 0.122268</td>
#       <td>  NANOG</td>
#       <td> protein_coding</td>
#       <td> 1.695084</td>
#       <td> 1.658277</td>
#     </tr>
#     <tr>
#       <th>ENSG00000117399.9</th>
#       <td> 0</td>
#       <td>  64.214649</td>
#       <td>  54.413888</td>
#       <td> 0.238928</td>
#       <td>  CDC20</td>
#       <td> protein_coding</td>
#       <td> 1.807634</td>
#       <td> 1.735710</td>
#     </tr>
#     <tr>
#       <th rowspan="17" valign="top">ES_2</th>
#       <th>ENSG00000136826.10</th>
#       <td> 0</td>
#       <td>   0.074948</td>
#       <td>   0.103369</td>
#       <td>-0.463837</td>
#       <td>   KLF4</td>
#       <td> protein_coding</td>
#       <td>-1.125238</td>
#       <td>-0.985609</td>
#     </tr>
#     <tr>
#       <th>ENSG00000181449.2</th>
#       <td> 0</td>
#       <td>  34.495120</td>
#       <td>  23.430925</td>
#       <td> 0.557978</td>
#       <td>   SOX2</td>
#       <td> protein_coding</td>
#       <td> 1.537758</td>
#       <td> 1.369789</td>
#     </tr>
#     <tr>
#       <th>ENSG00000163530.4</th>
#       <td> 0</td>
#       <td>   1.229187</td>
#       <td>   1.062047</td>
#       <td> 0.210856</td>
#       <td>  DPPA2</td>
#       <td> protein_coding</td>
#       <td> 0.089618</td>
#       <td> 0.026144</td>
#     </tr>
#     <tr>
#       <th>ENSG00000134323.10</th>
#       <td> 0</td>
#       <td>   4.551991</td>
#       <td>   4.464529</td>
#       <td> 0.027990</td>
#       <td>   MYCN</td>
#       <td> protein_coding</td>
#       <td> 0.658201</td>
#       <td> 0.649776</td>
#     </tr>
#     <tr>
#       <th>ENSG00000130816.10</th>
#       <td> 0</td>
#       <td>   2.093915</td>
#       <td>   2.046543</td>
#       <td> 0.033014</td>
#       <td>  DNMT1</td>
#       <td> protein_coding</td>
#       <td> 0.320959</td>
#       <td> 0.311021</td>
#     </tr>
#     <tr>
#       <th>ENSG00000241186.3</th>
#       <td> 0</td>
#       <td>  33.509631</td>
#       <td>  22.655078</td>
#       <td> 0.564741</td>
#       <td>  TDGF1</td>
#       <td> protein_coding</td>
#       <td> 1.525170</td>
#       <td> 1.355166</td>
#     </tr>
#     <tr>
#       <th>ENSG00000164362.14</th>
#       <td> 0</td>
#       <td>   0.442040</td>
#       <td>   0.720350</td>
#       <td>-0.704520</td>
#       <td>   TERT</td>
#       <td> protein_coding</td>
#       <td>-0.354538</td>
#       <td>-0.142457</td>
#     </tr>
#     <tr>
#       <th>ENSG00000156925.7</th>
#       <td> 0</td>
#       <td>   0.873384</td>
#       <td>   0.733276</td>
#       <td> 0.252259</td>
#       <td>   ZIC3</td>
#       <td> protein_coding</td>
#       <td>-0.058795</td>
#       <td>-0.134732</td>
#     </tr>
#     <tr>
#       <th>ENSG00000169679.10</th>
#       <td> 0</td>
#       <td>  10.894971</td>
#       <td>   8.520509</td>
#       <td> 0.354651</td>
#       <td>   BUB1</td>
#       <td> protein_coding</td>
#       <td> 1.037226</td>
#       <td> 0.930466</td>
#     </tr>
#     <tr>
#       <th>ENSG00000088305.13</th>
#       <td> 0</td>
#       <td>  25.847093</td>
#       <td>  23.908671</td>
#       <td> 0.112468</td>
#       <td> DNMT3B</td>
#       <td> protein_coding</td>
#       <td> 1.412412</td>
#       <td> 1.378555</td>
#     </tr>
#     <tr>
#       <th>ENSG00000171794.3</th>
#       <td> 0</td>
#       <td>   0.229323</td>
#       <td>   0.063257</td>
#       <td> 1.858091</td>
#       <td>   UTF1</td>
#       <td> protein_coding</td>
#       <td>-0.639553</td>
#       <td>-1.198894</td>
#     </tr>
#     <tr>
#       <th>ENSG00000116478.7</th>
#       <td> 0</td>
#       <td>   6.596415</td>
#       <td>   6.171585</td>
#       <td> 0.096041</td>
#       <td>  HDAC1</td>
#       <td> protein_coding</td>
#       <td> 0.819308</td>
#       <td> 0.790397</td>
#     </tr>
#     <tr>
#       <th>ENSG00000204531.1

# %% [markdown]
# To do:
# + Expression is actually bad in Brain, not a lot of the markers have any reads, rna-seq or riboseq

# %% [markdown]
# 3 base pair perodicity
# cofficent of variation
#
# focus on uORF and dORF + start and stop annotations first, TE / specific TE papers after
