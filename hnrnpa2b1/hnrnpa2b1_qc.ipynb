# %%
from gscripts.general import parsers
from IPython.core.display import HTML
from gscripts.clipseq import cl
from gscripts.general import dataviz
# Out:
# /nas/nas0/gpratt/virtualenvs/default/lib/python2.7/site-packages/seaborn/rcmod.py:465: UserWarning: set_color_palette is deprecated, use set_palette instead.
#   UserWarning)

# %%
iclip_metrics = parsers.clipseq_metrics("/nas3/gpratt/projects/hnrnpa2b1/analysis/hnrnpa2b1_iclip_v1/", iclip=True)
iclip_metrics = iclip_metrics.rename(columns={"Processed bases" : "Input Bases",
           "Processed reads" : "Input Reads",
           "Number of input reads" : "Reads after Quality Filtering"
           })

iclip_metrics["percent_mapped"] = iclip_metrics['Uniquely mapped reads number'].astype(float) / iclip_metrics['Reads after Quality Filtering']
iclip_metrics["percent_repetative"] = 1 - (iclip_metrics['Reads after Quality Filtering'] / iclip_metrics['Input Reads'].astype(float))
iclip_metrics["Reads After Triming"] = iclip_metrics['Input Reads'] - iclip_metrics['Too short reads']
iclip_metrics["%usable / input"] = (iclip_metrics['Usable Reads'] / iclip_metrics['Uniquely mapped reads number']) * 100
iclip_metrics["%usable / mapped"] = (iclip_metrics['Usable Reads'] / iclip_metrics['Input Reads']) * 100
iclip_metrics = iclip_metrics.drop(["Finished on", 
                  "Mapping speed, Million of reads per hour", 
                  "Trimmed bases",
                  "Started job on",
                  "Started mapping on"], axis=1)

# %%
filtered_df = iclip_metrics[[ "Input Reads",
                            "Reads After Triming",
                            "Reads after Quality Filtering", 
                            "Uniquely mapped reads number",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            #"spot",
                            "Num Peaks",
                            "%usable / input",
                            "%usable / mapped"
                            
                            ]]


HTML(filtered_df.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely mapped reads number" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas,
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads After Triming</th>
#       <th>Reads after Quality Filtering</th>
#       <th>Uniquely mapped reads number</th>
#       <th>Usable Reads</th>
#       <th>Num Peaks</th>
#       <th>%usable / input</th>
#       <th>%usable / mapped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1_NoIndex_L001_R1.R01</th>
#       <td>121,928,450</td>
#       <td>120,680,123</td>
#       <td> 92,401,764</td>
#       <td> 24,894,742</td>
#       <td>  389,530</td>
#       <td>  425</td>
#       <td>  1.564708</td>
#       <td>  0.319474</td>
#     </tr>
#     <tr>
#       <th>1_NoIndex_L001_R1.R02</th>
#       <td>    415,818</td>
#       <td>    414,227</td>
#       <td>    275,901</td>
#       <td>    111,038</td>
#       <td>      997</td>
#       <td>    1</td>
#       <td> 0.8978908</td>
#       <td>  0.239768</td>
#     </tr>
#     <tr>
#       <th>1_NoIndex_L001_R1.R03</th>
#       <td>     21,562</td>
#       <td>     21,487</td>
#       <td>     21,430</td>
#       <td>        348</td>
#       <td>       30</td>
#       <td>    0</td>
#       <td>   8.62069</td>
#       <td>  0.139134</td>
#     </tr>
#     <tr>
#       <th>1_NoIndex_L001_R1.R04</th>
#       <td>      6,506</td>
#       <td>      6,497</td>
#       <td>      5,914</td>
#       <td>        213</td>
#       <td>       18</td>
#       <td>    0</td>
#       <td>  8.450704</td>
#       <td>  0.276668</td>
#     </tr>
#     <tr>
#       <th>1_NoIndex_L001_R1.R05</th>
#       <td>      1,898</td>
#       <td>      1,866</td>
#       <td>      1,027</td>
#       <td>         30</td>
#       <td>       17</td>
#       <td>    0</td>
#       <td>  56.66667</td>
#       <td>  0.895680</td>
#     </tr>
#     <tr>
#       <th>1_NoIndex_L001_R1.R06</th>
#       <td>  1,155,810</td>
#       <td>  1,151,100</td>
#       <td>  1,096,890</td>
#       <td>     37,683</td>
#       <td>    3,283</td>
#       <td>    9</td>
#       <td>  8.712151</td>
#       <td>  0.284043</td>
#     </tr>
#     <tr>
#       <th>1_NoIndex_L001_R1.
td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R05</th>
#       <td>      1,833</td>
#       <td>      1,719</td>
#       <td>      1,370</td>
#       <td>        205</td>
#       <td>      133</td>
#       <td>    0</td>
#       <td>  64.87805</td>
#       <td>  7.255865</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R06</th>
#       <td>  2,132,404</td>
#       <td>  2,112,623</td>
#       <td>  2,028,025</td>
#       <td>    121,733</td>
#       <td>   32,044</td>
#       <td>  330</td>
#       <td>  26.32318</td>
#       <td>  1.502717</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R07</th>
#       <td>     51,366</td>
#       <td>     51,177</td>
#       <td>     49,988</td>
#       <td>     11,299</td>
#       <td>    9,175</td>
#       <td>    1</td>
#       <td>  81.20188</td>
#       <td> 17.862010</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R08</th>
#       <td>        928</td>
#       <td>        923</td>
#       <td>        895</td>
#       <td>        204</td>
#       <td>       92</td>
#       <td>    0</td>
#       <td>  45.09804</td>
#       <td>  9.913793</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R09</th>
#       <td>      1,509</td>
#       <td>      1,488</td>
#       <td>      1,225</td>
#       <td>        212</td>
#       <td>      120</td>
#       <td>    0</td>
#       <td>  56.60377</td>
#       <td>  7.952286</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R10</th>
#       <td>     93,796</td>
#       <td>     92,011</td>
#       <td>     83,897</td>
#       <td>     18,032</td>
#       <td>   12,728</td>
#       <td>   13</td>
#       <td>  70.58563</td>
#       <td> 13.569875</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R11</th>
#       <td>      2,328</td>
#       <td>      2,325</td>
#       <td>      2,243</td>
#       <td>        345</td>
#       <td>      136</td>
#       <td>    0</td>
#       <td>  39.42029</td>
#       <td>  5.841924</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R12</th>
#       <td>      1,988</td>
#       <td>      1,966</td>
#       <td>      1,736</td>
#       <td>        196</td>
#       <td>       99</td>
#       <td>    0</td>
#       <td>   50.5102</td>
#       <td>  4.979879</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R13</th>
#       <td>     25,762</td>
#       <td>     25,524</td>
#       <td>     25,024</td>
#       <td>      1,005</td>
#       <td>      287</td>
#       <td>    0</td>
#       <td>  28.55721</td>
#       <td>  1.114044</td>
#     </tr>
#     <

# %%
with dataviz.Figure("julia_out.svg", figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   "/nas3/gpratt/projects/julia/analysis/split_fastq_v2/1_NoIndex_L001_R1.metrics",
                                                   "R01 R02 R06 R16".split())
    ax.set_title("Fernando_high.metrics")
# Out:
# /nas3/yeolab/Software/lib/python2.7/site-packages/matplotlib-1.4.x-py2.7-linux-x86_64.egg/matplotlib/font_manager.py:1240: UserWarning: findfont: Font family ['Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-30c134a26f72> in <module>()
#       1 with dataviz.Figure("julia_out.svg", figsize=(6,6)) as fig:
#       2     ax = fig.add_subplot(1,1,1)
# ----> 3     clipseq_barcode_metrics.plot_barcode_pie_chart(ax,
#       4                                                    "/nas3/gpratt/projects/julia/analysis/split_fastq_v2/1_NoIndex_L001_R1.metrics",
#       5                                                    "R01 R02 R06 R16".split())
#
# NameError: name 'clipseq_barcode_metrics' is not defined

# %%
with dataviz.Figure("julia_out.svg", figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   "/nas3/gpratt/projects/julia/analysis/split_fastq_v2/2_NoIndex_L002_R1.metrics",
                                                   "R01 R02 R06 R16".split())
    ax.set_title("Fernando_mid.metrics")
