# %%
from collections import defaultdict, Counter
import glob
import os

from IPython.core.display import HTML, Image
from matplotlib_venn import venn3
import pandas as pd
import pybedtools
import pysam

from gscripts.general import parsers
# %load_ext autoreload
# %autoreload 2
reload(parsers)
reload(pybedtools)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <module 'pybedtools' from '/nas/nas0/gpratt/tools/pybedtools/pybedtools/__init__.pyc'>

# %%
# !scp -q tscc-login.sdsc.edu:~/projects/encode/analysis/v10/*.{metrics,final.out,peaks.bed} /nas3/gpratt/projects/encode/analysis/v10/
# Out:
# discarding /projects/ps-yeolab/software/anaconda-2.0.1_2014-08-12/bin from PATH
# prepending /projects/ps-yeolab/software/anaconda-2.0.1_2014-08-12/envs/gpratt/bin to PATH
# discarding /projects/ps-yeolab/software/anaconda-2.0.1_2014-08-12/bin from PATH
# prepending /projects/ps-yeolab/software/anaconda-2.0.1_2014-08-12/envs/gpratt/bin to PATH
# discarding /projects/ps-yeolab/software/anaconda-2.0.1_2014-08-12/bin from PATH
# prepending /projects/ps-yeolab/software/anaconda-2.0.1_2014-08-12/envs/gpratt/bin to PATH

# %%
analysis_dir = "/nas3/gpratt/projects/encode/analysis/v10/"
encode_v10 = parsers.clipseq_metrics(analysis_dir, iclip=True)

encode_v10["Reads After Triming"] = encode_v10['Input Reads'] - encode_v10['Too short reads']
encode_v10["Percent Collapsed"] = encode_v10['Usable Reads'] / encode_v10['Uniquely Mapped Reads'].astype(float)
encode_v10["Percent Usable"] = encode_v10['Usable Reads'] / encode_v10['Input Reads'].astype(float)

filtered_encode_v10 = encode_v10[[ "Input Reads",
                            #"Reads After Triming",
                            "Uniquely Mapped Reads",
                            "repetitive_count",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            #"Percent Collapsed",
                            "Percent Usable",
                            #"spot",
                            "Num Peaks",
                            "Passed QC"
                            ]]

HTML(filtered_encode_v10.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))
# Out:
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.R09.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.R07.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.R01.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.SBRclip26.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.SBRclip28.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/IMP3H_NoIndex_L003_R1.R10_IMP3_C11H.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/5_NoIndex_L005_R1.RSRclip37.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/5_NoIndex_L005_R1.BSRclip18.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/3_NoIndex_L003_R1.R04.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/IMP3M_NoIndex_L004_R1.R13_IMP3_D12M.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/5_NoIndex_L005_R1.SBRclip46.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/IMP3M_NoIndex_L004_R1.unassigned.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/4_NoIndex_L004_R1.R09.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/4_NoIndex_L004_R1.R03_FUS_a.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/IMP3H_NoIndex_L003_R1.R11_IMP3_C21H.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.R15.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/4_NoIndex_L004_R1.R04_FUS_b.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/KI2_NoIndex_L002_R1.R08_IMP1_8.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/IMP3M_NoIndex_L004_R1.R09_IMP3_C12M.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <closed file '/nas3/gpratt/projects/encode/analysis/v10/6_NoIndex_L006_R1.R05_FUBP1.polyATrim.adapterTrim.metrics', mode 'r' at 0x16abfc90>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>repetitive_count</th>
#       <th>Usable Reads</th>
#       <th>Percent Usable</th>
#       <th>Num Peaks</th>
#       <th>Passed QC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2_NoIndex_L002_R1.R02</th>
#       <td>     66,066</td>
#       <td>     35,291</td>
#       <td>     6885</td>
#       <td>     1,061</td>
#       <td> 0.016060</td>
#       <td>     20</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R03</th>
#       <td>    191,185</td>
#       <td>    111,677</td>
#       <td>    30971</td>
#       <td>     6,213</td>
#       <td> 0.032497</td>
#       <td>     71</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R07</th>
#       <td>     51,246</td>
#       <td>     26,578</td>
#       <td>     5902</td>
#       <td>       575</td>
#       <td> 0.011220</td>
#       <td>      6</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R08</th>
#       <td>     43,409</td>
#       <td>     22,509</td>
#       <td>     3197</td>
#       <td>       372</td>
#       <td> 0.008570</td>
#       <td>      0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R09</th>
#       <td>     35,878</td>
#       <td>     15,169</td>
#       <td>     7212</td>
#       <td>       322</td>
#       <td> 0.008975</td>
#       <td>      5</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R11</th>
#       <td>     44,588</td>
#       <td>     17,244</td>
#       <td>     4992</td>
#       <td>       350</td>
#       <td> 0.007850</td>
#       <td>      0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R15</th>
#       <td>     40,697</td>
#       <td>     20,171</td>
#       <td>     1967</td>
#       <td>       349</td>
#       <td> 0.008576</td>
#       <td>     11</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.R16</th>
#       <td>     61,898</td>
#       <td>     32,612</td>
#       <td>     6239</td>
#       <td>       790</td>
#       <td> 0.012763</td>
#       <td>     24</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.SBRclip26_TAI1_b</th>
#       <td> 31,695,182</td>
#       <td> 21,716,567</td>
#       <td>  3032956</td>
#       <td>   171,657</td>
#       <td> 0.005416</td>
#       <td>      0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.SBRclip26_TAI1_k562_rep1</th>
#       <td> 31,695,182</td>
#       <td> 21,726,875</td>
#       <td>  3032956</td>
#       <td>    97,172</td>
#       <td> 0.003066</td>
#       <td> 11,080</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.SBRclip28_TIA1_a</th>
#       <td> 36,192,891</td>
#       <td> 24,958,597</td>
#       <td>  3975126</td>
#       <td>    91,376</td>
#       <td> 0.002525</td>
#       <td> 12,053</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.SBRclip28_TIA1_k562_rep2</th>
#       <td> 36,192,891</td>
#       <td> 24,958,597</td>
#       <td>  3975126</td>
#       <td>    91,376</td>
#       <td> 0.002525</td>
#       <td> 12,053</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.SBRclip32_MBNL1_a</th>
#       <td> 38,548,741</td>
#       <td> 24,095,504</td>
#       <td>  7980824</td>
#       <td>   901,660</td>
#       <td> 0.023390</td>
#       <td> 24,960</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.SBRclip32_MBNL1_k562_rep2</th>
#       <td> 38,548,741</td>
#       <td> 24,095,504</td>
#       <td>  7980824</td>
#       <td>   901,660</td>
#       <td> 0.023390</td>
#       <td> 24,961</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>2_NoIndex_L002_R1.unassigned</th>
#       <td> 18,492,556</td>
#       <td> 11,286,523</td>
#       <td>  2132247</td>
#       <td>   331,344</td>
#       <td> 0.017918</td>
#       <td> 12,917</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip08_TIAL1_DirectIP_a</th>
#       <td> 49,379,052</td>
#       <td> 30,016,480</td>
#       <td> 10809762</td>
#       <td> 9,195,338</td>
#       <td> 0.186219</td>
#       <td> 63,529</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip08_TIAL1_DirectIP_k562_rep1</th>
#       <td> 37,473,455</td>
#       <td> 22,778,817</td>
#       <td>  8202256</td>
#       <td>         0</td>
#       <td>      NaN</td>
#       <td>      0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip10</th>
#       <td> 62,944,579</td>
#       <td> 28,984,588</td>
#       <td> 13327213</td>
#       <td>11,496,742</td>
#       <td> 0.182649</td>
#       <td> 60,396</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip12</th>
#       <td>    145,130</td>
#       <td>     52,255</td>
#       <td>     9235</td>
#       <td>    21,098</td>
#       <td> 0.145373</td>
#       <td>    101</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip14_HNRNPC_DirectIP_b</th>
#       <td> 42,270,975</td>
#       <td> 27,244,503</td>
#       <td>  6895008</td>
#       <td> 5,736,299</td>
#       <td> 0.135703</td>
#       <td> 31,556</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip14_HNRNPC_DirectIP_k562_rep1</th>
#       <td> 32,074,493</td>
#       <td> 20,671,367</td>
#       <td>  5230579</td>
#       <td> 5,280,733</td>
#       <td> 0.164640</td>
#       <td> 29,457</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip18_HNRNPC_DirectIP_a</th>
#       <td>     50,750</td>
#       <td>     22,392</td>
#       <td>     5483</td>
#       <td>     8,270</td>
#       <td> 0.162956</td>
#       <td>     33</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.BSRclip18_HNRNPC_DirectIP_k562_rep2</th>
#       <td>     29,026</td>
#       <td>     12,874</td>
#       <td>     3079</td>
#       <td>     6,210</td>
#       <td> 0.213946</td>
#       <td>     23</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.R01</th>
#       <td>     57,258</td>
#       <td>     33,730</td>
#       <td>     6126</td>
#       <td>    25,440</td>
#       <td> 0.444305</td>
#       <td>     68</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.R04</th>
#       <td>          0</td>
#       <td>        NaN</td>
#       <td>      NaN</td>
#       <td>         0</td>
#       <td>      NaN</td>
#       <td>      0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.R09</th>
#       <td>     28,631</td>
#       <td>     12,679</td>
#       <td>     4266</td>
#       <td>     9,728</td>
#       <td> 0.339772</td>
#       <td>     41</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.RSRclip37</th>
#       <td>     29,027</td>
#       <td>     18,951</td>
#       <td>     4672</td>
#       <td>     5,975</td>
#       <td> 0.205843</td>
#       <td>     30</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>3_NoIndex_L003_R1.unassigned</th>
#       <td> 14,457,248</td>
#       <td>  8,014,866</td>
#       <td>  2052977</td>
#       <td> 2,655,078</td>
#       <td> 0.183650</td>
#       <td> 23,595</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>4_NoIndex_L004_R1.BSRclip10_TDP43_a</th>
#       <td> 35,467,042</td>
#       <td> 21,147,707</td>
#       <td>  7854309</td>
#       <td>   212,083</td>
#       <td> 0.005980</td>
#       <td> 11,639</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>4_NoIndex_L004_R1.BSRclip10_TDP43_k562_rep1</th>
#       <td> 25,283,288</td>
#       <td> 15,067,522</td>
#       <td>  5604568</td>
#       <td>   197,220</td>
#       <td> 0.007800</td>
#       <td>  9,437</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>4_NoIndex_L004_R1.R03_FUS_a</th>
#       <td>          0</td>
#       <td> 38,113,244</td>
#       <td>  6921429</td>
#       <td>   895,473</td>
#       <td>      NaN</td>
#       <td>      0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>4_NoIndex_L004_R1.R03_FUS_k562_rep1</th>
#       <td> 37,736,609</td>
#       <td> 27,197,312</td>
#       <td>  4941664</td>
#       <td>   627,482</
