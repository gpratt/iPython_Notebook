# %%
from gscripts.general import parsers
from IPython.core.display import HTML
import glob
import os
from gscripts.general import dataviz
from gscripts.clipseq import clipseq_barcode_metrics

# %%
with dataviz.Figure("julia_out.svg", figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   "/nas3/gpratt/projects/julia/analysis/split_fastq_v2/B4P34_MeCP2_High_NoIndex_L007_R1.metrics",
                                                   "R01 R06".split())
    ax.set_title("B4P34_MeCP2_High.metrics")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-56b5bacc5b60> in <module>()
# ----> 1 glob.glob()
#
# TypeError: glob() takes exactly 1 argument (0 given)

# %%
analysis_dir = "/nas3/gpratt/projects/encode/analysis/split_fastq_v2/"

# %%
analysis_dir

# %%
glob.glob(os.path.join(analysis_dir, "*.metrics"))
# Out:
# ['/nas3/gpratt/projects/encode/analysis/split_fastq_v2/Fox2PhiX_S1_L001_R1_001.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/IMP3H_NoIndex_L003_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/BFH_NoIndex_L003_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/L3_NNNNNN_L008_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/IMP35_NoIndex_L006_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/L2_NNNNNN_L003_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/M3_NNNNNN_L007_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/PI63_NoIndex_L002_R1.fastq.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/H3_NNNNNN_L004_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/TC12_NoIndex_L003_R1.fastq.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/031314IMP3_S1_L001_R1_001.fastq.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/ZNL_NoIndex_L007_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/BSM_NoIndex_L008_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/BSH_NoIndex_L007_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/IMP3M_NoIndex_L004_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/BFM_NoIndex_L004_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/H1_NNNNNN_L002_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/M2_NNNNNN_L001_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/IMP3L_NoIndex_L005_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/HotnCold_S1_L001_R1_001.fastq.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/QC042314_S1_L001_R1_001.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/KI2_NoIndex_L002_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/HotnCold_S1_L001_R1_001.nophix.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/ZNH_NoIndex_L008_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/BPTM_NoIndex_L006_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/KPTH_NoIndex_L002_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/BPTH_NoIndex_L005_R1.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/HotnCold_S1_L001_R1_001.metrics',
#  '/nas3/gpratt/projects/encode/analysis/split_fastq_v2/KPTM_NoIndex_L001_R1.metrics']

# %%
file_name = "KI2_NoIndex_L002_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R01 R02 R03 R04 R07 R08".split())
    ax.set_title(file_name)
# Out:
# R08 AATG 79503583
# R02 TTGT 73464660
# R03 CAAT 47440869
# no barcode unassigned 5717745
# R01 GGTT 867843
# R09 TGGC 840396
# R11 AACC 720845
# R10 GGTC 456002
# R12 CCAC 436459
# R06 CCGG 262234
# R13 CGGA 261560
# R07 TTAG 139669
# R04 ACCT 136588
# R15 AATA 135309
# R05 GGCG 43378
# R16 TTAA 18760
# R14 GGCA 6312

# %%
file_name = "BFH_NoIndex_L003_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R02 R04 R06 R08 R10 R12 R14 R16".split())
    ax.set_title(file_name)
# Out:
# R09 TGGC 50085866
# R08 AATG 44153902
# R02 TTGT 37717305
# R11 AACC 18443619
# R03 CAAT 14632568
# no barcode unassigned 11660620
# R12 CCAC 11649477
# R06 CCGG 10674212
# R10 GGTC 8739470
# R13 CGGA 2369532
# R05 GGCG 1618895
# R07 TTAG 1460780
# R01 GGTT 684404
# R04 ACCT 630917
# R14 GGCA 225046
# R15 AATA 93353
# R16 TTAA 44990

# %%
file_name = "BFM_NoIndex_L004_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R02 R04 R06 R08 R10 R12 R14 R16".split())
    ax.set_title(file_name)
# Out:
# R09 TGGC 41387168
# R02 TTGT 38903123
# R08 AATG 36918858
# R06 CCGG 21254724
# R03 CAAT 19734413
# R11 AACC 17474519
# no barcode unassigned 11603694
# R12 CCAC 9523014
# R10 GGTC 6206882
# R05 GGCG 4588704
# R13 CGGA 3110527
# R07 TTAG 1768363
# R01 GGTT 1274362
# R04 ACCT 581701
# R14 GGCA 313313
# R15 AATA 70215
# R16 TTAA 51018

# %%
file_name = "BPTH_NoIndex_L005_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R01 R07 R03 R05 R09 R13 R11 R15".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 46997228
# R02 TTGT 37118927
# R08 AATG 36169657
# R11 AACC 16642617
# R03 CAAT 15500977
# no barcode unassigned 12382106
# R06 CCGG 10404849
# R12 CCAC 9269064
# R10 GGTC 7505380
# R15 AATA 3141885
# R13 CGGA 3009890
# R01 GGTT 2803567
# R05 GGCG 2433257
# R07 TTAG 1125583
# R04 ACCT 734706
# R16 TTAA 540048
# R14 GGCA 490216

# %%
file_name = "BPTM_NoIndex_L006_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R02 R04 R06 R08 R10 R12 R14 R16".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 46718665
# R08 AATG 31127333
# R02 TTGT 31119315
# R11 AACC 24336644
# R03 CAAT 12978865
# R06 CCGG 12393292
# no barcode unassigned 11053486
# R12 CCAC 8707232
# R10 GGTC 7423549
# R05 GGCG 3383857
# R13 CGGA 2849641
# R01 GGTT 1604586
# R15 AATA 1338588
# R07 TTAG 945425
# R14 GGCA 659614
# R04 ACCT 635578
# R16 TTAA 216066

# %%
file_name = "BSH_NoIndex_L007_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R02 R06 R04 R08 R10 R14 R12 R16".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 49198957
# R02 TTGT 33694338
# R08 AATG 29607924
# R06 CCGG 16119559
# R10 GGTC 12417655
# R11 AACC 11824990
# R03 CAAT 10801773
# no barcode unassigned 10681966
# R12 CCAC 9511029
# R13 CGGA 2879214
# R16 TTAA 2542682
# R04 ACCT 2024056
# R05 GGCG 1794390
# R01 GGTT 843509
# R07 TTAG 826941
# R14 GGCA 340898
# R15 AATA 170455

# %%
file_name = "BSM_NoIndex_L008_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R02 R06 R04 R08 R10 R14 R12 R16".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 37077853
# R10 GGTC 21880284
# R08 AATG 18726267
# R02 TTGT 16774732
# R04 ACCT 12073624
# R06 CCGG 9805246
# R11 AACC 7609882
# no barcode unassigned 7377987
# R03 CAAT 6855271
# R12 CCAC 6294247
# R16 TTAA 5789123
# R13 CGGA 1727113
# R05 GGCG 1123760
# R01 GGTT 514171
# R07 TTAG 512630
# R14 GGCA 240369
# R15 AATA 91333

# %%
file_name = "BSM_NoIndex_L008_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R02 R06 R04 R08 R10 R14 R12 R16".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 37077853
# R10 GGTC 21880284
# R08 AATG 18726267
# R02 TTGT 16774732
# R04 ACCT 12073624
# R06 CCGG 9805246
# R11 AACC 7609882
# no barcode unassigned 7377987
# R03 CAAT 6855271
# R12 CCAC 6294247
# R16 TTAA 5789123
# R13 CGGA 1727113
# R05 GGCG 1123760
# R01 GGTT 514171
# R07 TTAG 512630
# R14 GGCA 240369
# R15 AATA 91333

# %%
file_name = "KPTH_NoIndex_L002_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R09 R10 R11 R12 R13 R14 R15 R01 R02 R03 R04".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 42784721
# R02 TTGT 23434893
# R08 AATG 21681333
# no barcode unassigned 15917835
# R06 CCGG 15096377
# R11 AACC 11561438
# R14 GGCA 8257624
# R12 CCAC 8035507
# R03 CAAT 7974224
# R10 GGTC 6036102
# R13 CGGA 4491193
# R05 GGCG 1924062
# R01 GGTT 1055901
# R07 TTAG 691858
# R04 ACCT 386572
# R15 AATA 165656
# R16 TTAA 34269

# %%
file_name = "H3_NNNNNN_L004_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R11 R12 R04 R13 R07 R08 R09 R10".split()
                                                   )
    ax.set_title(file_name)
# Out:
# no barcode unassigned 45725358
# R04 ACCT 29677292
# R10 GGTC 25650717
# R07 TTAG 20522980
# R11 AACC 19655068
# R09 TGGC 11911943
# R12 CCAC 9984798
# R13 CGGA 9164683
# R08 AATG 8804358
# R16 TTAA 49315
# R01 GGTT 46591
# R05 GGCG 43850
# R15 AATA 31970
# R14 GGCA 28784
# R02 TTGT 13656
# R03 CAAT 12835
# R06 CCGG 8528

# %%
file_name = "M3_NNNNNN_L007_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R11 R12 R04 R13 R07 R08 R09 R10".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R10 GGTC 35630660
# R04 ACCT 33579958
# R07 TTAG 26072922
# R13 CGGA 16783054
# no barcode unassigned 14558399
# R08 AATG 14178680
# R09 TGGC 12490836
# R12 CCAC 4303338
# R11 AACC 2239967
# R16 TTAA 75727
# R01 GGTT 50892
# R15 AATA 36572
# R14 GGCA 23394
# R05 GGCG 14170
# R02 TTGT 11891
# R03 CAAT 9554
# R06 CCGG 7358

# %%
file_name = "L3_NNNNNN_L008_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R11 R12 R04 R13 R07 R08 R09 R10".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R07 TTAG 6054516
# R11 AACC 5113915
# R13 CGGA 3465628
# R10 GGTC 3244048
# R08 AATG 3005334
# R04 ACCT 2953091
# R12 CCAC 2470163
# R09 TGGC 2043594
# no barcode unassigned 1725555
# R16 TTAA 14689
# R01 GGTT 6192
# R15 AATA 4668
# R14 GGCA 3168
# R02 TTGT 2783
# R03 CAAT 1545
# R06 CCGG 1346
# R05 GGCG 1066

# %%
file_name = "ZNH_NoIndex_L008_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R09 R10 R11 R12".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 114515193
# R10 GGTC 64439194
# R11 AACC 25129743
# R12 CCAC 9507299
# no barcode unassigned 5300683
# R08 AATG 1184447
# R13 CGGA 658495
# R02 TTGT 407340
# R04 ACCT 335312
# R07 TTAG 333005
# R01 GGTT 170190
# R03 CAAT 164493
# R14 GGCA 161148
# R06 CCGG 133846
# R05 GGCG 52676
# R15 AATA 10053
# R16 TTAA 5924

# %%
file_name = "ZNL_NoIndex_L007_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R09 R10 R11 R12".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R09 TGGC 83313699
# R12 CCAC 65071691
# R10 GGTC 38226063
# R11 AACC 12345472
# no barcode unassigned 5400047
# R08 AATG 1146524
# R13 CGGA 514751
# R02 TTGT 246001
# R04 ACCT 187289
# R07 TTAG 161510
# R03 CAAT 144365
# R06 CCGG 113166
# R01 GGTT 108686
# R14 GGCA 102072
# R05 GGCG 41495
# R15 AATA 6686
# R16 TTAA 5188

# %%
file_name = "IMP35_NoIndex_L006_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R10 R09 R11 R12 R04 R13 R07 R08".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R13 CGGA 43700946
# R10 GGTC 30538480
# R09 TGGC 30518770
# R08 AATG 14863368
# R11 AACC 13952431
# R12 CCAC 11013839
# R07 TTAG 10350359
# R04 ACCT 7629903
# no barcode unassigned 5603660
# R01 GGTT 58977
# R14 GGCA 43215
# R16 TTAA 19449
# R15 AATA 16189
# R06 CCGG 15351
# R05 GGCG 12874
# R03 CAAT 5957
# R02 TTGT 5515

# %%
file_name = "IMP3H_NoIndex_L003_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R10 R09 R11 R12 R04 R13 R07 R08".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R10 GGTC 65098909
# R09 TGGC 61091902
# R13 CGGA 50890314
# R08 AATG 11870803
# no barcode unassigned 10566992
# R04 ACCT 9721917
# R07 TTAG 8476791
# R11 AACC 3776327
# R12 CCAC 2705676
# R01 GGTT 133506
# R14 GGCA 77778
# R05 GGCG 19081
# R16 TTAA 18670
# R15 AATA 17646
# R06 CCGG 17275
# R02 TTGT 5673
# R03 CAAT 4871

# %%
file_name = "IMP3M_NoIndex_L004_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R10 R09 R11 R12 R04 R13 R07 R08".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R13 CGGA 144716503
# R04 ACCT 23256262
# R11 AACC 12234913
# R12 CCAC 9998212
# no barcode unassigned 4940294
# R09 TGGC 1727883
# R10 GGTC 1463361
# R07 TTAG 508745
# R08 AATG 497840
# R06 CCGG 40690
# R14 GGCA 30754
# R15 AATA 6750
# R05 GGCG 6417
# R16 TTAA 5286
# R01 GGTT 4734
# R02 TTGT 3780
# R03 CAAT 3153

# %%
file_name = "IMP3L_NoIndex_L005_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R10 R09 R11 R12 R04 R13 R07 R08".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R13 CGGA 31246511
# R11 AACC 27040408
# R12 CCAC 20921326
# R08 AATG 19858342
# R09 TGGC 15803852
# R07 TTAG 14691567
# R10 GGTC 13741413
# R04 ACCT 5627128
# no barcode unassigned 3532627
# R16 TTAA 29264
# R14 GGCA 24451
# R15 AATA 24206
# R01 GGTT 22586
# R06 CCGG 13769
# R05 GGCG 10244
# R03 CAAT 8609
# R02 TTGT 7489

# %%
file_name = "H1_NNNNNN_L002_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R11 R12".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R11 AACC 81761879
# no barcode unassigned 28261948
# R12 CCAC 1348741
# R13 CGGA 727145
# R08 AATG 559872
# R09 TGGC 439637
# R07 TTAG 429714
# R04 ACCT 71886
# R10 GGTC 37954
# R15 AATA 33129
# R05 GGCG 15701
# R16 TTAA 12356
# R01 GGTT 9359
# R02 TTGT 9179
# R06 CCGG 8995
# R14 GGCA 8205
# R03 CAAT 7955

# %%
file_name = "M2_NNNNNN_L001_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R07 R12".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R12 CCAC 62746640
# R07 TTAG 52450239
# no barcode unassigned 17986277
# R11 AACC 633365
# R08 AATG 382139
# R09 TGGC 227005
# R16 TTAA 136365
# R13 CGGA 72419
# R02 TTGT 23108
# R10 GGTC 20900
# R15 AATA 9204
# R03 CAAT 9052
# R06 CCGG 8246
# R04 ACCT 7965
# R14 GGCA 4039
# R01 GGTT 3725
# R05 GGCG 3111

# %%
file_name = "L2_NNNNNN_L003_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "R07 R12".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R12 CCAC 82017587
# R07 TTAG 74012037
# no barcode unassigned 11594340
# R11 AACC 523435
# R08 AATG 432404
# R09 TGGC 217900
# R16 TTAA 159827
# R13 CGGA 58513
# R02 TTGT 36501
# R10 GGTC 19948
# R15 AATA 15212
# R03 CAAT 14673
# R04 ACCT 10658
# R06 CCGG 10475
# R01 GGTT 8485
# R14 GGCA 8262
# R05 GGCG 6751

# %%
file_name = "Fox2PhiX_S1_L001_R1_001"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "BSRclip02 BSRclip04 SBRclip36 SBRclip38R".split()
                                                   )
    ax.set_title(file_name)
# Out:
# R02 TTGT 5862921
# no barcode unassigned 4043717
# R03 CAAT 2849414
# R08 AATG 700667
# R07 TTAG 359238
# R13 CGGA 254877
# R09 TGGC 209907
# R14 GGCA 130952
# R06 CCGG 110629
# R05 GGCG 94224
# R11 AACC 83651
# R01 GGTT 74508
# R10 GGTC 61336
# R12 CCAC 53608
# R15 AATA 33596
# R16 TTAA 30262
# KERclip03 TTAGGC 21480
# R04 ACCT 18921
# RSRclip37 CGGAAT 8261
# rKERclip23 CCACTC 7783

# %%
file_name = "HotnCold_S1_L001_R1_001"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "BSRclip02 BSRclip04 BSRclip22 BSRclip20 BSRclip08 BSRclip10".split()
                                                   )
    ax.set_title(file_name)
# Out:
# no barcode unassigned 2673420
# BSRclip04 TGACCA 667721
# BSRclip02 CGATGT 311914
# BSRclip10 TAGCTT 288939
# R12 CCAC 285786
# R13 CGGA 227607
# rBSRclip22 CGTACG 101648
# BSRclip20 GTGGCC 81635
# R11 AACC 51538
# R04 ACCT 41727
# R08 AATG 38126
# BSRclip08 ACTTGA 34485
# rKERclip23 CCACTC 33605
# R10 GGTC 32088
# R07 TTAG 31684
# R09 TGGC 27741
# R02 TTGT 19566
# R16 TTAA 17599
# R15 AATA 16668
# R03 CAAT 15427

# %%
import pandas as pd

# %%
(1.0 / (4*4*4*4)) * 11565275
# Out:
# 45176.85546875

# %%
(result/ ) * 100
# Out:
#               num
# seq
# AAAATG   0.001630
# AACC     0.008484
# AAGCTA   0.000661
# AATA     0.010279
# AATG     0.016307
# ACAGTG  27.171385
# ACATCG   0.000908
# ACCT     0.008903
# ACTGAT   0.002180
# ACTTGA   0.001544
# AGCTAG   0.000168
# AGGAAT   0.000628
# AGTCAA   0.000260
# AGTTCC   0.000435
# ATCACG   0.003358
# ATCAGT   0.001235
# ATCGTG   0.000586
# ATGAGC  31.434494
# ATGTCA   0.002367
# ATTATA   0.002324
# ATTCCG   0.000475
# ATTCCT   0.003445
# ATTGGC   0.000533
# CAAAAG  33.005847
# CAACTA   0.002180
# CAAT     0.031148
# CACCGG   0.000443
# CACGAT   0.000524
# CACTCA   0.000403
# CACTGT   0.000455
# CAGATC   0.030218
# CAGGCG   0.000364
# CATGGC   0.000637
# CATTTT   0.003596
# CCAACA   0.000201
# CCAC     0.003733
# CCACTC   0.000683
# CCGG     0.002002
# CCGGTG   0.000021
# CCGTCC   0.000045
# CGAAAC   0.000063
# CGATGT   0.000407
# CGATTA   0.000006
# CGCCTG   0.000181
# CGGA     0.001510
# CGGAAT   0.000064
# CGTACG   0.000493
# CGTGAT   0.000192
# CTAGCT   0.000119
# CTATAC   0.000006
# CTCAGA   0.000295
# CTCTAC   0.000562
# CTGATC   0.000949
# CTTCGA   0.000091
# CTTGTA   0.001257
# CTTTTG   0.001254
# GAATGA   0.000255
# GACGAC   0.003132
# GAGTGG   0.000757
# GATCAG   0.003081
#               ...
#
# [112 rows x 1 columns]

# %%
result = pd.read_csv(os.path.join(analysis_dir, "%s.fastq.metrics" % file_name), sep="\t", 
            header=None, names=['seq', 'barcode', 'num']).groupby("seq").sum()

# %%
file_name = "TC12_NoIndex_L003_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.fastq.metrics" % file_name),
                                                   "KERclip05 KERclip07 SBRclip28 SBRclip26".split()
                                                   )
    ax.set_title(file_name)
# Out:
# SBRclip28 CAAAAG 47411436
# SBRclip26 ATGAGC 45154257
# KERclip05 ACAGTG 39030490
# no barcode unassigned 11565275
# KERclip03 TTAGGC 66372
# R03 CAAT 44743
# KERclip07 CAGATC 43407
# RSRclip47 TCGAAG 37415
# R02 TTGT 29095
# R16 TTAA 25456
# R08 AATG 23424
# R07 TTAG 16387
# R15 AATA 14765
# R04 ACCT 12789
# R11 AACC 12187
# R09 TGGC 12134
# rSBRclip40 TCTGAG 9691
# RSRclip45 TCATTC 8029
# R14 GGCA 6283
# RSRclip43 TACAGC 6035

# %%
file_name = "PI63_NoIndex_L002_R1"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.fastq.metrics" % file_name),
                                                   "BSRclip6 BSRclip8 BSRclip10 BSRclip12 BSRclip14 BSRclip16 BSRclip18 BSRclip24".split()
                                                   )
    ax.set_title(file_name)
# Out:
# no barcode unassigned 5121487
# BSRclip14 AGTTCC 4030254
# BSRclip12 CTTGTA 3750253
# BSRclip10 TAGCTT 1579359
# BSRclip06 GCCAAT 1374480
# BSRclip24 GGTAGC 1256263
# BSRclip18 GTCCGC 866594
# R09 TGGC 433015
# R08 AATG 328144
# R02 TTGT 263770
# R11 AACC 103926
# R10 GGTC 101317
# R03 CAAT 91757
# R13 CGGA 79167
# R14 GGCA 78093
# R12 CCAC 46591
# R01 GGTT 22614
# R16 TTAA 19007
# R05 GGCG 17558
# R07 TTAG 16347

# %%
clipseq_barcode_metrics.barcodes_df
# Out:
#               seq
# id
# R01          GGTT
# R02          TTGT
# R03          CAAT
# R04          ACCT
# R05          GGCG
# R06          CCGG
# R07          TTAG
# R08          AATG
# R09          TGGC
# R10          GGTC
# R11          AACC
# R12          CCAC
# R13          CGGA
# R14          GGCA
# R15          AATA
# R16          TTAA
# BSRclip02  CGATGT
# BSRclip04  TGACCA
# BSRclip06  GCCAAT
# BSRclip08  ACTTGA
# BSRclip10  TAGCTT
# BSRclip12  CTTGTA
# BSRclip14  AGTTCC
# BSRclip16  CCGTCC
# BSRclip18  GTCCGC
# BSRclip20  GTGGCC
# BSRclip22  CGTACG
# BSRclip24  GGTAGC
# KERclip01  ATCACG
# KERclip03  TTAGGC
# KERclip05  ACAGTG
# KERclip07  CAGATC
# KERclip09  GATCAG
# KERclip11  GGCTAC
# KERclip13  AGTCAA
# KERclip15  ATGTCA
# KERclip17  GTAGAG
# KERclip19  GTGAAA
# KERclip21  GTTTCG
# KERclip23  GAGTGG
# RSRclip25  ACTGAT
# RSRclip27  ATTCCT
# RSRclip29  CAACTA
# RSRclip31  CACGAT
# RSRclip33  CAGGCG
# RSRclip35  CATTTT
# RSRclip37  CGGAAT
# RSRclip39  CTATAC
# RSRclip41  GACGAC
# RSRclip43  TACAGC
# RSRclip45  TCATTC
# RSRclip47  TCGAAG
# SBRclip26  ATGAGC
# SBRclip28  CAAAAG
# SBRclip30  CACCGG
# SBRclip32  CACTCA
# SBRclip34  CATGGC
# SBRclip36  CCAACA
# SBRclip38  CTAGCT
# SBRclip40  CTCAGA
#               ...
#
# [112 rows x 1 columns]

# %%
file_name = "QC042314_S1_L001_R1_001"
with dataviz.Figure("%s.svg" % file_name, figsize=(6,6)) as fig:
    ax = fig.add_subplot(1,1,1)
    clipseq_barcode_metrics.plot_barcode_pie_chart(ax, 
                                                   os.path.join(analysis_dir, "%s.metrics" % file_name),
                                                   "BSRclip6 BSRclip8 BSRclip10 BSRclip12 BSRclip14 BSRclip16 BSRclip18 BSRclip24".split()
                                                   )
    ax.set_title(file_name)
# Out:
# no barcode unassigned 102253
# KERclip05 ACAGTG 96445
# BSRclip14 AGTTCC 39025
# SBRclip26 ATGAGC 38408
# BSRclip12 CTTGTA 38115
# SBRclip28 CAAAAG 37097
# BSRclip24 GGTAGC 25737
# BSRclip10 TAGCTT 13333
# BSRclip06 GCCAAT 7259
# BSRclip18 GTCCGC 4834
# R09 TGGC 2903
# R08 AATG 2115
# R02 TTGT 2001
# R14 GGCA 814
# R11 AACC 779
# R13 CGGA 729
# R10 GGTC 669
# R03 CAAT 622
# R12 CCAC 430
# R01 GGTT 182

# %%
barcode_distributions = {os.path.basename(file_name) : 
                         clipseq_barcode_metrics.parse_file(file_name) for file_name in glob.glob("/nas3/gpratt/projects/encode/data/*.gz")}
