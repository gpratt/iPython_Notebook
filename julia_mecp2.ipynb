# %%
from itertools import groupby, combinations
import glob
import os
from collections import defaultdict
import gffutils
import scipy.stats
from IPython.core.display import HTML
import pandas as pd

from gscripts.general import parsers

# %%
human_db = "/nas3/gpratt/gencode/gencode.v17.annotation.gtf.db"
db = gffutils.FeatureDB(human_db)
genes = db.features_of_type('gene')
gene_type_dict = {}
gene_name_dict = {}
gene_len_dict  = {} 
for gene in genes:
    gene_id = gene.attributes['gene_id'][0] if type(gene.attributes['gene_id']) == list else gene.attributes['gene_id']
    try:      
        gene_type_dict[gene_id] = gene.attributes['gene_type'][0]
    except KeyError:
        pass
    
    try:
        gene_name_dict[gene_id] = gene.attributes['gene_name'][0]
    except KeyError:
        pass
    
    try:
        gene_len_dict[gene_id] = len(gene)
    except KeyError:
        pass
gene_id_dict = {value[0] : name for name, value in gene_name_dict.items()}

gene_type_dict = defaultdict(str, gene_type_dict.items())
gene_name_dict = defaultdict(str, gene_name_dict.items())

# %%
def plot_rpkm_vs_rpkm(name1, name2, **kwargs):
    if "ax" in kwargs: 
        ax = kwargs['ax']
        del kwargs['ax']
        
        ax.loglog(master_df.ix[name2].RPKM, master_df.ix[name1].RPKM, "o", alpha=.05)
        ax.set_title(name2 + " vs " + name1 + " " + str(scipy.stats.linregress(master_df.ix[name1].RPKM, master_df.ix[name2].RPKM)[2]))
        #print str(scipy.stats.linregress(master_df.ix[name1].RPKM, master_df.ix[name2].RPKM))
        ax.set_xlabel(name1, fontsize=18)
        ax.set_ylabel(name2, fontsize=18)
    else:
        loglog(master_df.ix[name2].RPKM, master_df.ix[name1].RPKM, "o", alpha=.05)
        title(name2 + " vs " + name1 + " " + str(scipy.stats.linregress(master_df.ix[name1].RPKM, master_df.ix[name2].RPKM)[2]))
        xlabel(name1)
        ylabel(name2)

# %% [markdown]
# #Basic Mapping QC

# %%
mecp2_qc = parsers.rnaseq_metrics("/nas3/gpratt/projects/julia/analysis/mecp2_ripseq_v1/")

# %%
HTML(mecp2_qc.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Processed bases</th>
#       <th>Processed reads</th>
#       <th>Quality-trimmed</th>
#       <th>Too long reads</th>
#       <th>Too short reads</th>
#       <th>Trimmed bases</th>
#       <th>Trimmed reads</th>
#       <th>% of reads mapped to multiple loci</th>
#       <th>% of reads mapped to too many loci</th>
#       <th>% of reads unmapped: other</th>
#       <th>% of reads unmapped: too many mismatches</th>
#       <th>% of reads unmapped: too short</th>
#       <th>Average input read length</th>
#       <th>Average mapped length</th>
#       <th>Deletion average length</th>
#       <th>Deletion rate per base</th>
#       <th>Finished on</th>
#       <th>Insertion average length</th>
#       <th>Insertion rate per base</th>
#       <th>Mapping speed, Million of reads per hour</th>
#       <th>Mismatch rate per base, percent</th>
#       <th>Number of input reads</th>
#       <th>Number of reads mapped to multiple loci</th>
#       <th>Number of reads mapped to too many loci</th>
#       <th>Number of splices: AT/AC</th>
#       <th>Number of splices: Annotated (sjdb)</th>
#       <th>Number of splices: GC/AG</th>
#       <th>Number of splices: GT/AG</th>
#       <th>Number of splices: Non-canonical</th>
#       <th>Number of splices: Total</th>
#       <th>Started job on</th>
#       <th>Started mapping on</th>
#       <th>Uniquely mapped reads %</th>
#       <th>
#       <td> 0</td>
#       <td> 1706</td>
#       <td> 214046</td>
#       <td> 582</td>
#       <td> 216490</td>
#       <td> Mar 17 22:25:56</td>
#       <td> Mar 17 22:40:54</td>
#       <td> 86.23%</td>
#       <td> 5026393</td>
#       <td> 0.403997</td>
#       <td> 0.788274</td>
#     </tr>
#     <tr>
#       <th>Undetermined_S0_L001_R1_001</th>
#       <td>   8560299</td>
#       <td>  172955</td>
#       <td>  2975</td>
#       <td> 0</td>
#       <td> 5480</td>
#       <td>  568441</td>
#       <td>   9006</td>
#       <td>  7.60%</td>
#       <td> 0.09%</td>
#       <td> 0.01%</td>
#       <td> 0.00%</td>
#       <td> 39.90%</td>
#       <td> 49</td>
#       <td> 48.83</td>
#       <td> 1.45</td>
#       <td> 0.01%</td>
#       <td> Mar 17 22:20:02</td>
#       <td> 1.29</td>
#       <td> 0.00%</td>
#       <td>   59.62</td>
#       <td> 0.43%</td>
#       <td>  165605</td>
#       <td>  12589</td>
#       <td>  154</td>
#       <td>   1</td>
#       <td> 0</td>
#       <td>   36</td>
#       <td>   4108</td>
#       <td>  20</td>
#       <td>   4165</td>
#       <td> Mar 17 22:18:55</td>
#       <td> Mar 17 22:19:52</td>
#       <td> 52.40%</td>
#       <td>   86771</td>
#       <td> 0.658881</td>
#       <td> 0.912356</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 5 million reads mapped for EGFP and MeCP2 input good PCB and NRF scores (not a lot of duplicate reads) most reads uniquely mapped, overall a good start to the QC

# %% [markdown]
# #Code For Loading RPKMs

# %%
datasets = glob.glob("/nas3/gpratt/projects/julia/analysis/mecp2_ripseq_v1/*.rpkm")
datasets = {os.path.basename(dataset).split("_")[0] : pd.read_csv(dataset, index_col=0, sep="\t") for dataset in datasets}
ripseq_df = pd.concat(datasets, join="outer")
ripseq_df = ripseq_df.drop("flag",1)
ripseq_df['gene_id'] = ripseq_df.index.get_level_values(1)
ripseq_df['gene_name'] = ripseq_df.gene_id.apply(lambda x: gene_name_dict[x])
ripseq_df['gene_type'] = ripseq_df.gene_id.apply(lambda x: gene_type_dict[x])
ripseq_df = ripseq_df.drop("gene_id",1)

# %%
ripseq_df["logged_rpkm"] = ripseq_df.RPKM.apply(log10)
logged_rpkm_df = ripseq_df[ripseq_df.logged_rpkm != np.NINF].logged_rpkm
def plot_hist2d(name1, name2):
    x = logged_rpkm_df.ix[name2]
    y = logged_rpkm_df.ix[name1]
    x.name = "one"
    y.name = "two"
    foo = pd.concat([x, y], axis=1, join="inner")
    hist2d(foo.one, foo.two, bins=175, norm=Normalize(), cmin=1, vmin=0, vmax=45)
    xlabel(name1, fontsize=18)
    ylabel(name2, fontsize=18)
    colorbar()

# %% [markdown]
# #Correlations between all combinations of RPKMs

# %%
figsize(15,15)
ys = len(list(combinations(set(ripseq_df.index.get_level_values(level=0)), 2)))
for x, (name1, name2) in enumerate(combinations(set(ripseq_df.index.get_level_values(level=0)), 2)):
    subplot((ys / 3) + 1, 3 , x + 1)
    #plot_rpkm_vs_rpkm(name1, name2)
    plot_hist2d(name1, name2)
    #loglog(ripseq_df.ix[name1].RPKM, ripseq_df.ix[name2].RPKM, 'o')
    title(name2 + " vs " + name1 + " " + str(scipy.stats.linregress(ripseq_df.ix[name1].RPKM, ripseq_df.ix[name2].RPKM)[2]))
    xlim((-4,5))
    ylim((-4,5))
tight_layout()

# %% [markdown]
# EGFP and Input are well correlated, hopefully this is expected, Also somewhat correlated to MeCP2 IP, there is less of the seperation that we saw in the UPF1 RIP, could be from lower read coverage.  Additionally I filter out genes that have a 0 count. This could throw off correlations.  I'm going to check for number of genes that have 0 rpkm (no read coverage) in the controls, but are enriched in MeCP2-IP.
#
# First I'll look at all genes sorted by the rpmk of the ip sample (I do this because its a quick way of getting at potentally enriched genes)

# %%
mecp2_combined = ripseq_df.ix['MeCP2-IP'] 
mecp2_input = ripseq_df.ix['MeCP2-input']

mecp2_combined["Log2 IP / Input Fold Change"] = (mecp2_combined.RPKM / mecp2_input.RPKM).apply(log2)

mecp2_combined = mecp2_combined.drop("RPKM", 1)

mecp2_combined['ip_rpkm'] = ripseq_df.ix['MeCP2-IP'].RPKM
mecp2_combined['input_rpkm'] = ripseq_df.ix['MeCP2-input'].RPKM
mecp2_combined.sort("ip_rpkm", ascending=False)
# Out:
#                         gene_name             gene_type  \
# gene
# ENSG00000210151.2          MT-TS1               Mt_tRNA
# ENSG00000258017.1  RP11-386G11.10             antisense
# ENSG00000210135.1           MT-TN               Mt_tRNA
# ENSG00000198804.2          MT-CO1        protein_coding
# ENSG00000198727.2          MT-CYB        protein_coding
# ENSG00000198786.2          MT-ND5        protein_coding
# ENSG00000228253.1         MT-ATP8        protein_coding
# ENSG00000198899.2         MT-ATP6        protein_coding
# ENSG00000258232.2   RP11-161H23.5             antisense
# ENSG00000264558.1    RP11-138C9.1             antisense
# ENSG00000198886.2          MT-ND4        protein_coding
# ENSG00000210140.1           MT-TC               Mt_tRNA
# ENSG00000210144.1           MT-TY               Mt_tRNA
# ENSG00000198938.2          MT-CO3        protein_coding
# ENSG00000198712.1          MT-CO2        protein_coding
# ENSG00000212907.2         MT-ND4L        protein_coding
# ENSG00000262477.1      AC021224.1               lincRNA
# ENSG00000198763.3          MT-ND2        protein_coding
# ENSG00000269968.1     RP5-940J5.9             antisense
# ENSG00000234961.1   RP11-124N14.3             antisense
# ENSG00000237973.1    hsa-mir-6723            pseudogene
# ENSG00000258092.1     RP4-816N1.7             antisense
# ENSG00000198840.2          MT-ND3        protein_coding
# ENSG00000248527.1        MTATP6P1            pseudogene
# ENSG00000198888.2          MT-ND1        protein_coding
# ENSG00000229939.1   RP11-111F16.2            pseudogene
# ENSG00000262831.1    RP11-498C9.2             antisense
# ENSG00000227751.1     RP1-20B21.4             antisense
# ENSG00000225972.1        MTND1P23            pseudogene
# ENSG00000225630.1        MTND2P28            pseudogene
# ENSG00000210156.1           MT-TK               Mt_tRNA
# ENSG00000210082.2         MT-RNR2               Mt_rRNA
