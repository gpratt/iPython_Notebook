# %%
import pickle
from IPython.display import Image
path = "/nas3/gpratt/projects/upf1/scripts/"
import pybedtools
from pybedtools.scripts import venn_mpl
import matplotlib.pyplot as plt

# %%
pickled_files = {}
pickled_files['WT'] = pickle.load(open("/nas3/gpratt/projects/upf1/scripts/assigned/WT_NoIndex_L006_R1.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed.pickle"))
pickled_files['DEAA'] = pickle.load(open("/nas3/gpratt/projects/upf1/scripts/assigned/UPF1_1_2.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed.pickle"))
pickled_files['K498A'] = pickle.load(open("/nas3/gpratt/projects/upf1/scripts/assigned/UPF1_3_4.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed.pickle"))

# %%
Image(filename=path + "UPF1_1_2.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed.QCfig.png")

# %%
Image(filename=path + "UPF1_3_4.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed.QCfig.png")

# %%
Image(filename=path + "WT_NoIndex_L006_R1.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed.QCfig.png")

# %%
beds = { 'DEAA' : pybedtools.BedTool(path + "UPF1_1_2.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed"),
         'K498A': pybedtools.BedTool(path + 'UPF1_3_4.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed'),
         'WT'   : pybedtools.BedTool(path + 'WT_NoIndex_L006_R1.polyATrim.adapterTrim.rmRep.sorted.rmDup.peaks.bed')
         }

# %%
for name, bed in beds.items():
    print name, len(bed)
# Out:
# WT 1229
# K498A
# 74321
# DEAA
# 77123

# %%
sizes = {'100' : len(beds['DEAA'] - beds['K498A'] - beds['WT']), 
         '010' : len(beds['K498A'] - beds['DEAA'] - beds['WT']),  
         '110' : len(beds['DEAA'] + beds['K498A'] - beds['WT']), 
         '001' : len(beds['WT'] - beds['K498A'] - beds['DEAA']), 
         '101' : len(beds['DEAA'] + beds['WT'] - beds['K498A']), 
         '011' : len(beds['WT'] + beds['K498A'] - beds['DEAA']), 
         '111' : len(beds['WT'] + beds['K498A'] + beds['DEAA'])}

matplotlib_venn.venn3(sizes, set_labels=['DEAA', 'K498A', 'WT'])
# Out:
# <matplotlib_venn._venn3.Venn3 instance at 0x272de3f8>

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ind = np.arange(5)

width = .20

K498A_region = array(pickled_files['K498A']['region_sizes'].values())
DEAA_region = array(pickled_files['DEAA']['region_sizes'].values())
WT_region = array(pickled_files['WT']['region_sizes'].values())
genic_region = array(pickled_files['WT']['genic_region_sizes'].values())

K498A_region = K498A_region / (sum(K498A_region) * 1.0)
DEAA_region = DEAA_region / (sum(DEAA_region) * 1.0)
WT_region = WT_region / (sum(WT_region) * 1.0)
genic_region = genic_region / (sum(genic_region) * 1.0)

ax.bar(ind + (width * 0), K498A_region, width, color='r', label="K498A") 
ax.bar(ind + (width * 1), DEAA_region, width, color='y', label="DEAA")
ax.bar(ind + (width * 2), WT_region, width, color='g', label="WT")
ax.bar(ind + (width * 3), genic_region, width, color='w', label="Genic")
ax.set_ylabel('% In Region')
ax.set_xticks(ind+width * 3)
ax.set_xticklabels(pickled_files['WT']['genic_region_sizes'].keys() )
ax.legend(loc=0)

# %%
def generate_distribution(dist):
    count, bins = np.histogram(dist, range=(0, 1.0), 
                                    bins=50, 
                                    density=True
                                    )
    return count, [(bins[x] + bins[x+1]) / 2 for x in range(len(bins) - 1)]

# %%
k498a_count, bins = generate_distribution(pickled_files['K498A']['mRNA_positions'])
DEAA_count, bins = generate_distribution(pickled_files['DEAA']['mRNA_positions'])
WT_count, bins = generate_distribution(pickled_files['WT']['mRNA_positions'])

plot(bins, k498a_count, label="K498A")
plot(bins, DEAA_count, label="DEAA")
plot(bins, WT_count, label="WT")
legend(loc=0)

# %%
x = pickled_files['WT']['kmer_results']

# %%
y = x['UTR3'][6]

# %%
print y[0]
# Out:
# {'GAACGT': Motif(freq1=15.0, freq2=10.0, delta=4.041724882724358), 'CGTCGT': Motif(freq1=2.0, freq2=5.0, delta=0.21822201728271504), 'CTTCTT': Motif(freq1=16.0, freq2=88.0, delta=-2.265190626015971), 'CACCCT': Motif(freq1=16.0, freq2=44.0, delta=0.29819073840600663), 'GAACGG': Motif(freq1=6.0, freq2=6.0, delta=2.0000648441848443), 'GAACGC': Motif(freq1=5.0, freq2=14.0, delta=0.13246003538357135), 'GAACGA': Motif(freq1=4.0, freq2=10.0, delta=0.3086183733062419), 'CACCCA': Motif(freq1=9.0, freq2=59.0, delta=-2.2408598546500627), 'CTTCTA': Motif(freq1=10.0, freq2=36.0, delta=-0.5108174060948917), 'CACCCC': Motif(freq1=20.0, freq2=45.0, delta=1.0743609973735662), 'CTTCTC': Motif(freq1=34.0, freq2=75.0, delta=1.49354330464375), 'CACCCG': Motif(freq1=3.0, freq2=22.0, delta=-1.5012120992976186), 'CTTCTG': Motif(freq1=42.0, freq2=72.0, delta=2.9208853367200325), 'CGTGTG': Motif(freq1=8.0, freq2=10.0, delta=1.9052513449311022), 'TAAGGT': Motif(freq1=7.0, freq2=22.0, delta=-0.10721965442774851), 'CGTGTC': Motif(freq1=7.0, freq2=6.0, delta=2.4020066723775066), 'CGTGTA': Motif(freq1=8.0, freq2=13.0, delta=1.3859483696294916), 'GGCAAC': Motif(freq1=3.0, freq2=23.0, delta=-1.5852992101860621), 'GGAAAT': Motif(freq1=17.0, freq2=59.0, delta=-0.5299217627990989), 'TAAGGG': Motif(freq1=8.0, freq2=16.0, delta=0.9428701802392419), 'CGTGTT': Motif(freq1=8.0, freq2=13.0, delta=1.3859483696294916), 'TAAGGC': Motif(freq1=6.0, freq2=25.0, delta=-0.7259269874197193), 'TAAGGA': Motif(freq1=14.0, freq2=45.0, delta=-0.22552976090635218), 'GTCAAA': Motif(freq1=4.0, freq2=25.0, delta=-1.3938555075607288), 'GTCAAC': Motif(freq1=6.0, freq2=16.0, delta=0.24619761579197086), 'GTCAAG': Motif(freq1=14.0, freq2=27.0, delta=1.3526542939456816), 'CTGTCC': Motif(freq1=37.0, freq2=51.0, delta=3.693622994319768), 'TCAGAG': Motif(freq1=16.0, freq2=56.0, delta=-0.5444369698183343), 'CTGTCA': Motif(freq1=16.0, freq2=44.0, delta=0.29819073840600663), 'CTCGCC': Motif(freq1=7.0, freq2=9.0, delta=1.732125684397875), 'CTGTCG': Motif(freq1=6.0, freq2=10.0, delta=1.1547504562652497), 'GTATCT': Motif(freq1=16.0, freq2=29.0, delta=1.6354584811812756), 'CTGTGC': Motif(freq1=28.0, freq2=61.0, delta=1.4079157182164346), 'TCAGAA': Motif(freq1=14.0, freq2=66.0, delta=-1.5495282847245533), 'GTCAAT': Motif(freq1=6.0, freq2=24.0, delta=-0.6325067996029823), 'GTATCA': Motif(freq1=5.0, freq2=17.0, delta=-0.2461976157919711), 'TCAGAT': Motif(freq1=11.0, freq2=43.0, delta=-0.7857888502411058), 'GTATCG': Motif(freq1=1.0, freq2=5.0, delta=-0.4714121625656792), 'CTGTCT': Motif(freq1=33.0, freq2=72.0, delta=1.5217093975376779), 'GGTGTC': Motif(freq1=5.0, freq2=37.0, delta=-1.960138207065424), 'GGTGTA': Motif(freq1=9.0, freq2=21.0, delta=0.6325067996029823), 'GGTGTG': Motif(freq1=13.0, freq2=28.0, delta=0.9919464822268332), 'TATCCT': Motif(freq1=12.0, freq2=19.0, delta=1.7629655408764604), 'CCGGGG': Motif(freq1=4.0, freq2=25.0, delta=-1.3938555075607288), 'TTCTGT': Motif(freq1=49.0, freq2=73.0, delta=3.869317534318855), 'ATTCCT': Motif(freq1=13.0, freq2=45.0, delta=-0.45493011890067625), 'CCGGGC': Motif(freq1=7.0, freq2=21.0, delta=0.0), 'CCGGGA': Motif(freq1=3.0, freq2=22.0, delta=-1.5012120992976186), 'TATCCA': Motif(freq1=4.0, freq2=25.0, delta=-1.3938555075607288), 'AGGCAG': Motif(freq1=11.0, freq2=88.0, delta=-3.1922776428605686), 'TATCCC': Motif(freq1=7.0, freq2=15.0, delta=0.7385928473759128), 'AGAGGT': Motif(freq1=6.0, freq2=43.0, delta=-2.0622382720611885), 'TATCCG': Motif(freq1=3.0, freq2=1.0, delta=2.309426034487699), 'GGTGTT': Motif(freq1=10.0, freq2=34.0, delta=-0.3481967063334734), 'ATTCCG': Motif(freq1=1.0, freq2=5.0, delta=-0.4714121625656792), 'TTCTGG': Motif(freq1=25.0, freq2=58.0, delta=1.0775728899827928), 'CCGGGT': Motif(freq1=8.0, freq2=15.0, delta=1.0835400103053299), 'ATTCCC': Motif(freq1=19.0, freq2=29.0, delta=2.3336359836869773), 'TTCTGC': Motif(freq1=31.0, freq2=69.0, delta=1.3860151577045576), 'ATTCCA': Motif(freq1=8.0, freq2=48.0, delta=-1.851920408412419), 'TTCTGA':  ...
