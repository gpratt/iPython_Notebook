# %%
cd /nas3/gpratt/projects/chen_ago/v3
# Out:
# /nas/nas0/gpratt/projects/chen_ago/v3

# %%
import pybedtools
import pysam
from collections import defaultdict, Counter
import pandas as pd
from matplotlib_venn import venn3
from IPython.core.display import HTML
import pysam
from matplotlib_venn import venn2

# %%
def parse_star_file(star_file):
    star_dict = {}

    star_dict["Started job on"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Started mapping on"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Finished on"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Mapping speed, Million of reads per hour"] = star_file.next().strip().split("|")[1].strip()
    star_file.next()
    star_dict["Number of input reads"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Average input read length"] = star_file.next().strip().split("|")[1].strip()
    star_file.next()
    star_dict["Uniquely mapped reads number"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Uniquely mapped reads %"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Average mapped length"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of splices: Total"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of splices: Annotated (sjdb)"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of splices: GT/AG"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of splices: GC/AG"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of splices: AT/AC"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of splices: Non-canonical"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Mismatch rate per base, percent"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Deletion rate per base"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Deletion average length"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Insertion rate per base"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Insertion average length"] = star_file.next().strip().split("|")[1].strip()
    star_file.next()
    star_dict["Number of reads mapped to multiple loci"] = star_file.next().strip().split("|")[1].strip()
    star_dict["% of reads mapped to multiple loci"] = star_file.next().strip().split("|")[1].strip()
    star_dict["Number of reads mapped to too many loci"] = star_file.next().strip().split("|")[1].strip()
    star_dict["% of reads mapped to too many loci"] = star_file.next().strip().split("|")[1].strip()
    star_file.next()
    star_dict["% of reads unmapped: too many mismatches"] = star_file.next().strip().split("|")[1].strip()
    star_dict["% of reads unmapped: too short"] = star_file.next().strip().split("|")[1].strip()
    star_dict["% of reads unmapped: other"] = star_file.next().strip().split("|")[1].strip()
    return star_dict

def parse_peak_metrics(fn):
    with open(fn) as file_handle:
        file_handle.next()
        return {'spot' : float(file_handle.next())}
    
def parse_nrf_file(nrf_file):
    with open(nrf_file) as nrf_file:
        names = nrf_file.next().strip().split()
        values = nrf_file.next().strip().split()
        return {name : float(value) for name, value in zip(names, values)} 
    
def parse_rm_duped_metrics_file(nrf_file):
    total_count = 0
    removed_count = 0 
    
    with open(nrf_file) as nrf_file:
        df = pd.read_csv(nrf_file, sep="\t")
        sum(df.total_count) - sum(df.removed_count)
        
        return {"total_count" : sum(df.total_count), 
                "removed_count" : sum(df.removed_count), 
                "Usable Reads" : sum(df.total_count) - sum(df.removed_count)}
    
def commas(x):
    try:        
        return "{:,}".format(int(x))
    except ValueError:
        return 0

# %%
spot_files = !ls *peaks.metrics
spot_df = pd.DataFrame({".".join(spot_file.split(".")[0:2]): parse_peak_metrics(spot_file) for spot_file in spot_files}).transpose().fillna(0)

nrf_files = !ls *.NRF.metrics
nrf_frame = pd.DataFrame({".".join(nrf_file.split(".")[0:2]) : parse_nrf_file(nrf_file) for nrf_file in nrf_files}).transpose().fillna(0)

qc_files = !ls *.final.out
star_frame = pd.DataFrame({".".join(qc_file.split(".")[0:2]) : parse_star_file(open(qc_file)) for qc_file in qc_files}).transpose().fillna(0)

rm_duped_metrics = !ls *.rmDup.metrics
rm_duped_metrics = pd.DataFrame({".".join(rm_duped_metric.split(".")[0:2]) : parse_rm_duped_metrics_file(rm_duped_metric) for rm_duped_metric in rm_duped_metrics}).transpose().fillna(0)

peaks_files = !ls *.peaks.bed
peaks_metrics = pd.DataFrame({".".join(peaks_file.split(".")[0:2]) : {"Num Peaks" : len(pybedtools.BedTool(peaks_file))} for peaks_file in peaks_files}).transpose().fillna(0)

ago1_normoxia = pysam.Samfile("AGO1_normoxia.bam")
ago1_hypoxia = pysam.Samfile("AGO1_hypoxia.bam")

# %%
combined_df = pd.merge(nrf_frame, star_frame, left_index=True, right_index=True, how="outer")
combined_df = pd.merge(combined_df, spot_df, left_index=True, right_index=True, how="outer")
combined_df = pd.merge(combined_df, rm_duped_metrics, left_index=True, right_index=True, how="outer")
combined_df = pd.merge(combined_df, peaks_metrics, left_index=True, right_index=True, how="outer").fillna(0)

combined_df['Usable Reads'].ix['AGO1_normoxia.peaks'] = ago1_normoxia.mapped
combined_df['Usable Reads'].ix['AGO1_hypoxia.peaks'] = ago1_hypoxia.mapped

# %%
filtered_df = combined_df[["Number of input reads", 
                                                  "Uniquely mapped reads number",
                                                  "Uniquely mapped reads %",
                                                  "Usable Reads",
                                                  "spot",
                                                  "Num Peaks"]]


filtered_df = filtered_df.rename(index={"AGO1_hypoxia.peaks" : "Hypoxia",
                          "AGO1_normoxia.peaks" : "Normoxia"})
HTML(filtered_df.to_html(formatters={"Number of input reads" : commas,
                             "Uniquely mapped reads number" : commas,
                             "Usable Reads" : commas,
                             "Num Peaks": commas
                             } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Number of input reads</th>
#       <th>Uniquely mapped reads number</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Usable Reads</th>
#       <th>spot</th>
#       <th>Num Peaks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Hypoxia</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>      0</td>
#       <td>1,671,928</td>
#       <td> 0.298583</td>
#       <td>36,511</td>
#     </tr>
#     <tr>
#       <th>Normoxia</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>      0</td>
#       <td>5,113,585</td>
#       <td> 0.253018</td>
#       <td>49,587</td>
#     </tr>
#     <tr>
#       <th>ZNH_NoIndex_L008_R1.R09_AGO1_normoxia_LowRNAse_H</th>
#       <td> 77,432,534</td>
#       <td> 49,217,010</td>
#       <td> 63.56%</td>
#       <td>2,269,433</td>
#       <td> 0.176071</td>
#       <td>19,100</td>
#     </tr>
#     <tr>
#       <th>ZNH_NoIndex_L008_R1.R10_AGO1_normoxia_HighRNAse_H</th>
#       <td> 55,357,061</td>
#       <td> 36,104,420</td>
#       <td> 65.22%</td>
#       <td>1,529,535</td>
#       <td> 0.185076</td>
#       <td>12,193</td>
#     </tr>
#     <tr>
#       <th>ZNH_NoIndex_L008_R1.R11_AGO1_hypoxia_LowRNAse_H</th>
#       <td> 19,192,769</td>
#       <td>  9,814,827</td>
#       <td> 51.14%</td>
#       <td>  428,600</td>
#       <td> 0.071511</td>
#       <td> 1,924</td>
#     </tr>
#     <tr>
#       <th>ZNH_NoIndex_L008_R1.R12_AGO1_hypoxia_HighRNase_H</th>
#       <td>  8,204,751</td>
#       <td>  5,468,713</td>
#       <td> 66.65%</td>
#       <td>  217,326</td>
#       <td> 0.063691</td>
#       <td>   856</td>
#     </tr>
#     <tr>
#       <th>ZNL_NoIndex_L007_R1.R09_AGO1_normoxia_LowRNAse_L</th>
#       <td> 45,306,658</td>
#       <td> 16,665,344</td>
#       <td> 36.78%</td>
#       <td>  668,411</td>
#       <td> 0.147214</td>
#       <td> 8,460</td>
#     </tr>
#     <tr>
#       <th>ZNL_NoIndex_L007_R1.R10_AGO1_normoxia_HighRNAse_L</th>
#       <td> 30,283,196</td>
#       <td> 24,245,170</td>
#       <td> 80.06%</td>
#       <td>  646,206</td>
#       <td> 0.107277</td>
#       <td> 3,223</td>
#     </tr>
#     <tr>
#       <th>ZNL_NoIndex_L007_R1.R11_AGO1_hypoxia_LowRNAse_L</th>
#       <td> 10,114,688</td>
#       <td>  6,399,542</td>
#       <td> 63.27%</td>
#       <td>  311,846</td>
#       <td> 0.051976</td>
#       <td>   995</td>
#     </tr>
#     <tr>
#       <th>ZNL_NoIndex_L007_R1.R12_AGO1_hypoxia_HighRNase_L</th>
#       <td> 55,149,422</td>
#       <td> 39,260,347</td>
#       <td> 71.19%</td>
#       <td>  714,156</td>
#       <td> 0.300793</td>
#       <td>22,396</td>
#     </tr>
#   </tbody>
# </table>

# %%
hypoxia_peaks = pybedtools.BedTool("AGO1_hypoxia.peaks.bed")
normoxia_peaks = pybedtools.BedTool("AGO1_normoxia.peaks.bed")
targetscan_mirnas = pybedtools.BedTool("targetScanS_20131012.bed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-323-36052d913514> in <module>()
#       1 hypoxia_peaks = pybedtools.BedTool("AGO1_hypoxia.peaks.bed")
#       2 normoxia_peaks = pybedtools.BedTool("AGO1_normoxia.peaks.bed")
# ----> 3 targetscan_mirnas = pybedtools.BedTool("targetScanS_20131012.bed")
#
# /nas3/yeolab/Software/Python-2.7.5/lib/python2.7/site-packages/pybedtools-0.6.2-py2.7-linux-x86_64.egg/pybedtools/bedtool.pyc in __init__(self, fn, from_string)
#     364             elif isinstance(fn, basestring):
#     365                 if not os.path.exists(fn):
# --> 366                     raise ValueError('File "%s" does not exist' % fn)
#     367                 self._isbam = isBAM(fn)
#     368
#
# ValueError: File "targetScanS_20131012.bed" does not exist

# %%
hypoxia_targets = pd.Series(Counter([interval.name.split(":")[1] for interval in targetscan_mirnas.intersect(hypoxia_peaks, u=True, s=True)]), name="hypoxia")
normoxia_targets = pd.Series(Counter([interval.name.split(":")[1] for interval in targetscan_mirnas.intersect(normoxia_peaks, u=True, s=True)]), name="normoxia")
combined_results = pd.concat({"Hypoxia" : hypoxia_targets, "Normoxia" : normoxia_targets}, axis=1).fillna(0).astype(float)

# %%
merged_df = filtered_df.ix[['Hypoxia', 'Normoxia']]

# %%
#number of peaks overlapping targetscan reads 
combined_results.sum()
# Out:
# Hypoxia     1848
# Normoxia    4744
# dtype: float64

# %% [markdown]
# Target scan is not a great measure of actual targets / my peaks are not real.  One or the other...

# %% [markdown]
# number of reads
# hypoxia, normoxia
# 1671928, 5113585

# %%
#trying to normalize for variable number of reads, by dividing by total number of peaks
read_normalized = combined_results / merged_df['Usable Reads'] 
print read_normalized.sum()
print "fold change", log2(read_normalized['Hypoxia'].sum() / read_normalized['Normoxia'].sum())
# Out:
# Hypoxia     0.001105
# Normoxia    0.000928
# dtype: float64
# fold change 0.252683107849

# %%
#trying to normalize for variable number of reads, by dividing by total number of peaks
peak_normalized = combined_results / array([len(hypoxia_peaks), len(normoxia_peaks)])
print peak_normalized.sum()
print "fold change", log2(peak_normalized['Hypoxia'].sum() / peak_normalized['Normoxia'].sum())
# Out:
# Hypoxia     0.050615
# Normoxia    0.095670
# dtype: float64
# fold change -0.918508491093

# %%
normalized_results = (peak_normalized *1000)

# %%
figsize(20,10)
subplot(1,2,1)
scatter(combined_results.Hypoxia, combined_results.Normoxia)
title("unnormalized binding events per miRNA")
xlabel("hypoxia")
ylabel("normoxia")
plot((0,350), (0,350))
xlim(0,80)
ylim(0,350)

subplot(1,2,2)
scatter(normalized_results.Hypoxia, normalized_results.Normoxia)
title("normalized binding events per miRNA")
xlabel("hypoxia")
ylabel("normoxia")
plot((-1,6), (-1,6))
xlim(-1,2)
ylim(-1,6)
# Out:
# (-1, 6)

# %% [markdown]
# So there are in general more peaks in normoxia conditions, but this could simply be a result of more reads

# %% [markdown]
# Upregulated in Hypoxia genes

# %%
figsize(10,10)
hist((combined_results / combined_results.sum() * 100)['Normoxia'])
# Out:
# (array([ 57.,  37.,  18.,   5.,  13.,   8.,   2.,   5.,   2.,   1.]),
#  array([ 0.02107926,  0.32462057,  0.62816189,  0.9317032 ,  1.23524452,
#         1.53878583,  1.84232715,  2.14586847,  2.44940978,  2.7529511 ,
#         3.05649241]),
#  <a list of 10 Patch objects>)

# %%
beds = { "Hypoxia Peaks" : hypoxia_peaks, "Normoxia Peaks" : normoxia_peaks, "targetscan mirnas" : targetscan_mirnas}

figsize(16,12)

H = "Hypoxia Peaks"
M = "Normoxia Peaks"
L = "targetscan mirnas"
venn3(
    {"001" : len(beds[L].intersect(beds[M], v=True, s=True).intersect(beds[H], v=True, s=True)),
     "010" : len(beds[M].intersect(beds[L], v=True, s=True).intersect(beds[H], v=True, s=True)),
     "011" : len(beds[L].intersect(beds[M], u=True, s=True).intersect(beds[H], v=True, s=True)),
     "100" : len(beds[H].intersect(beds[L], v=True, s=True).intersect(beds[M], v=True, s=True)),
     "101" : len(beds[H].intersect(beds[L], u=True, s=True).intersect(beds[M], v=True, s=True)),
     "110" : len(beds[H].intersect(beds[M], u=True, s=True).intersect(beds[L], v=True, s=True)),
     "111" : len(beds[H].intersect(beds[M], u=True, s=True).intersect(beds[L], u=True, s=True)),
    },
    
set_labels = (H, M, L))
# Out:
# <matplotlib_venn._venn3.Venn3 instance at 0x13f09908>

# %%
beds = { "Hypoxia Peaks" : hypoxia_peaks, "Normoxia Peaks" : normoxia_peaks, "miranda mirnas" : miranda}

figsize(16,12)

H = "Hypoxia Peaks"
M = "Normoxia Peaks"
L = "miranda mirnas"
venn3(
    {"001" : len(beds[L].intersect(beds[M], v=True, s=True).intersect(beds[H], v=True, s=True)),
     "010" : len(beds[M].intersect(beds[L], v=True, s=True).intersect(beds[H], v=True, s=True)),
     "011" : len(beds[L].intersect(beds[M], u=True, s=True).intersect(beds[H], v=True, s=True)),
     "100" : len(beds[H].intersect(beds[L], v=True, s=True).intersect(beds[M], v=True, s=True)),
     "101" : len(beds[H].intersect(beds[L], u=True, s=True).intersect(beds[M], v=True, s=True)),
     "110" : len(beds[H].intersect(beds[M], u=True, s=True).intersect(beds[L], v=True, s=True)),
     "111" : len(beds[H].intersect(beds[M], u=True, s=True).intersect(beds[L], u=True, s=True)),
    },
    
set_labels = (H, M, L))
# Out:
# <matplotlib_venn._venn3.Venn3 instance at 0x145efbd8>

# %%
def get_genes(interval):
    return interval.name.split("_")[0]
    return interval.name.split("_")[0]

# %%
hypoxia_genes = set([get_genes(interval) for interval in hypoxia_peaks])
normoxia_genes = set([get_genes(interval) for interval in normoxia_peaks])

# %%
print "Hypoxia Genes", "Normoxia Genes", "Overlapped Genes"
print len(hypoxia_genes), len(normoxia_genes), len(normoxia_genes & hypoxia_genes)
# Out:
# Hypoxia Genes Normoxia Genes Overlapped Genes
# 8861 12562 7716

# %%
bedstr = ""
error_count = 0
with open("human_predictions_S_C_aug2010.txt") as miranda:
    print miranda.next().strip().split("\t")
    for line in miranda:
        try:
            line = line.strip().split("\t")
            reference, chrom, location, strand = line[13][1:-1].split(":")
            start, stop = location.split("-")
            bedstr += "\t".join(["chr" +chrom, start, stop, line[1], "0", strand]) + "\n"
        except Exception as e:
            error_count += 1
            
miranda = pybedtools.BedTool(bedstr, from_string=True).saveas()
# Out:
# ['#mirbase_acc', 'mirna_name', 'gene_id', 'gene_symbol', 'transcript_id', 'ext_transcript_id', 'mirna_alignment', 'alignment', 'gene_alignment', 'mirna_start', 'mirna_end', 'gene_start', 'gene_end', 'genome_coordinates', 'conservation', 'align_score', 'seed_cat', 'energy', 'mirsvr_score']

# %%
print len(targetscan_mirnas), len(miranda)
# Out:
# 54199
# 1081250

# %%
venn2(
    {"01" : len(targetscan_mirnas.intersect(miranda, v=True, s=True)),
     "10" : len(miranda.intersect(targetscan_mirnas, v=True, s=True)),
     "11" : len(targetscan_mirnas.intersect(miranda, u=True, s=True)), }
, set_labels = ("miranda", "targetscan_mirnas")
    )
# Out:
# <matplotlib_venn._venn2.Venn2 instance at 0x2aaab419f560>

# %%
cd fastq/
# Out:
# /nas/nas0/gpratt/projects/chen_ago/v2_good/fastq

# %%
counts = !ls ZN*fastq.collapsed*counts

# %%
hypoxia_df = pd.DataFrame()
normoxia_df = pd.DataFrame()
for count in counts:
    tmp = pd.read_csv(count, 
            sep="\t", names=['mir', 'count'], header=None, index_col=0)
    if count.split(".")[1] == "R09" or count.split(".")[1] == "R10":
        normoxia_df = hypoxia_df.add(tmp, fill_value=0)
    else:
        hypoxia_df = normoxia_df.add(tmp, fill_value=0)

# %%
combined_list.ix['TOTAL'] / array([1671928, 5113585])
# Out:
# hypoxia     0.140270
# normoxia    0.013996
# Name: TOTAL, dtype: float64

# %%
combined_list
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 346 entries, TOTAL to hsa-miR-99b-5p
# Data columns (total 2 columns):
# hypoxia     346  non-null values
# normoxia    346  non-null values
# dtypes: float64(2)

# %%
def count_reads(fasta):
    total = 0
    with open(fasta) as fasta_file:
        for line in fasta_file:
            if line.startswith(">"):
                total += int(line.strip().split("_")[-1])
    return total

# %%
normoxia = (count_reads("ZNH_NoIndex_L008_R1.R09.polyATrim.adapterTrim.fastq.collapsed.fasta") +
count_reads("ZNH_NoIndex_L008_R1.R10.polyATrim.adapterTrim.fastq.collapsed.fasta") +
count_reads("ZNL_NoIndex_L007_R1.R09.polyATrim.adapterTrim.fastq.collapsed.fasta") +
count_reads("ZNL_NoIndex_L007_R1.R10.polyATrim.adapterTrim.fastq.collapsed.fasta"))

# %%
hypoxia = (count_reads("ZNH_NoIndex_L008_R1.R11.polyATrim.adapterTrim.fastq.collapsed.fasta") +
count_reads("ZNH_NoIndex_L008_R1.R12.polyATrim.adapterTrim.fastq.collapsed.fasta") +
count_reads("ZNL_NoIndex_L007_R1.R11.polyATrim.adapterTrim.fastq.collapsed.fasta") +
count_reads("ZNL_NoIndex_L007_R1.R12.polyATrim.adapterTrim.fastq.collapsed.fasta"))

# %%
print "normoxia", normoxia
print "hypoxia", hypoxia
# Out:
# normoxia 38593458
# hypoxia 11930128

# %%
combined_list.ix['TOTAL'] / array([11930128, 38593458])
# Out:
# hypoxia     0.011242
# normoxia    0.002934
# Name: TOTAL, dtype: float64

# %%
combined_list = pd.DataFrame({"hypoxia" : hypoxia_df['count'], "normoxia" : normoxia_df['count']}).fillna(0)

# %%
combined_list['fold_change'] = log2(combined_list['hypoxia'] / combined_list['normoxia'])

# %%
HTML(combined_list.sort("fold_change").to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hypoxia</th>
#       <th>normoxia</th>
#       <th>fold_change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>hsa-miR-3189-5p</th>
#       <td>      1</td>
#       <td>      1</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-224-3p</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-2277-3p</th>
#       <td>     14</td>
#       <td>     14</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-23a-5p</th>
#       <td>      1</td>
#       <td>      1</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4799-5p</th>
#       <td>      1</td>
#       <td>      1</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4787-3p</th>
#       <td>     10</td>
#       <td>     10</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-24-2-5p</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4785</th>
#       <td>      5</td>
#       <td>      5</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4750-3p</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-26a-2-3p</th>
#       <td>     13</td>
#       <td>     13</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-26a-5p</th>
#       <td>     43</td>
#       <td>     43</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-26b-3p</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4742-3p</th>
#       <td>      5</td>
#       <td>      5</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-27a-5p</th>
#       <td>     17</td>
#       <td>     17</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4712-5p</th>
#       <td>     14</td>
#       <td>     14</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-28-3p</th>
#       <td>      3</td>
#       <td>      3</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-296-5p</th>
#       <td>     19</td>
#       <td>     19</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-29c-5p</th>
#       <td>     21</td>
#       <td>     21</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4700-5p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-301b</th>
#       <td>      8</td>
#       <td>      8</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3064-3p</th>
#       <td>     57</td>
#       <td>     57</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-455-3p</th>
#       <td>    105</td>
#       <td>    105</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-485-3p</th>
#       <td>     12</td>
#       <td>     12</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-454-3p</th>
#       <td>     22</td>
#       <td>     22</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-22-5p</th>
#       <td>      1</td>
#       <td>      1</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-218-5p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-194-5p</th>
#       <td>      7</td>
#       <td>      7</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-195-5p</th>
#       <td>      6</td>
#       <td>      6</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-196b-3p</th>
#       <td>     11</td>
#       <td>     11</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-197-3p</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-545-3p</th>
#       <td>      3</td>
#       <td>      3</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-532-3p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-505-3p</th>
#       <td>     34</td>
#       <td>     34</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-5047</th>
#       <td>     36</td>
#       <td>     36</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-199a-5p</th>
#       <td>     17</td>
#       <td>     17</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-503-5p</th>
#       <td>     38</td>
#       <td>     38</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-374b-5p</th>
#       <td>      7</td>
#       <td>      7</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-501-5p</th>
#       <td>     14</td>
#       <td>     14</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-19b-1-5p</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-501-3p</th>
#       <td>      8</td>
#       <td>      8</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-500b</th>
#       <td>      4</td>
#       <td>      4</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-20a-3p</th>
#       <td>     47</td>
#       <td>     47</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-20a-5p</th>
#       <td>     18</td>
#       <td>     18</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-497-5p</th>
#       <td>      5</td>
#       <td>      5</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-214-3p</th>
#       <td>     29</td>
#       <td>     29</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-497-3p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-216a-5p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-491-5p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-548ah-3p</th>
#       <td>      3</td>
#       <td>      3</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-30d-3p</th>
#       <td>      6</td>
#       <td>      6</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-451a</th>
#       <td>      1</td>
#       <td>      1</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-424-3p</th>
#       <td>     10</td>
#       <td>     10</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-361-5p</th>
#       <td>      3</td>
#       <td>      3</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3614-5p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3615</th>
#       <td>     29</td>
#       <td>     29</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-362-3p</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3648</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-421</th>
#       <td>      8</td>
#       <td>      8</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3652</th>
#       <td>      1</td>
#       <td>      1</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3654</th>
#       <td>     31</td>
#       <td>     31</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3655</th>
#       <td>      8</td>
#       <td>      8</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3656</th>
#       <td>     15</td>
#       <td>     15</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3658</th>
#       <td>      3</td>
#       <td>      3</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3917</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-378f</th>
#       <td>      2</td>
#       <td>      2</td>
#       <td> 0.000000</td>
#     </tr>
#     <tr>

# %%
                    HTML(combined_list[combined_list['hypoxia'] > combined_list['normoxia']].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hypoxia</th>
#       <th>normoxia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>TOTAL</th>
#       <td> 134114</td>
#       <td> 113228</td>
#     </tr>
#     <tr>
#       <th>hsa-let-7a-5p</th>
#       <td>     55</td>
#       <td>     19</td>
#     </tr>
#     <tr>
#       <th>hsa-let-7b-5p</th>
#       <td>    175</td>
#       <td>    161</td>
#     </tr>
#     <tr>
#       <th>hsa-let-7e-5p</th>
#       <td>     10</td>
#       <td>      7</td>
#     </tr>
#     <tr>
#       <th>hsa-let-7i-3p</th>
#       <td>    206</td>
#       <td>    195</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-100-5p</th>
#       <td>    213</td>
#       <td>    188</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-101-3p</th>
#       <td>     53</td>
#       <td>     34</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-106b-5p</th>
#       <td>     30</td>
#       <td>     18</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-10b-5p</th>
#       <td>     63</td>
#       <td>     55</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1181</th>
#       <td>     19</td>
#       <td>      8</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1227-5p</th>
#       <td>      3</td>
#       <td>      0</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1244</th>
#       <td>     42</td>
#       <td>     27</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1246</th>
#       <td>   3337</td>
#       <td>   1929</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1248</th>
#       <td>    132</td>
#       <td>     70</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1249</th>
#       <td>     40</td>
#       <td>     12</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-125a-3p</th>
#       <td>     26</td>
#       <td>     24</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-125a-5p</th>
#       <td>    251</td>
#       <td>    232</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-125b-1-3p</th>
#       <td>     29</td>
#       <td>     19</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-125b-5p</th>
#       <td>   4178</td>
#       <td>   3647</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-126-3p</th>
#       <td>   4782</td>
#       <td>   3578</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-126-5p</th>
#       <td>    453</td>
#       <td>    352</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1260b</th>
#       <td>      1</td>
#       <td>      0</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1271-3p</th>
#       <td>      6</td>
#       <td>      5</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1273f</th>
#       <td>     19</td>
#       <td>     17</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1273g-3p</th>
#       <td>     49</td>
#       <td>     47</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-128</th>
#       <td>     41</td>
#       <td>     23</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1281</th>
#       <td>     10</td>
#       <td>      4</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1290</th>
#       <td>     20</td>
#       <td>      8</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1307-5p</th>
#       <td>    335</td>
#       <td>    286</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-139-3p</th>
#       <td>     38</td>
#       <td>     36</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-139-5p</th>
#       <td>    170</td>
#       <td>    133</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-140-5p</th>
#       <td>     34</td>
#       <td>     25</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-142-3p</th>
#       <td>     15</td>
#       <td>     14</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-146a-5p</th>
#       <td>     89</td>
#       <td>     78</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-148b-3p</th>
#       <td>     77</td>
#       <td>     66</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-149-5p</th>
#       <td>    121</td>
#       <td>    113</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-151a-3p</th>
#       <td>    148</td>
#       <td>    100</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-151a-5p</th>
#       <td>     80</td>
#       <td>     66</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-151b</th>
#       <td>     85</td>
#       <td>     71</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-154-5p</th>
#       <td>     40</td>
#       <td>     11</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-15b-5p</th>
#       <td>     25</td>
#       <td>     16</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-16-5p</th>
#       <td>     95</td>
#       <td>     69</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-17-5p</th>
#       <td>     30</td>
#       <td>     24</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181a-2-3p</th>
#       <td>     30</td>
#       <td>     18</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181a-5p</th>
#       <td>    461</td>
#       <td>    424</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181b-3p</th>
#       <td>     39</td>
#       <td>     38</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181b-5p</th>
#       <td>    265</td>
#       <td>    177</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-186-5p</th>
#       <td>   1311</td>
#       <td>   1174</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-18a-5p</th>
#       <td>     26</td>
#       <td>     15</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-193a-3p</th>
#       <td>    625</td>
#       <td>    518</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-193b-3p</th>
#       <td>    124</td>
#       <td>     86</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1972</th>
#       <td>      2</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1973</th>
#       <td>    394</td>
#       <td>    214</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-198</th>
#       <td>    109</td>
#       <td>     95</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-199a-3p</th>
#       <td>    279</td>
#       <td>    242</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-199b-3p</th>
#       <td>    277</td>
#       <td>    240</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-19a-3p</th>
#       <td>    168</td>
#       <td>    131</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-19a-5p</th>
#       <td>     33</td>
#       <td>     12</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-19b-3p</th>
#       <td>    311</td>
#       <td>    236</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-204-5p</th>
#       <td>     64</td>
#       <td>     54</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-21-3p</th>
#       <td>     54</td>
#       <td>     52</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-21-5p</th>
#       <td>   2910</td>
#       <td>   2339</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-214-5p</th>
#       <td>     50</td>
#       <td>     31</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-22-3p</th>
#       <td>    103</td>
#       <td>     53</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-221-3p</th>
#       <td>    454</td>
#       <td>    406</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-221-5p</th>
#       <td>     40</td>
#       <td>     39</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-222-3p</th>
#       <td>   4297</td>
#       <td>   3831</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-222-5p</th>
#       <td>     79</td>
#       <td>     53</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-224-5p</th>
#       <td>     55</td>
#       <td>     52</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-23a-3p</th>
#       <td>    812</td>
#       <td>    651</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-23b-3p</th>
#       <td>    210</td>
#       <td>    139</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-24-1-5p</th>
#       <td>      4</td>
#       <td>      3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-24-3p</th>
#       <td>    525</td>
#       <td>    394</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-25-3p</th>
#       <td>     48</td>
#       <td>     39</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-26b-5p</th>
#       <td>     44</td>
#       <td>     40</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-27a-3p</th>
#       <td>  17966</td>
#       <td>  12911</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-27b-3p</th>
#       <td>    296</td>
#       <td>    201</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-29a-3p</th>
#       <td>   2085</td>
#       <td>   1904</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-29a-5p</th>
#       <td>     10</td>
#       <td>      9</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-29b-3p</th>
#       <td>    998</td>
#       <td>    968</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-29c-3p</th>
#       <td>    527</td>
#       <td>    484</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-301a-3p</th>
#       <td>      9</td>
#       <td>      1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3064-5p</th>
#       <td>

# %%
HTML(combined_list[combined_list['hypoxia'] < combined_list['normoxia']].to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hypoxia</th>
#       <th>normoxia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>hsa-let-7a-5p</th>
#       <td>  14</td>
#       <td>   74</td>
#     </tr>
#     <tr>
#       <th>hsa-let-7g-3p</th>
#       <td>  15</td>
#       <td>   17</td>
#     </tr>
#     <tr>
#       <th>hsa-let-7g-5p</th>
#       <td>   0</td>
#       <td>   10</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-103a-3p</th>
#       <td>   6</td>
#       <td>   15</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1181</th>
#       <td>  19</td>
#       <td>   28</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1227-5p</th>
#       <td>   0</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1249</th>
#       <td>  21</td>
#       <td>   40</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-125b-1-3p</th>
#       <td>  14</td>
#       <td>   22</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1268a</th>
#       <td>   0</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1281</th>
#       <td>   1</td>
#       <td>    9</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1290</th>
#       <td>  10</td>
#       <td>   13</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1306-3p</th>
#       <td>   0</td>
#       <td>    6</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-140-5p</th>
#       <td>  34</td>
#       <td>   40</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-142-3p</th>
#       <td>   0</td>
#       <td>   15</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-151a-3p</th>
#       <td> 129</td>
#       <td>  143</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-154-5p</th>
#       <td>   0</td>
#       <td>   40</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-16-1-3p</th>
#       <td>   1</td>
#       <td>    7</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181b-5p</th>
#       <td> 191</td>
#       <td>  197</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181c-3p</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-181d</th>
#       <td>   0</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-186-3p</th>
#       <td>  15</td>
#       <td>   19</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-18a-5p</th>
#       <td>  16</td>
#       <td>   21</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-191-5p</th>
#       <td>   4</td>
#       <td>    5</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1915-3p</th>
#       <td>   0</td>
#       <td>    9</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-196b-5p</th>
#       <td>   0</td>
#       <td>    2</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1972</th>
#       <td>  14</td>
#       <td>   23</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-1973</th>
#       <td> 182</td>
#       <td>  266</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-199a-5p</th>
#       <td>  31</td>
#       <td>   37</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-19a-5p</th>
#       <td>  13</td>
#       <td>   39</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-19b-1-5p</th>
#       <td>   4</td>
#       <td>   15</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-214-5p</th>
#       <td>  41</td>
#       <td>   57</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-216a-3p</th>
#       <td>   0</td>
#       <td>    8</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-22-3p</th>
#       <td>  73</td>
#       <td>   82</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-222-5p</th>
#       <td>  52</td>
#       <td>   64</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-2682-5p</th>
#       <td>   0</td>
#       <td>   35</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-27a-5p</th>
#       <td>  18</td>
#       <td>   25</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-301a-3p</th>
#       <td>   8</td>
#       <td>   14</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-30a-5p</th>
#       <td> 361</td>
#       <td>  465</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3177-3p</th>
#       <td>   0</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3189-3p</th>
#       <td>   0</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-324-5p</th>
#       <td>  64</td>
#       <td>   83</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-330-5p</th>
#       <td>   9</td>
#       <td>   16</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-339-5p</th>
#       <td>  30</td>
#       <td>   32</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3605-3p</th>
#       <td>   0</td>
#       <td>   93</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3605-5p</th>
#       <td>   0</td>
#       <td>   24</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-3648</th>
#       <td>  11</td>
#       <td>  118</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-423-3p</th>
#       <td>  52</td>
#       <td>   63</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-423-5p</th>
#       <td>   1</td>
#       <td>   11</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-425-3p</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4417</th>
#       <td>  52</td>
#       <td>   66</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4419b</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4466</th>
#       <td> 755</td>
#       <td> 1063</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4485</th>
#       <td> 458</td>
#       <td>  666</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4488</th>
#       <td>  11</td>
#       <td>   20</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4492</th>
#       <td>  28</td>
#       <td>  267</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4508</th>
#       <td>  26</td>
#       <td>  233</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-450a-5p</th>
#       <td>   1</td>
#       <td>    2</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-452-5p</th>
#       <td>   1</td>
#       <td>    4</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4523</th>
#       <td>   0</td>
#       <td>   12</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4532</th>
#       <td>  64</td>
#       <td> 1042</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-455-5p</th>
#       <td>  50</td>
#       <td>   66</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4640-3p</th>
#       <td>   0</td>
#       <td>   32</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4668-3p</th>
#       <td>   0</td>
#       <td>    2</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4683</th>
#       <td>   0</td>
#       <td>    6</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4684-5p</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4700-5p</th>
#       <td>   0</td>
#       <td>    2</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4729</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4743-5p</th>
#       <td>   0</td>
#       <td>   71</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-4784</th>
#       <td>   0</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-5008-3p</th>
#       <td>   0</td>
#       <td>   15</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-500a-3p</th>
#       <td>   3</td>
#       <td>    4</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-503-3p</th>
#       <td>   0</td>
#       <td>   12</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-504</th>
#       <td>   1</td>
#       <td>    4</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-542-3p</th>
#       <td>   2</td>
#       <td>   13</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-548v</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-5585-3p</th>
#       <td>   5</td>
#       <td>   19</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-5587-5p</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-568</th>
#       <td>   5</td>
#       <td>   18</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-5697</th>
#       <td>   0</td>
#       <td>   44</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-579</th>
#       <td>   0</td>
#       <td>   20</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-6084</th>
#       <td>   0</td>
#       <td>    4</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-625-5p</th>
#       <td>   1</td>
#       <td>   20</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-628-5p</th>
#       <td>   0</td>
#       <td>    2</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-660-3p</th>
#       <td>   1</td>
#       <td>   16</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-661</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-663b</th>
#       <td> 555</td>
#       <td>  676</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-7-5p</th>
#       <td>   0</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>hsa-miR-

# %% [markdown]
# So these peak numbers aren't going to quite add up, overlapping peaks and order of choice of overlap will both slightly change the counts, this is alright, as expect, but something good to know if other counts aren't perfectly self consistant. For mirna analysis I'll base my calls off of the targetscan mirnas because that way I can avoid double counting.
