# %%
from collections import defaultdict, Counter
import glob
import os

from IPython.core.display import HTML, Image, SVG
from matplotlib_venn import venn3
import pandas as pd
import pybedtools
import pysam

from gscripts.general import parsers
# %load_ext autoreload

# %autoreload 2
reload(parsers)
reload(pybedtools)

import matplotlib.pyplot as plt
from gscripts.general import dataviz

# %%
# !mkdir -p  /nas3/gpratt/projects/fox2_iclip/analysis/v4
# !scp -q tscc-login.sdsc.edu:/home/gpratt/projects/fox2_iclip/analysis/v4/*.{metrics,final.out,peaks.bed,svg} /nas3/gpratt/projects/fox2_iclip/analysis/v4

# %%
analysis_dir = "/nas3/gpratt/projects/fox2_iclip/analysis/v4"
encode_v10 = parsers.clipseq_metrics(analysis_dir, iclip=True)

encode_v10["Reads After Triming"] = encode_v10['Input Reads'] - encode_v10['Too short reads']
encode_v10["Fraction Collapsed"] = encode_v10['Usable Reads'] / encode_v10['Uniquely Mapped Reads'].astype(float)
encode_v10["Fraction Usable"] = encode_v10['Usable Reads'] / encode_v10['Input Reads'].astype(float)

filtered_encode_v10 = encode_v10[[ "Input Reads",
                            "Reads After Triming",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            "spot",
                            "Num Peaks",
                            "Passed QC"
                            ]]

HTML(filtered_encode_v10.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas,
                                     "repetitive_count" : parsers.commas, 
                                     } ))
# Out:
# <closed file '/nas3/gpratt/projects/fox2_iclip/analysis/v4/M2_NoIndex_L002_R1.R10_low1.polyATrim.adapterTrim.metrics', mode 'r' at 0x21e95ae0>
# <closed file '/nas3/gpratt/projects/fox2_iclip/analysis/v4/M2_NoIndex_L002_R1.R10_lowRNAse_M_2.polyATrim.adapterTrim.metrics', mode 'r' at 0x21e95ae0>
# <closed file '/nas3/gpratt/projects/fox2_iclip/analysis/v4/H2_NoIndex_L001_R1.R07_high.polyATrim.adapterTrim.metrics', mode 'r' at 0x21e95ae0>
# <closed file '/nas3/gpratt/projects/fox2_iclip/analysis/v4/H2_NoIndex_L001_R1.R10_low1.polyATrim.adapterTrim.metrics', mode 'r' at 0x21e95ae0>
# <closed file '/nas3/gpratt/projects/fox2_iclip/analysis/v4/H2_NoIndex_L001_R1.R07_highRNAse_H.polyATrim.adapterTrim.metrics', mode 'r' at 0x21e95ae0>
# <closed file '/nas3/gpratt/projects/fox2_iclip/analysis/v4/H2_NoIndex_L001_R1.R10_lowRNAse_H_2.polyATrim.adapterTrim.metrics', mode 'r' at 0x21e95ae0>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads After Triming</th>
#       <th>repetitive_count</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Usable Reads</th>
#       <th>Fraction Collapsed</th>
#       <th>Fraction Usable</th>
#       <th>spot</th>
#       <th>Num Peaks</th>
#       <th>Passed QC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>F1_CLIP_BS_NoIndex_L007_R1.polyATrim</th>
#       <td>146,894,220</td>
#       <td>136,410,459</td>
#       <td>22,818,531</td>
#       <td> 44,665,834</td>
#       <td> 39.32%</td>
#       <td>  228,398</td>
#       <td> 0.005113</td>
#       <td> 0.001555</td>
#       <td> 0.384461</td>
#       <td>16,328</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>F3_CLIP_BS_NoIndex_L008_R1.polyATrim</th>
#       <td>160,064,644</td>
#       <td>148,728,432</td>
#       <td> 7,579,613</td>
#       <td> 34,802,230</td>
#       <td> 24.66%</td>
#       <td>  499,640</td>
#       <td> 0.014357</td>
#       <td> 0.003121</td>
#       <td> 0.330964</td>
#       <td>30,904</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>H2_NoIndex_L001_R1.R07_high</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>         0</td>
#       <td>        NaN</td>
#       <td>    NaN</td>
#       <td>        0</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>     0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>H2_NoIndex_L001_R1.R07_highRNAse_H</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>         0</td>
#       <td>        NaN</td>
#       <td>    NaN</td>
#       <td>        0</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>     0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>H2_NoIndex_L001_R1.R10_low1</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>         0</td>
#       <td>        NaN</td>
#       <td>    NaN</td>
#       <td>        0</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>     0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>H2_NoIndex_L001_R1.R10_lowRNAse_H_2</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>         0</td>
#       <td>        NaN</td>
#       <td>    NaN</td>
#       <td>        0</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>     0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>H2_NoIndex_L001_R1.R12_low2</th>
#       <td>112,120,785</td>
#       <td>104,687,805</td>
#       <td> 6,506,419</td>
#       <td> 78,302,298</td>
#       <td> 79.75%</td>
#       <td>3,663,293</td>
#       <td> 0.046784</td>
#       <td> 0.032673</td>
#       <td> 0.115387</td>
#       <td>44,006</td>
#       <td>  True</td>
#     </tr>
#     <tr>
#       <th>L2_NoIndex_L003_R1.R07_high</th>
#       <td>117,663,794</td>
#       <td>113,784,823</td>
#       <td>   315,706</td>
#       <td>    376,471</td>
#       <td>  0.33%</td>
#       <td>  113,462</td>
#       <td> 0.301383</td>
#       <td> 0.000964</td>
#       <td> 0.088887</td>
#       <td> 1,236</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>L2_NoIndex_L003_R1.R10_low1</th>
#       <td> 16,954,012</td>
#       <td> 16,630,904</td>
#       <td>    25,536</td>
#       <td>    121,899</td>
#       <td>  0.73%</td>
#       <td>   98,794</td>
#       <td> 0.810458</td>
#       <td> 0.005827</td>
#       <td> 0.023675</td>
#       <td>   577</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>L2_NoIndex_L003_R1.R12_low2</th>
#       <td>117,152,683</td>
#       <td>112,990,782</td>
#       <td>   221,448</td>
#       <td>    845,657</td>
#       <td>  0.75%</td>
#       <td>  645,197</td>
#       <td> 0.762954</td>
#       <td> 0.005507</td>
#       <td> 0.057959</td>
#       <td> 6,323</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>M2_NoIndex_L002_R1.R07_high</th>
#       <td>129,289,569</td>
#       <td>122,510,244</td>
#       <td>11,410,137</td>
#       <td> 23,645,568</td>
#       <td> 21.28%</td>
#       <td>  379,040</td>
#       <td> 0.016030</td>
#       <td> 0.002932</td>
#       <td> 0.121997</td>
#       <td> 3,680</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>M2_NoIndex_L002_R1.R10_low1</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>         0</td>
#       <td>        NaN</td>
#       <td>    NaN</td>
#       <td>        0</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>     0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>M2_NoIndex_L002_R1.R10_lowRNAse_M_2</th>
#       <td>          0</td>
#       <td>          0</td>
#       <td>         0</td>
#       <td>        NaN</td>
#       <td>    NaN</td>
#       <td>        0</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>      NaN</td>
#       <td>     0</td>
#       <td> False</td>
#     </tr>
#     <tr>
#       <th>M2_NoIndex_L002_R1.R12_low2</th>
#       <td>124,320,492</td>
#       <td>117,622,810</td>
#       <td>   997,085</td>
#       <td> 44,065,474</td>
#       <td> 37.78%</td>
#       <td>2,460,024</td>
#       <td> 0.055827</td>
#       <td> 0.019788</td>
#       <td> 0.126856</td>
#       <td>41,394</td>
#       <td>  True</td>
#     </tr>
#   </tbody>
# </table>
