# %% [markdown]
# Initilizaing Analysis
# -----------
#
# Ignore

# %%
import pandas as pd
from IPython.core.display import HTML

from gscripts.general import parsers

# %%
qc_metrics = parsers.clipseq_metrics("/nas3/gpratt/projects/tiffany_genentech/analysis/v1/", iclip=True)
qc_metrics = qc_metrics.rename(columns={"Processed bases" : "Input Bases",
           "Processed reads" : "Input Reads",
           "Number of input reads" : "Reads after Quality Filtering"
           })

# %% [markdown]
# #Raw QC

# %%
HTML(qc_metrics.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Bases</th>
#       <th>Input Reads</th>
#       <th>Quality-trimmed</th>
#       <th>Too long reads</th>
#       <th>Too short reads</th>
#       <th>Trimmed bases</th>
#       <th>Trimmed reads</th>
#       <th>% of reads mapped to multiple loci</th>
#       <th>% of reads mapped to too many loci</th>
#       <th>% of reads unmapped: other</th>
#       <th>% of reads unmapped: too many mismatches</th>
#       <th>% of reads unmapped: too short</th>
#       <th>Average input read length</th>
#       <th>Average mapped length</th>
#       <th>Deletion average length</th>
#       <th>Deletion rate per base</th>
#       <th>Finished on</th>
#       <th>Insertion average length</th>
#       <th>Insertion rate per base</th>
#       <th>Mapping speed, Million of reads per hour</th>
#       <th>Mismatch rate per base, percent</th>
#       <th>Reads after Quality Filtering</th>
#       <th>Number of reads mapped to multiple loci</th>
#       <th>Number of reads mapped to too many loci</th>
#       <th>Number of splices: AT/AC</th>
#       <th>Number of splices: Annotated (sjdb)</th>
#       <th>Number of splices: GC/AG</th>
#       <th>Number of splices: GT/AG</th>
#       <th>Number of splices: Non-canonical</th>
#       <th>Number of splices: Total</th>
#       <th>Started job on</th>
#       <th>Started mapping on</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Uniquely mapped reads number</th>
#       <th>NRF</th>
#       <th>PCB</th>
#       <th>Usable Reads</th>
#       <th>removed_count</th>
#       <th>total_count</th>
#       <th>Num Peaks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LIB19982_SAM18146099_R1.R02</th>
#       <td>  289550323</td>
#       <td>  7062203</td>
#       <td>  223318</td>
#       <td> 0</td>
#       <td>   1024</td>
#       <td>   188140</td>
#       <td>  13263</td>
#       <td> 0.00%</td>
#       <td> 41.27%</td>
#       <td> 0.00%</td>
#       <td> 0.00%</td>
#       <td> 47.41%</td>
#       <td> 40</td>
#       <td> 33.05</td>
#       <td> 1.53</td>
#       <td> 0.05%</td>
#       <td> Apr 08 16:17:42</td>
#       <td> 1.09</td>
#       <td> 0.00%</td>
#       <td>  784.78</td>
#       <td> 1.77%</td>
#       <td>  6539872</td>
#       <td> 0</td>
#       <td>  2699002</td>
#       <td>  1</td>
#       <td> 0</td>
#       <td>  535</td>
#       <td>  19941</td>
#       <td>  8264</td>
#       <td>  28741</td>
#       <td> Apr 08 16:16:39</td>
#       <td> Apr 08 16:17:12</td>
#       <td> 11.32%</td>
#       <td>   740466</td>
#       <td> 0.011566</td>
#       <td> 0.314106</td>
#       <td>  44267</td>
#       <td>   696199</td>
#       <td>   740466</td>
#       <td>  421</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R
td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1_resequenced.R08</th>
#       <td> 2630323594</td>
#       <td> 64154234</td>
#       <td> 8249266</td>
#       <td> 0</td>
#       <td> 207691</td>
#       <td> 19008830</td>
#       <td> 996912</td>
#       <td> 0.00%</td>
#       <td> 42.68%</td>
#       <td> 0.07%</td>
#       <td> 0.00%</td>
#       <td> 17.25%</td>
#       <td> 40</td>
#       <td> 38.11</td>
#       <td> 1.42</td>
#       <td> 0.14%</td>
#       <td> Apr 19 22:57:39</td>
#       <td> 1.16</td>
#       <td> 0.01%</td>
#       <td> 1034.81</td>
#       <td> 1.28%</td>
#       <td> 36793226</td>
#       <td> 0</td>
#       <td> 15703550</td>
#       <td> 53</td>
#       <td> 0</td>
#       <td> 3289</td>
#       <td> 100545</td>
#       <td> 41617</td>
#       <td> 145504</td>
#       <td> Apr 19 22:55:11</td>
#       <td> Apr 19 22:55:31</td>
#       <td> 40.00%</td>
#       <td> 14718554</td>
#       <td> 0.004190</td>
#       <td> 0.326566</td>
#       <td> 165070</td>
#       <td> 14553484</td>
#       <td> 14718554</td>
#       <td> 1104</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1_resequenced.unassigned</th>
#       <td>  608536473</td>
#       <td> 14842353</td>
#       <td> 2486300</td>
#       <td> 0</td>
#       <td>  81666</td>
#       <td>  8967113</td>
#       <td> 327023</td>
#       <td> 0.00%</td>
#       <td> 19.27%</td>
#       <td> 0.03%</td>
#       <td> 0.00%</td>
#       <td> 50.89%</td>
#       <td> 40</td>
#       <td> 38.93</td>
#       <td> 1.42</td>
#       <td> 0.02%</td>
#       <td> Apr 19 22:55:04</td>
#       <td> 1.13</td>
#       <td> 0.00%</td>
#       <td>  720.86</td>
#       <td> 0.59%</td>
#       <td> 13215786</td>
#       <td> 0</td>
#       <td>  2546333</td>
#       <td>  2</td>
#       <td> 0</td>
#       <td> 1498</td>
#       <td> 100126</td>
#       <td>  5848</td>
#       <td> 107474</td>
#       <td> Apr 19 22:52:55</td>
#       <td> Apr 19 22:53:58</td>
#       <td> 29.81%</td>
#       <td>  3939713</td>
#       <td> 0.028923</td>
#       <td> 0.484098</td>
#       <td> 278074</td>
#       <td>  3661639</td>
#       <td>  3939713</td>
#       <td> 3834</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #Important QC Metrics

# %%
qc_metrics["Reads After Triming"] = qc_metrics['Input Reads'] - qc_metrics['Too short reads']

filtered_df = qc_metrics[[ "Input Reads",
                            "Reads After Triming",
                            "Reads after Quality Filtering", 
                            "Uniquely mapped reads number",
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            #"spot",
                            "Num Peaks"
                            ]]

filtered_df['Percent Usable'] = (filtered_df['Usable Reads'] / filtered_df['Uniquely mapped reads number']) * 100
HTML(filtered_df.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely mapped reads number" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads After Triming</th>
#       <th>Reads after Quality Filtering</th>
#       <th>Uniquely mapped reads number</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Usable Reads</th>
#       <th>Num Peaks</th>
#       <th>Percent Usable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>LIB19982_SAM18146099_R1.R02</th>
#       <td> 7,062,203</td>
#       <td> 7,061,179</td>
#       <td>  6,539,872</td>
#       <td>    740,466</td>
#       <td> 11.32%</td>
#       <td> 44,267</td>
#       <td>  421</td>
#       <td> 5.978262</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1.R08</th>
#       <td> 5,605,218</td>
#       <td> 5,599,050</td>
#       <td>  3,257,933</td>
#       <td>  1,279,767</td>
#       <td> 39.28%</td>
#       <td> 56,518</td>
#       <td>  254</td>
#       <td> 4.416273</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1.unassigned</th>
#       <td> 1,644,168</td>
#       <td> 1,637,080</td>
#       <td>  1,532,504</td>
#       <td>    260,540</td>
#       <td> 17.00%</td>
#       <td> 34,521</td>
#       <td>  275</td>
#       <td> 13.24979</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1_resequenced.R02</th>
#       <td>76,544,546</td>
#       <td>76,487,360</td>
#       <td> 70,477,389</td>
#       <td>  8,145,766</td>
#       <td> 11.56%</td>
#       <td>226,835</td>
#       <td>1,109</td>
#       <td> 2.784698</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1_resequenced.R08</th>
#       <td>64,154,234</td>
#       <td>63,946,543</td>
#       <td> 36,793,226</td>
#       <td> 14,718,554</td>
#       <td> 40.00%</td>
#       <td>165,070</td>
#       <td>1,104</td>
#       <td>  1.12151</td>
#     </tr>
#     <tr>
#       <th>LIB19982_SAM18146099_R1_resequenced.unassigned</th>
#       <td>14,842,353</td>
#       <td>14,760,687</td>
#       <td> 13,215,786</td>
#       <td>  3,939,713</td>
#       <td> 29.81%</td>
#       <td>278,074</td>
#       <td>3,834</td>
#       <td>  7.05823</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Analysis
# --------
#
# The number of usable (randomer collapsed) reads from this analysis is too low to confidently draw genome wide conclusions.  The Precent Usable Reads is decent when compared to internal datasets from the Yeo Lab.  We see a range of 1%-10% on average.
#
# I recommend much deeper sequencing.  Enough to get up to ~1m usable reads.  For R08 this means sequencing at least 23,000,000 reads and 17,000,000 for R02

# %% [markdown]
# #Second Round of Sequencing (trying to figure out why no barcodes are mapped

# %%
barcodes = pd.read_csv("/nas3/gpratt/projects/tiffany_genentech/analysis/split_fastq/LIB20241_SAM18256965_R1.metrics", 
            sep="\t", header=None, names=["Barcode", "Randomer", "Count"])

# %%
barcodes['infered_barcode'] = barcodes['Randomer'].apply(lambda x: x[3:9])

# %%
barcodes.groupby("Barcode").Count.sum().sort()

# %%
unassigned_barcodes = barcodes[barcodes['Barcode'] == 'unassigned']

# %%
unassigned_barcodes["percent_of_total"] = (unassigned_barcodes.Count / unassigned_barcodes.Count.sum()) * 100
# Out:
# -c:1: SettingWithCopyWarning: A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_index,col_indexer] = value instead

# %%
x= unassigned_barcodes.groupby("infered_barcode").Count.sum()
x.sort(ascending=False)
x

# %% [markdown]
# This is my target list of barcodes to search for to see if they exist

# %%
unassigned_barcodes[unassigned_barcodes.infered_barcode == "TCGGAA"].sort("Count", ascending=False)
# Out:
#            Barcode   Randomer    Count infered_barcode  percent_of_total
# 246209  unassigned  AGATCGGAA  8786649          TCGGAA          8.175665
# 39110   unassigned  AGGTCGGAA    20169          TCGGAA          0.018767
# 257251  unassigned  GGATCGGAA    12013          TCGGAA          0.011178
# 52036   unassigned  CGATCGGAA     8827          TCGGAA          0.008213
# 30705   unassigned  NGATCGGAA     4853          TCGGAA          0.004516
# 55021   unassigned  TGATCGGAA     2574          TCGGAA          0.002395
# 3056    unassigned  AGTTCGGAA     2342          TCGGAA          0.002179
# 218269  unassigned  AAATCGGAA     1681          TCGGAA          0.001564
# 132563  unassigned  ATATCGGAA     1143          TCGGAA          0.001064
# 217329  unassigned  GAATCGGAA     1017          TCGGAA          0.000946
# 139539  unassigned  AGCTCGGAA      778          TCGGAA          0.000724
# 32949   unassigned  CCATCGGAA      655          TCGGAA          0.000609
# 172376  unassigned  ACATCGGAA      565          TCGGAA          0.000526
# 12019   unassigned  GCGTCGGAA      299          TCGGAA          0.000278
