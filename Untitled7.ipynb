# %%
import os

# %%
for base, dirs, files in os.walk("."):
    print base, dirs
# Out:
# . ['.git', '335_LxUPF12_NoIndex_L003_R1_summary', 'tmp', '334_LxLuc3_NoIndex_L002_R1', 'bar', '333_LxLuc2_NoIndex_L001_R1_summary', '.ipynb_checkpoints', '336_LxUPF13_NoIndex_L004_R1_summary', '333_LxLuc2_NoIndex_L001_R1', '336_LxUPF13_NoIndex_L004_R1', '335_LxUPF12_NoIndex_L003_R1', '334_LxLuc3_NoIndex_L002_R1_summary']
# ./.git ['logs', 'hooks', 'branches', 'objects', 'refs', 'info']
# ./.git/logs ['refs']
# ./.git/logs/refs ['heads', 'remotes']
# ./.git/logs/refs/heads []
# ./.git/logs/refs/remotes ['origin']
# ./.git/logs/refs/remotes/origin []
# ./.git/hooks []
# ./.git/branches []
# ...

# %%
os.walk?

# %%
pwd
# Out:
# u'/nas/nas0/gpratt/iPython_Notebook'
