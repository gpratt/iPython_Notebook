# %%
from collections import defaultdict, Counter
import glob
import os

from IPython.core.display import HTML, Image
from matplotlib_venn import venn3
import pandas as pd
import pybedtools
import pysam

from gscripts.general import parsers
# %load_ext autoreload
# %autoreload 2
reload(parsers)
reload(pybedtools)
# Out:
# <module 'pybedtools' from '/nas3/gpratt/anaconda/lib/python2.7/site-packages/pybedtools-0.6.8-py2.7-linux-x86_64.egg/pybedtools/__init__.pyc'>

# %%
analysis_dir = "/nas3/gpratt/projects/encode/analysis/encode_v2/"
encode_v10 = parsers.clipseq_metrics(analysis_dir, iclip=True)

encode_v10["Reads After Triming"] = encode_v10['Input Reads'] - encode_v10['Too short reads']
encode_v10["Fraction Collapsed"] = encode_v10['Usable Reads'] / encode_v10['Uniquely Mapped Reads'].astype(float)
encode_v10["Fraction Usable"] = encode_v10['Usable Reads'] / encode_v10['Input Reads'].astype(float)

filtered_encode_v10 = encode_v10[[ "Input Reads",
                            "Reads After Triming",
                            "repetitive_count",
                            "Uniquely Mapped Reads",
                            "Uniquely mapped reads %",
                            "Usable Reads",
                            "Fraction Collapsed",
                            "Fraction Usable",
                            #"spot",
                            "Num Peaks",
                            "Passed QC"
                            ]]
# Out:
# <closed file '/nas3/gpratt/projects/encode/analysis/encode_v2/SLBPNHS-pool2_S7_R2.B06_SLBPNHS_pool2_SLBP.polyATrim.adapterTrim.metrics', mode 'r' at 0x5cdf9c0>
# <closed file '/nas3/gpratt/projects/encode/analysis/encode_v2/2F-input_S10_R2.unassigned.polyATrim.adapterTrim.metrics', mode 'r' at 0x5cdf9c0>
# <closed file '/nas3/gpratt/projects/encode/analysis/encode_v2/5_K562_Input_2_Infminus_CGCTCATT-TATAGCCT_R2.unassigned.polyATrim.adapterTrim.metrics', mode 'r' at 0x5cdf9c0>

# %%
a2b1_results = filtered_encode_v10[["A2B1" in item for item in filtered_encode_v10.index]]
HTML(a2b1_results.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads After Triming</th>
#       <th>repetitive_count</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Uniquely mapped reads %</th>
#       <th>Usable Reads</th>
#       <th>Fraction Collapsed</th>
#       <th>Fraction Usable</th>
#       <th>Num Peaks</th>
#       <th>Passed QC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>F1_IN_A2B1_ATTACTCG-TATAGCCT_L008_R2.A04</th>
#       <td>45,039</td>
#       <td>42,963</td>
#       <td>41378</td>
#       <td>788</td>
#       <td>49.72%</td>
#       <td>677</td>
#       <td>0.859137</td>
#       <td>0.015031</td>
#       <td>8</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F1_IN_A2B1_ATTACTCG-TATAGCCT_L008_R2.unassigned</th>
#       <td>15,194,880</td>
#       <td>14,438,838</td>
#       <td>7277122</td>
#       <td>3,508,620</td>
#       <td>48.99%</td>
#       <td>2,615,137</td>
#       <td>0.745346</td>
#       <td>0.172106</td>
#       <td>28,409</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F2_IP_A2B1_GAGATTCC-TATAGCCT_L008_R2.A01</th>
#       <td>50,796</td>
#       <td>34,679</td>
#       <td>5529</td>
#       <td>20,848</td>
#       <td>71.52%</td>
#       <td>18,454</td>
#       <td>0.885169</td>
#       <td>0.363296</td>
#       <td>32</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F2_IP_A2B1_GAGATTCC-TATAGCCT_L008_R2.C01_F2_IP_mnCLIP_A2B1_high_2_hnRNPA2B1</th>
#       <td>5,881,739</td>
#       <td>4,520,826</td>
#       <td>666599</td>
#       <td>2,817,518</td>
#       <td>73.10%</td>
#       <td>2,337,893</td>
#       <td>0.829770</td>
#       <td>0.397483</td>
#       <td>14,778</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F2_IP_A2B1_GAGATTCC-TATAGCCT_L008_R2.D08fixed_F2_IP_mnCLIP_A2B1_high_2_hnRNPA2B1</th>
#       <td>2,537,590</td>
#       <td>2,103,793</td>
#       <td>352673</td>
#       <td>1,312,562</td>
#       <td>74.96%</td>
#       <td>1,133,182</td>
#       <td>0.863336</td>
#       <td>0.446558</td>
#       <td>6,754</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F2_IP_mnCLIP_A2B1_high_2_hnRNPA2B1merged.peaks</th>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>21,885</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F3_IN_A2B1_ATTCAGAA-TATAGCCT_L008_R2.A04</th>
#       <td>71,216</td>
#       <td>68,074</td>
#       <td>66016</td>
#       <td>985</td>
#       <td>47.86%</td>
#       <td>813</td>
#       <td>0.825381</td>
#       <td>0.011416</td>
#       <td>6</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F3_IN_A2B1_ATTCAGAA-TATAGCCT_L008_R2.unassigned</th>
#       <td>18,411,871</td>
#       <td>17,563,005</td>
#       <td>9299647</td>
#       <td>4,079,618</td>
#       <td>49.37%</td>
#       <td>2,933,614</td>
#       <td>0.719090</td>
#       <td>0.159333</td>
#       <td>35,668</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F3_IP_A2B1_GAATTCGT-TATAGCCT_L008_R2.A01_F3_IP_mnCLIP_A2B1_med_1_hnRNPA2B1</th>
#       <td>6,049,518</td>
#       <td>5,390,244</td>
#       <td>877013</td>
#       <td>3,593,141</td>
#       <td>79.61%</td>
#       <td>2,878,580</td>
#       <td>0.801132</td>
#       <td>0.475836</td>
#       <td>17,432</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F3_IP_A2B1_GAATTCGT-TATAGCCT_L008_R2.B06_F3_IP_mnCLIP_A2B1_med_1_hnRNPA2B1</th>
#       <td>2,356,015</td>
#       <td>2,143,946</td>
#       <td>443411</td>
#       <td>1,367,241</td>
#       <td>80.40%</td>
#       <td>1,199,320</td>
#       <td>0.877183</td>
#       <td>0.509046</td>
#       <td>7,821</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F3_IP_A2B1_GAATTCGT-TATAGCCT_L008_R2.C01</th>
#       <td>59,190</td>
#       <td>48,690</td>
#       <td>6574</td>
#       <td>33,073</td>
#       <td>78.53%</td>
#       <td>27,857</td>
#       <td>0.842288</td>
#       <td>0.470637</td>
#       <td>41</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F3_IP_A2B1_GAATTCGT-TATAGCCT_L008_R2.D08fixed</th>
#       <td>31,133</td>
#       <td>23,997</td>
#       <td>3846</td>
#       <td>15,599</td>
#       <td>77.41%</td>
#       <td>13,679</td>
#       <td>0.876915</td>
#       <td>0.439373</td>
#       <td>31</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F3_IP_mnCLIP_A2B1_med_1_hnRNPA2B1merged.peaks</th>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>23,785</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F4_IN_A2B1_ATTACTCG-ATAGAGGC_L008_R2.A04</th>
#       <td>58,638</td>
#       <td>55,974</td>
#       <td>54415</td>
#       <td>854</td>
#       <td>54.78%</td>
#       <td>765</td>
#       <td>0.895785</td>
#       <td>0.013046</td>
#       <td>6</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F4_IN_A2B1_ATTACTCG-ATAGAGGC_L008_R2.unassigned</th>
#       <td>18,235,734</td>
#       <td>17,267,263</td>
#       <td>9029645</td>
#       <td>4,188,953</td>
#       <td>50.85%</td>
#       <td>3,074,445</td>
#       <td>0.733941</td>
#       <td>0.168595</td>
#       <td>0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F4_IP_A2B1_TCCGGAGA-ATAGAGGC_L008_R2.A01</th>
#       <td>31,718</td>
#       <td>24,316</td>
#       <td>3845</td>
#       <td>15,732</td>
#       <td>76.85%</td>
#       <td>13,820</td>
#       <td>0.878464</td>
#       <td>0.435715</td>
#       <td>26</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F4_IP_A2B1_TCCGGAGA-ATAGAGGC_L008_R2.C01_F4_IP_mnCLIP_A2B1_med_2_hnRNPA2B1</th>
#       <td>9,378,904</td>
#       <td>8,111,655</td>
#       <td>1066268</td>
#       <td>5,525,978</td>
#       <td>78.43%</td>
#       <td>4,435,658</td>
#       <td>0.802692</td>
#       <td>0.472940</td>
#       <td>24,454</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F4_IP_A2B1_TCCGGAGA-ATAGAGGC_L008_R2.D08fixed_F4_IP_mnCLIP_A2B1_med_2_hnRNPA2B1</th>
#       <td>1,764,674</td>
#       <td>1,563,807</td>
#       <td>232779</td>
#       <td>1,057,608</td>
#       <td>79.46%</td>
#       <td>958,702</td>
#       <td>0.906481</td>
#       <td>0.543274</td>
#       <td>5,590</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F4_IP_mnCLIP_A2B1_med_2_hnRNPA2B1merged.peaks</th>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>27,590</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F5_IN_A2B1_CGCTCATT-ATAGAGGC_L008_R2.unassigned</th>
#       <td>11,021,670</td>
#       <td>10,311,978</td>
#       <td>5128214</td>
#       <td>2,367,722</td>
#       <td>45.68%</td>
#       <td>1,592,874</td>
#       <td>0.672745</td>
#       <td>0.144522</td>
#       <td>0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F5_IP_A2B1_GAGATTCC-ATAGAGGC_L008_R2.A01_F5_IP_mnCLIP_A2B1_low_1_hnRNPA2B1</th>
#       <td>6,800,221</td>
#       <td>6,173,041</td>
#       <td>859336</td>
#       <td>4,369,535</td>
#       <td>82.23%</td>
#       <td>3,726,904</td>
#       <td>0.852929</td>
#       <td>0.548056</td>
#       <td>18,228</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F5_IP_A2B1_GAGATTCC-ATAGAGGC_L008_R2.B06_F5_IP_mnCLIP_A2B1_low_1_hnRNPA2B1</th>
#       <td>1,448,199</td>
#       <td>1,330,567</td>
#       <td>232347</td>
#       <td>908,710</td>
#       <td>82.74%</td>
#       <td>840,597</td>
#       <td>0.925044</td>
#       <td>0.580443</td>
#       <td>4,391</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F5_IP_mnCLIP_A2B1_low_1_hnRNPA2B1merged.peaks</th>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>21,822</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>F6_IN_A2B1_ATTCAGAA-ATAGAGGC_L008_R2.unassigned</th>
#       <td>8,448,855</td>
#       <td>7,934,240</td>
#       <td>3956911</td>
#       <td>1,675,069</td>
#       <td>42.12%</td>
#       <td>1,104,996</td>
#       <td>0.659672</td>
#       <td>0.130786</td>
#       <td>0</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>F6_IP_A2B1_GAATTCGT-ATAGAGGC_L008_R2.A01</th>
#       <td>1,237,354</td>
#       <td>1,107,587</td>
#       <td>157847<
