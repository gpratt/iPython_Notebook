# %%
from collections import defaultdict, Counter
import glob
import os

from IPython.core.display import HTML, Image
from matplotlib_venn import venn3
import pandas as pd
import pybedtools
import pysam

from gscripts.general import parsers

# %%
# %load_ext autoreload
# %autoreload 2
reload(parsers)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <module 'gscripts.general.parsers' from '/nas/nas0/gpratt/gscripts/gscripts/general/parsers.pyc'>

# %%
fet_clip
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#
# [0 rows x 0 columns]

# %%
analysis_dir = "/nas3/gpratt/projects/fet_family/analysis/fet_iclip_v1/"
fet_clip = parsers.clipseq_metrics(analysis_dir, iclip=True)

fet_clip["Reads After Triming"] = fet_clip['Input Reads'] - fet_clip['Too short reads']
fet_clip["Percent Collapsed"] = fet_clip['Usable Reads'] / fet_clip['Uniquely Mapped Reads'].astype(float)
fet_clip["Percent Usable"] = fet_clip['Usable Reads'] / fet_clip['Input Reads'].astype(float)

filtered_guttman_clip = fet_clip[[ "Input Reads",
                            "Reads After Triming",
                            "Uniquely Mapped Reads",
                            #"Uniquely mapped reads %",
                            "Usable Reads",
                            "Percent Collapsed",
                            "Percent Usable",
                            #"spot",
                            "Num Peaks",
                            ]]

HTML(filtered_guttman_clip.to_html(formatters={"Input Reads" : parsers.commas,
                                     "Reads After Triming" : parsers.commas,
                                     "Reads after Quality Filtering" : parsers.commas,
                                     "Uniquely Mapped Reads" : parsers.commas,
                                     "Usable Reads" : parsers.commas,
                                     "Num Peaks": parsers.commas
                                     } ))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Input Reads</th>
#       <th>Reads After Triming</th>
#       <th>Uniquely Mapped Reads</th>
#       <th>Usable Reads</th>
#       <th>Percent Collapsed</th>
#       <th>Percent Usable</th>
#       <th>Num Peaks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kki_1_NoIndex_L003_R1.R04_FUS_1_H</th>
#       <td> 31,691,207</td>
#       <td> 31,565,390</td>
#       <td> 20,879,934</td>
#       <td>  186,228</td>
#       <td> 0.008919</td>
#       <td> 0.005876</td>
#       <td>   61</td>
#     </tr>
#     <tr>
#       <th>Kki_1_NoIndex_L003_R1.R07</th>
#       <td>    614,830</td>
#       <td>    612,764</td>
#       <td>    166,010</td>
#       <td>    2,316</td>
#       <td> 0.013951</td>
#       <td> 0.003767</td>
#       <td>    1</td>
#     </tr>
#     <tr>
#       <th>Kki_1_NoIndex_L003_R1.R08</th>
#       <td>    498,564</td>
#       <td>    497,126</td>
#       <td>     57,408</td>
#       <td>      933</td>
#       <td> 0.016252</td>
#       <td> 0.001871</td>
#       <td>    0</td>
#     </tr>
#     <tr>
#       <th>Kki_1_NoIndex_L003_R1.R09_FUS_2_H</th>
#       <td>124,722,530</td>
#       <td>124,000,203</td>
#       <td> 71,908,099</td>
#       <td>  718,135</td>
#       <td> 0.009987</td>
#       <td> 0.005758</td>
#       <td>  710</td>
#     </tr>
#     <tr>
#       <th>Kki_1_NoIndex_L003_R1.R10_TAF15_1_H</th>
#       <td> 34,933,042</td>
#       <td> 34,786,558</td>
#       <td> 21,366,215</td>
#       <td>  222,362</td>
#       <td> 0.010407</td>
#       <td> 0.006365</td>
#       <td>   75</td>
#     </tr>
#     <tr>
#       <th>Kki_1_NoIndex_L003_R1.unassigned</th>
#       <td>  7,874,728</td>
#       <td>  7,836,460</td>
#       <td>  2,871,664</td>
#       <td>1,062,850</td>
#       <td> 0.370116</td>
#       <td> 0.134970</td>
#       <td>  293</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R02</th>
#       <td>  1,551,507</td>
#       <td>  1,546,337</td>
#       <td>    193,925</td>
#       <td>    4,409</td>
#       <td> 0.022736</td>
#       <td> 0.002842</td>
#       <td>    5</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R03</th>
#       <td>    734,954</td>
#       <td>    732,116</td>
#       <td>     37,652</td>
#       <td>    1,667</td>
#       <td> 0.044274</td>
#       <td> 0.002268</td>
#       <td>    0</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R07_TAF15_2_M</th>
#       <td> 35,747,458</td>
#       <td> 35,621,757</td>
#       <td> 19,798,347</td>
#       <td>  280,897</td>
#       <td> 0.014188</td>
#       <td> 0.007858</td>
#       <td>   82</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R08_TDP43_1_H</th>
#       <td> 32,499,475</td>
#       <td> 32,402,665</td>
#       <td>  9,828,728</td>
#       <td>  112,942</td>
#       <td> 0.011491</td>
#       <td> 0.003475</td>
#       <td>  244</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R09</th>
#       <td>  2,367,852</td>
#       <td>  2,358,878</td>
#       <td>    773,333</td>
#       <td>   11,043</td>
#       <td> 0.014280</td>
#       <td> 0.004664</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R10</th>
#       <td>  2,181,687</td>
#       <td>  2,174,444</td>
#       <td>    708,613</td>
#       <td>    9,182</td>
#       <td> 0.012958</td>
#       <td> 0.004209</td>
#       <td>    2</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.R11_TDP43_2_H</th>
#       <td>109,011,844</td>
#       <td>108,354,056</td>
#       <td> 44,952,272</td>
#       <td>  465,424</td>
#       <td> 0.010354</td>
#       <td> 0.004269</td>
#       <td>  129</td>
#     </tr>
#     <tr>
#       <th>Kki_2_NoIndex_L004_R1.unassigned</th>
#       <td>  9,473,340</td>
#       <td>  9,421,165</td>
#       <td>  2,741,853</td>
#       <td>  270,780</td>
#       <td> 0.098758</td>
#       <td> 0.028583</td>
#       <td>  130</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.R02</th>
#       <td>    983,312</td>
#       <td>    978,256</td>
#       <td>    162,474</td>
#       <td>    4,434</td>
#       <td> 0.027291</td>
#       <td> 0.004509</td>
#       <td>    3</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.R07_TAF15_2_H</th>
#       <td>131,974,613</td>
#       <td>130,847,718</td>
#       <td> 72,049,473</td>
#       <td>1,251,844</td>
#       <td> 0.017375</td>
#       <td> 0.009485</td>
#       <td>  990</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.R08_TDP43_1_M</th>
#       <td> 24,258,457</td>
#       <td> 24,074,215</td>
#       <td>  9,459,704</td>
#       <td>  162,806</td>
#       <td> 0.017210</td>
#       <td> 0.006711</td>
#       <td>  389</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.R09</th>
#       <td>  4,387,116</td>
#       <td>  4,355,500</td>
#       <td>  1,391,332</td>
#       <td>   31,068</td>
#       <td> 0.022330</td>
#       <td> 0.007082</td>
#       <td>   19</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.R10</th>
#       <td>  3,323,874</td>
#       <td>  3,305,312</td>
#       <td>  1,081,142</td>
#       <td>   19,185</td>
#       <td> 0.017745</td>
#       <td> 0.005772</td>
#       <td>   18</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.R11_TDP43_2_M</th>
#       <td> 36,960,092</td>
#       <td> 36,340,569</td>
#       <td> 15,673,026</td>
#       <td>  206,317</td>
#       <td> 0.013164</td>
#       <td> 0.005582</td>
#       <td>1,546</td>
#     </tr>
#     <tr>
#       <th>Kki_3_NoIndex_L005_R1.unassigned</th>
#       <td>  9,632,270</td>
#       <td>  9,544,130</td>
#       <td>  3,362,772</td>
#       <td>  462,361</td>
#       <td> 0.137494</td>
#       <td> 0.048001</td>
#       <td>  306</td>
#     </tr>
#   </tbody>
# </table>
